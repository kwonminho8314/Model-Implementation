# %%
import tensorflow as tf 
from tensorflow.keras import backend, regularizers, initializers, models
from tensorflow.keras import layers
from tensorflow import keras
from tensorflow.keras.utils import plot_model


def _gen_l2_regularizer(use_l2_regularizer=True, l2_weight_decay=1e-4):
  return regularizers.l2(l2_weight_decay) if use_l2_regularizer else None

# %%
cifar10 = keras.datasets.cifar10

(x_train, y_train), (x_test, y_test) = cifar10.load_data()
x_train, x_test = x_train / 255.0, x_test / 255.0

print("x_train:", len(x_train), "x_test:", len(x_test))
# Out:
# x_train: 50000 x_test: 10000

# %%
def plain_conv_block(input_tensor,
               filters,
               stage,
               block,
               strides=(2,2),
               use_l2_regularizer=True,
               bn_decay=0.9,
               bn_epsilon=1e-5):
  

  if backend.image_data_format() == 'channels_last':
    bn_axis=3
  else:
    bn_axis=1

  conv_name='conv'+str(stage)+block+'_branch'
  bn_name='bn'+str(stage)+block+'_branch'

  x = layers.Conv2D(filters,(3,3),strides=strides,padding='same',use_bias=False,kernel_initializer='he_normal',
                    kernel_regularizer=_gen_l2_regularizer(use_l2_regularizer),
                    name = conv_name+'2a')(input_tensor)

  x = layers.BatchNormalization(axis=bn_axis, momentum=bn_decay, epsilon=bn_epsilon,name=bn_name+'2a')(x)

  x = layers.Activation('relu')(x)
  
  x = layers.Conv2D(filters,(3,3),use_bias=False,padding='same',kernel_initializer='he_normal',
                    kernel_regularizer=_gen_l2_regularizer(use_l2_regularizer),
                    name = conv_name+'2b')(x)

  x = layers.BatchNormalization(axis=bn_axis, momentum=bn_decay, epsilon=bn_epsilon,name=bn_name+'2b')(x)

  x = layers.Activation('relu')(x)

  return x

# %%
def plain_identity_block(input_tensor,
                   filters,
                   stage,
                   block,
                   use_l2_regularizer=True,
                   bn_decay=0.9,
                   bn_epsilon=1e-5):
  
  if backend.image_data_format() == 'channels_last':
    bn_axis=3
  else:
    bn_axis=1

  id_name='id'+str(stage)+block+'_branch'
  bn_name='bn'+str(stage)+block+'_branch'

  x = layers.Conv2D(filters,(3,3),padding='same',use_bias=False,kernel_initializer='he_normal',
                    kernel_regularizer=_gen_l2_regularizer(use_l2_regularizer),
                    name = id_name+'2a')(input_tensor)

  x = layers.BatchNormalization(axis=bn_axis,momentum=bn_decay, epsilon=bn_epsilon,name=bn_name+'2a')(x)

  x = layers.Activation('relu')(x)

  x = layers.Conv2D(filters,(3,3),padding='same',use_bias=False,kernel_initializer='he_normal',
                    kernel_regularizer=_gen_l2_regularizer(use_l2_regularizer),
                    name = id_name+'2b')(x)

  x = layers.BatchNormalization(axis=bn_axis,momentum=bn_decay, epsilon=bn_epsilon,name=bn_name+'2b')(x)
  
  x = layers.Activation('relu')(x)

  return x

# %%
def plain34(num_classes,
             batch_size=None,
             use_l2_regularizer=True,
             rescale_inputs=False,
             bn_decay=0.9,
             bn_epsilon=1e-5):
 

  input_shape = (32, 32, 3) 
  img_input = layers.Input(shape=input_shape, batch_size=batch_size)
  if rescale_inputs:
  
    x = layers.Lambda(
        lambda x: x * 255.0 - backend.constant(
            imagenet_preprocessing.CHANNEL_MEANS,
            shape=[1, 1, 3],
            dtype=x.dtype),
        name='rescale')(
            img_input)
  else:
    x = img_input

  if backend.image_data_format() == 'channels_first':
    x = layers.Permute((3, 1, 2))(x)
    bn_axis = 1
  else:  # channels_last
    bn_axis = 3

  block_config = dict(
      use_l2_regularizer=use_l2_regularizer,
      bn_decay=bn_decay,
      bn_epsilon=bn_epsilon)
  x = layers.ZeroPadding2D(padding=(3, 3), name='conv1_pad')(x)
  x = layers.Conv2D(
      64, (7, 7),
      strides=(2, 2),
      padding='valid',
      use_bias=False,
      kernel_initializer='he_normal',
      kernel_regularizer=_gen_l2_regularizer(use_l2_regularizer),
      name='conv1')(
          x)
  x = layers.BatchNormalization(
      axis=bn_axis,
      momentum=bn_decay,
      epsilon=bn_epsilon,
      name='bn_conv1')(
          x)
  x = layers.Activation('relu')(x)
  x = layers.MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)

  x = plain_identity_block(x, 64, stage=2, block='a', **block_config)
  x = plain_identity_block(x, 64, stage=2, block='b', **block_config)
  x = plain_identity_block(x, 64, stage=2, block='c', **block_config)

  x = plain_conv_block(x,128, stage=3, block='a', **block_config)
  x = plain_identity_block(x, 128, stage=3, block='b', **block_config)
  x = plain_identity_block(x, 128, stage=3, block='c', **block_config)
  x = plain_identity_block(x, 128, stage=3, block='d', **block_config)

  x = plain_conv_block(x,256, stage=4, block='a', **block_config)
  x = plain_identity_block(x,256, stage=4, block='b', **block_config)
  x = plain_identity_block(x, 256, stage=4, block='c', **block_config)
  x = plain_identity_block(x, 256, stage=4, block='d', **block_config)
  x = plain_identity_block(x, 256, stage=4, block='e', **block_config)
  x = plain_identity_block(x, 256, stage=4, block='f', **block_config)

  x = plain_conv_block(x,512, stage=5, block='a', **block_config)
  x = plain_identity_block(x, 512, stage=5, block='b', **block_config)
  x = plain_identity_block(x, 512, stage=5, block='c', **block_config)

  x = layers.GlobalAveragePooling2D()(x)
  x = layers.Dense(
      num_classes,
      kernel_initializer=initializers.RandomNormal(stddev=0.01),
      kernel_regularizer=_gen_l2_regularizer(use_l2_regularizer),
      bias_regularizer=_gen_l2_regularizer(use_l2_regularizer),
      name='fc1000')(x)

  x = layers.Activation('softmax', dtype='float32')(x)

  return models.Model(img_input, x, name='plain34')

# %%
plain_34 = plain34(num_classes=10)
plain_34.summary()
# Out:
# Model: "plain34"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 32, 32, 3)]       0
#
#  conv1_pad (ZeroPadding2D)   (None, 38, 38, 3)         0
#
#  conv1 (Conv2D)              (None, 16, 16, 64)        9408
#
#  bn_conv1 (BatchNormalizatio  (None, 16, 16, 64)       256
#  n)
#
#  activation (Activation)     (None, 16, 16, 64)        0
#
#  max_pooling2d (MaxPooling2D  (None, 8, 8, 64)         0
#  )
#
#  id2a_branch2a (Conv2D)      (None, 8, 8, 64)          36864
#
#  bn2a_branch2a (BatchNormali  (None, 8, 8, 64)         256
#  zation)
#
#  activation_1 (Activation)   (None, 8, 8, 64)          0
#
#  id2a_branch2b (Conv2D)      (None, 8, 8, 64)          36864
#
#  bn2a_branch2b (BatchNormali  (None, 8, 8, 64)         256
#  zation)
#
#  activation_2 (Activation)   (None, 8, 8, 64)          0
#
#  id2b_branch2a (Conv2D)      (None, 8, 8, 64)          36864
#
#  bn2b_branch2a (BatchNormali  (None, 8, 8, 64)         256
#  zation)
#
#  activation_3 (Activation)   (None, 8, 8, 64)          0
#
#  id2b_branch2b (Conv2D)      (None, 8, 8, 64)          36864
#
#  bn2b_branch2b (BatchNormali  (None, 8, 8, 64)         256
#  zation)
#
#  activation_4 (Activation)   (None, 8, 8, 64)          0
#
#  id2c_branch2a (Conv2D)      (None, 8, 8, 64)          36864
#
#  bn2c_branch2a (BatchNormali  (None, 8, 8, 64)         256
#  zation)
#
#  activation_5 (Activation)   (None, 8, 8, 64)          0
#
#  id2c_branch2b (Conv2D)      (None, 8, 8, 64)          36864
#
#  bn2c_branch2b (BatchNormali  (None, 8, 8, 64)         256
#  zation)
#
#  activation_6 (Activation)   (None, 8, 8, 64)          0
#
#  conv3a_branch2a (Conv2D)    (None, 4, 4, 128)         73728
#
#  bn3a_branch2a (BatchNormali  (None, 4, 4, 128)        512
#  zation)
#
#  activation_7 (Activation)   (None, 4, 4, 128)         0
#
#  conv3a_branch2b (Conv2D)    (None, 4, 4, 128)         147456
#
#  bn3a_branch2b (BatchNormali  (None, 4, 4, 128)        512
#  zation)
#
#  activation_8 (Activation)   (None, 4, 4, 128)         0
#
#  id3b_branch2a (Conv2D)      (None, 4, 4, 128)         147456
#
#  bn3b_branch2a (BatchNormali  (None, 4, 4, 128)        512
#  zation)
#
#  activation_9 (Activation)   (None, 4, 4, 128)         0
#
#  id3b_branch2b (Conv2D)      (None, 4, 4, 128)         147456
#
#  bn3b_branch2b (BatchNormali  (None, 4, 4, 128)        512
#  zation)
#
#  activation_10 (Activation)  (None, 4, 4, 128)         0
#
#  id3c_branch2a (Conv2D)      (None, 4, 4, 128)         147456
#
#  bn3c_branch2a (BatchNormali  (None, 4, 4, 128)        512
#  zation)
#
#  activation_11 (Activation)  (None, 4, 4, 128)         0
#
#  id3c_branch2b (Conv2D)      (None, 4, 4, 128)         147456
#
#  bn3c_branch2b (BatchNormali  (None, 4, 4, 128)        512
#  zation)
#
#  activation_12 (Activation)  (None, 4, 4, 128)         0
#
#  id3d_branch2a (Conv2D)      (None, 4, 4, 128)         147456
#
#  bn3d_branch2a (BatchNormali  (None, 4, 4, 128)        512
#  zation)
#
#  activation_13 (Activation)  (None, 4, 4, 128)         0
#
#  id3d_branch2b (Conv2D)      (None, 4, 4, 128)         147456
#
#  bn3d_branch2b (BatchNormali  (None, 4, 4, 128)        512
#  zation)
#
#  activation_14 (Activation)  (None, 4, 4, 128)         0
#
#  conv4a_branch2a (Conv2D)    (None, 2, 2, 256)         294912
#
#  bn4a_branch2a (BatchNormali  (None, 2, 2, 256)        1024
#  zation)
#
#  activation_15 (Activation)  (None, 2, 2, 256)         0
#
#  conv4a_branch2b (Conv2D)    (None, 2, 2, 256)         589824
#
#  bn4a_branch2b (BatchNormali  (None, 2, 2, 256)        1024
#  zation)
#
#  activation_16 (Activation)  (None, 2, 2, 256)         0
#
#  id4b_branch2a (Conv2D)      (None, 2, 2, 256)         589824
#
#  bn4b_branch2a (BatchNormali  (None, 2, 2, 256)        1024
#  zation)
#
#  activation_17 (Activation)  (None, 2, 2, 256)         0
#
#  id4b_branch2b (Conv2D)      (None, 2, 2, 256)         589824
#
#  bn4b_branch2b (BatchNormali  (None, 2, 2, 256)        1024
#  zation)
#
#  activation_18 (Activation)  (None, 2, 2, 256)         0
#
#  id4c_branch2a (Conv2D)      (None, 2, 2, 256)         589824
#
#  bn4c_branch2a (BatchNormali  (None, 2, 2, 256)        1024
#  zation)
#
#  activation_19 (Activation)  (None, 2, 2, 256)         0
#
#  id4c_branch2b (Conv2D)      (None, 2, 2, 256)         589824
#
#  bn4c_branch2b (BatchNormali  (None, 2, 2, 256)        1024
#  zation)
#
#  activation_20 (Activation)  (None, 2, 2, 256)         0
#
#  id4d_branch2a (Conv2D)      (None, 2, 2, 256)         589824
#
#  bn4d_branch2a (BatchNormali  (None, 2, 2, 256)        1024
#  zation)
#
#  activation_21 (Activation)  (None, 2, 2, 256)         0
#
#  id4d_branch2b (Conv2D)      (None, 2, 2, 256)         589824
#
#  bn4d_branch2b (BatchNormali  (None, 2, 2, 256)        1024
#  zation)
#
#  activation_22 (Activation)  (None, 2, 2, 256)         0
#
#  id4e_branch2a (Conv2D)      (None, 2, 2, 256)         589824
#
#  bn4e_branch2a (BatchNormali  (None, 2, 2, 256)        1024
#  zation)
#
#  activation_23 (Activation)  (None, 2, 2, 256)         0
#
#  id4e_branch2b (Conv2D)      (None, 2, 2, 256)         589824
#
#  bn4e_branch2b (BatchNormali  (None, 2, 2, 256)        1024
#  zation)
#
#  activation_24 (Activation)  (None, 2, 2, 256)         0
#
#  id4f_branch2a (Conv2D)      (None, 2, 2, 256)         589824
#
#  bn4f_branch2a (BatchNormali  (None, 2, 2, 256)        1024
#  zation)
#
#  activation_25 (Activation)  (None, 2, 2, 256)         0
#
#  id4f_branch2b (Conv2D)      (None, 2, 2, 256)         589824
#
#  bn4f_branch2b (BatchNormali  (None, 2, 2, 256)        1024
#  zation)
#
#  activation_26 (Activation)  (None, 2, 2, 256)         0
#
#  conv5a_branch2a (Conv2D)    (None, 1, 1, 512)         1179648
#
#  bn5a_branch2a (BatchNormali  (None, 1, 1, 512)        2048
#  zation)
#
#  activation_27 (Activation)  (None, 1, 1, 512)         0
#
#  conv5a_branch2b (Conv2D)    (None, 1, 1, 512)         2359296
#
#  bn5a_branch2b (BatchNormali  (None, 1, 1, 512)        2048
#  zation)
#
#  activation_28 (Activation)  (None, 1, 1, 512)         0
#
#  id5b_branch2a (Conv2D)      (None, 1, 1, 512)         2359296
#
#  bn5b_branch2a (BatchNormali  (None, 1, 1, 512)        2048
#  zation)
#
#  activation_29 (Activation)  (None, 1, 1, 512)         0
#
#  id5b_branch2b (Conv2D)      (None, 1, 1, 512)         2359296
#
#  bn5b_branch2b (BatchNormali  (None, 1, 1, 512)        2048
#  zation)
#
#  activation_30 (Activation)  (None, 1, 1, 512)         0
#
#  id5c_branch2a (Conv2D)      (None, 1, 1, 512)         2359296
#
#  bn5c_branch2a (BatchNormali  (None, 1, 1, 512)        2048
#  zation)
#
#  activation_31 (Activation)  (None, 1, 1, 512)         0
#
#  id5c_branch2b (Conv2D)      (None, 1, 1, 512)         2359296
#
#  bn5c_branch2b (BatchNormali  (None, 1, 1, 512)        2048
#  zation)
#
#  activation_32 (Activation)  (None, 1, 1, 512)         0
#
#  global_average_pooling2d (G  (None, 512)              0
#  lobalAveragePooling2D)
#
#  fc1000 (Dense)              (None, 10)                5130
#
#  activation_33 (Activation)  (None, 10)                0
#
# =================================================================
# Total params: 21,131,210
# Trainable params: 21,115,978
# Non-trainable params: 15,232
# _________________________________________________________________

# %%
plot_model(plain_34,show_shapes=True)

# %%
plain_34.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

history_plain34 = plain_34.fit(x_train, y_train, epochs=100)
# Out:
# Epoch 1/100
# 1563/1563 [==============================] - 45s 26ms/step - loss: 2.6509 - accuracy: 0.2490
# Epoch 2/100
# 1563/1563 [==============================] - 40s 26ms/step - loss: 2.2654 - accuracy: 0.2377
# Epoch 3/100
# 1563/1563 [==============================] - 40s 26ms/step - loss: 2.1565 - accuracy: 0.2429
# Epoch 4/100
# 1563/1563 [==============================] - 40s 26ms/step - loss: 2.2236 - accuracy: 0.2163
# Epoch 5/100
# 1563/1563 [==============================] - 40s 26ms/step - loss: 2.3542 - accuracy: 0.1759
# Epoch 6/100
# 1563/1563 [==============================] - 40s 26ms/step - loss: 2.4390 - accuracy: 0.1448
# Epoch 7/100
# 1563/1563 [==============================] - 40s 26ms/step - loss: 2.5249 - accuracy: 0.1658
# Epoch 8/100
# 1563/1563 [==============================] - 40s 26ms/step - loss: 2.2853 - accuracy: 0.1971
# Epoch 9/100
# 1563/1563 [==============================] - 40s 26ms/step - loss: 2.0469 - accuracy: 0.2485
# Epoch 10/100
# 1563/1563 [==============================] - 40s 26ms/step - loss: 2.0378 - accuracy: 0.2585
# Epoch 11/100
# 1563/1563 [==============================] - 40s 26ms/step - loss: 2.1348 - accuracy: 0.2532
# Epoch 12/100
# 1563/1563 [==============================] - 40s 26ms/step - loss: 1.9999 - accuracy: 0.2868
# Epoch 13/100
# 1563/1563 [==============================] - 40s 26ms/step - loss: 2.0457 - accuracy: 0.2743
# Epoch 14/100
# 1563/1563 [==============================] - 40s 26ms/step - loss: 2.0902 - accuracy: 0.2807
# Epoch 15/100
# 1563/1563 [==============================] - 40s 26ms/step - loss: 2.2157 - accuracy: 0.2507
# Epoch 16/100
# 1563/1563 [==============================] - 40s 26ms/step - loss: 1.9929 - accuracy: 0.2990
# Epoch 17/100
# 1563/1563 [==============================] - 40s 26ms/step - loss: 1.9376 - accuracy: 0.3025
# Epoch 18/100
# 1563/1563 [==============================] - 40s 26ms/step - loss: 1.9265 - accuracy: 0.3160
# Epoch 19/100
# 1563/1563 [==============================] - 40s 26ms/step - loss: 1.9015 - accuracy: 0.3223
# Epoch 20/100
# 1563/1563 [==============================] - 40s 26ms/step - loss: 1.9278 - accuracy: 0.3200
# Epoch 21/100
# 1563/1563 [==============================] - 40s 26ms/step - loss: 2.2213 - accuracy: 0.2229
# Epoch 22/100
# 1563/1563 [==============================] - 40s 26ms/step - loss: 2.0810 - accuracy: 0.2708
# Epoch 23/100
# 1563/1563 [==============================] - 40s 26ms/step - loss: 1.9542 - accuracy: 0.3206
# Epoch 24/100
# 1563/1563 [==============================] - 40s 26ms/step - loss: 2.1582 - accuracy: 0.2470
# Epoch 25/100
# 1563/1563 [==============================] - 40s 26ms/step - loss: 2.1206 - accuracy: 0.2416
# Epoch 26/100
# 1563/1563 [==============================] - 40s 26ms/step - loss: 1.8658 - accuracy: 0.3279
# Epoch 27/100
# 1563/1563 [==============================] - 40s 26ms/step - loss: 1.8487 - accuracy: 0.3406
# Epoch 28/100
# 1563/1563 [==============================] - 40s 26ms/step - loss: 1.8513 - accuracy: 0.3489
# Epoch 29/100
# 1563/1563 [==============================] - 40s 26ms/step - loss: 1.8660 - accuracy: 0.3408
# Epoch 30/100
# 1563/1563 [==============================] - 40s 26ms/step - loss: 1.9196 - accuracy: 0.3328
# Epoch 31/100
# 1563/1563 [==============================] - 40s 26ms/step - loss: 2.0474 - accuracy: 0.2977
# Epoch 32/100
# 1563/1563 [==============================] - 40s 26ms/step - loss: 2.0239 - accuracy: 0.3019
# Epoch 33/100
# 1563/1563 [==============================] - 40s 26ms/step - loss: 2.1956 - accuracy: 0.2150
# Epoch 34/100
# 1563/1563 [==============================] - 40s 26ms/step - loss: 1.9309 - accuracy: 0.3080
# Epoch 35/100
# 1563/1563 [==============================] - 40s 26ms/step - loss: 1.9124 - accuracy: 0.3164
# Epoch 36/100
# 1563/1563 [==============================] - 40s 26ms/step - loss: 1.9681 - accuracy: 0.2975
# Epoch 37/100
# 1563/1563 [==============================] - 40s 26ms/step - loss: 1.9749 - accuracy: 0.2909
# Epoch 38/100
# 1563/1563 [==============================] - 40s 26ms/step - loss: 2.0190 - accuracy: 0.2842
# Epoch 39/100
# 1563/1563 [==============================] - 40s 26ms/step - loss: 2.1027 - accuracy: 0.2488
# Epoch 40/100
# 1563/1563 [==============================] - 40s 26ms/step - loss: 2.0252 - accuracy: 0.2745
# Epoch 41/100
# 1563/1563 [==============================] - 40s 26ms/step - loss: 1.8978 - accuracy: 0.3174
# Epoch 42/100
# 1563/1563 [==============================] - 40s 26ms/step - loss: 1.8374 - accuracy: 0.3398
# Epoch 43/100
# 1563/1563 [==============================] - 40s 26ms/step - loss: 1.8236 - accuracy: 0.3457
# Epoch 44/100
# 1563/1563 [==============================] - 40s 26ms/step - loss: 1.7598 - accuracy: 0.3718
# Epoch 45/100
# 1563/1563 [==============================] - 40s 26ms/step - loss: 1.8981 - accuracy: 0.3267
# Epoch 46/100
# 1563/1563 [==============================] - 40s 26ms/step - loss: 2.1800 - accuracy: 0.2266
# Epoch 47/100
# 1563/1563 [==============================] - 40s 26ms/step - loss: 2.0132 - accuracy: 0.2892
# Epoch 48/100
# 1563/1563 [==============================] - 41s 26ms/step - loss: 1.9176 - accuracy: 0.3211
# Epoch 49/100
# 1563/1563 [==============================] - 40s 26ms/step - loss: 1.8256 - accuracy: 0.3534
# Epoch 50/100
# 1563/1563 [==============================] - 40s 26ms/step - loss: 1.8414 - accuracy: 0.3477
# Epoch 51/100
# 1563/1563 [==============================] - 40s 26ms/step - loss: 1.8648 - accuracy: 0.3402
# Epoch 52/100
# 1563/1563 [==============================] - 40s 26ms/step - loss: 1.7655 - accuracy: 0.3798
# Epoch 53/100
# 1563/1563 [==============================] - 40s 26ms/step - loss: 1.7340 - accuracy: 0.3845
# Epoch 54/100
# 1563/1563 [==============================] - 40s 26ms/step - loss: 1.7171 - accuracy: 0.3951
# Epoch 55/100
# 1563/1563 [==============================] - 40s 26ms/step - loss: 1.7667 - accuracy: 0.3878
# Epoch 56/100
# 1563/1563 [==============================] - 40s 26ms/step - loss: 1.7699 - accuracy: 0.3822
# Epoch 57/100
# 1563/1563 [==============================] - 40s 26ms/step - loss: 1.9076 - accuracy: 0.3310
# Epoch 58/100
# 1563/1563 [==============================] - 40s 26ms/step - loss: 1.9347 - accuracy: 0.3214
# Epoch 59/100
# 1563/1563 [==============================] - 40s 26ms/step - loss: 2.1062 - accuracy: 0.2485
# Epoch 60/100
# 1563/1563 [==============================] - 40s 26ms/step - loss: 2.2255 - accuracy: 0.2065
# Epoch 61/100
# 1563/1563 [==============================] - 40s 26ms/step - loss: 2.2103 - accuracy: 0.2039
# Epoch 62/100
# 1563/1563 [==============================] - 40s 26ms/step - loss: 2.1000 - accuracy: 0.2314
# Epoch 63/100
# 1563/1563 [==============================] - 40s 26ms/step - loss: 1.9770 - accuracy: 0.2837
# Epoch 64/100
# 1563/1563 [==============================] - 40s 26ms/step - loss: 2.0274 - accuracy: 0.2820
# Epoch 65/100
# 1563/1563 [==============================] - 40s 26ms/step - loss: 2.1284 - accuracy: 0.2399
# Epoch 66/100
# 1563/1563 [==============================] - 40s 26ms/step - loss: 2.0820 - accuracy: 0.2651
# Epoch 67/100
# 1563/1563 [==============================] - 40s 26ms/step - loss: 2.1005 - accuracy: 0.2562
# Epoch 68/100
# 1563/1563 [==============================] - 41s 26ms/step - loss: 2.0829 - accuracy: 0.2505
# Epoch 69/100
# 1563/1563 [==============================] - 41s 26ms/step - loss: 2.0532 - accuracy: 0.2593
# Epoch 70/100
# 1563/1563 [==============================] - 40s 26ms/step - loss: 2.0209 - accuracy: 0.2689
# Epoch 71/100
# 1563/1563 [==============================] - 40s 26ms/step - loss: 2.0177 - accuracy: 0.2724
# Epoch 72/100
# 1563/1563 [==============================] - 40s 26ms/step - loss: 2.1569 - accuracy: 0.2268
# Epoch 73/100
# 1563/1563 [==============================] - 40s 26ms/step - loss: 2.1876 - accuracy: 0.2324
# Epoch 74/100
# 1563/1563 [==============================] - 41s 26ms/step - loss: 2.1516 - accuracy: 0.2322
# Epoch 75/100
# 1563/1563 [==============================] - 40s 26ms/step - loss: 2.1721 - accuracy: 0.2386
# Epoch 76/100
# 1563/1563 [==============================] - 40s 26ms/step - loss: 2.2423 - accuracy: 0.2097
# Epoch 77/100
# 1563/1563 [==============================] - 41s 26ms/step - loss: 2.2007 - accuracy: 0.2237
# Epoch 78/100
# 1563/1563 [==============================] - 40s 26ms/step - loss: 2.2761 - accuracy: 0.2034
# Epoch 79/100
# 1563/1563 [==============================] - 40s 26ms/step - loss: 2.2841 - accuracy: 0.2071
# Epoch 80/100
# 1563/1563 [==============================] - 40s 26ms/step - loss: 2.2109 - accuracy: 0.2220
# Epoch 81/100
# 1563/1563 [==============================] - 40s 26ms/step - loss: 2.2155 - accuracy: 0.2247
# Epoch 82/100
# 1563/1563 [==============================] - 40s 26ms/step - loss: 2.1377 - accuracy: 0.2416
# Epoch 83/100
# 1563/1563 [==============================] - 40s 26ms/step - loss: 2.1327 - accuracy: 0.2313
# Epoch 84/100
# 1563/1563 [==============================] - 40s 26ms/step - loss: 2.1207 - accuracy: 0.2269
# Epoch 85/100
# 1563/1563 [==============================] - 40s 26ms/step - loss: 2.1078 - accuracy: 0.2357
# Epoch 86/100
# 1563/1563 [==============================] - 40s 26ms/step - loss: 2.0874 - accuracy: 0.2444
# Epoch 87/100
# 1563/1563 [==============================] - 40s 26ms/step - loss: 2.1142 - accuracy: 0.2355
# Epoch 88/100
# 1563/1563 [==============================] - 40s 26ms/step - loss: 2.1316 - accuracy: 0.2451
# Epoch 89/100
# 1563/1563 [==============================] - 40s 26ms/step - loss: 2.0832 - accuracy: 0.2587
# Epoch 90/100
# 1563/1563 [==============================] - 40s 26ms/step - loss: 2.0737 - accuracy: 0.2613
# Epoch 91/100
# 1563/1563 [==============================] - 40s 26ms/step - loss: 2.1694 - accuracy: 0.2387
# Epoch 92/100
# 1563/1563 [==============================] - 40s 26ms/step - loss: 2.1043 - accuracy: 0.2637
# Epoch 93/100
# 1563/1563 [==============================] - 40s 26ms/step - loss: 1.9966 - accuracy: 0.2785
# Epoch 94/100
# 1563/1563 [==============================] - 40s 26ms/step - loss: 2.0084 - accuracy: 0.2772
# Epoch 95/100
# 1563/1563 [==============================] - 40s 26ms/step - loss: 2.0267 - accuracy: 0.2676
# Epoch 96/100
# 1563/1563 [==============================] - 40s 26ms/step - loss: 2.0347 - accuracy: 0.2649
# Epoch 97/100
# 1563/1563 [==============================] - 40s 26ms/step - loss: 2.0820 - accuracy: 0.2515
# Epoch 98/100
# 1563/1563 [==============================] - 40s 26ms/step - loss: 2.0573 - accuracy: 0.2593
# Epoch 99/100
# 1563/1563 [==============================] - 40s 26ms/step - loss: 1.9876 - accuracy: 0.2748
# Epoch 100/100
# 1563/1563 [==============================] - 40s 26ms/step - loss: 2.0040 - accuracy: 0.2751

# %%
def conv_block(input_tensor,
               filters,
               stage,
               block,
               strides=(2,2),
               use_l2_regularizer=True,
               bn_decay=0.9,
               bn_epsilon=1e-5):
  

  if backend.image_data_format() == 'channels_last':
    bn_axis=3
  else:
    bn_axis=1

  conv_name='conv'+str(stage)+block+'_branch'
  bn_name='bn'+str(stage)+block+'_branch'

  x = layers.Conv2D(filters,(3,3),strides=strides,padding='same',use_bias=False,kernel_initializer='he_normal',
                    kernel_regularizer=_gen_l2_regularizer(use_l2_regularizer),
                    name = conv_name+'2a')(input_tensor)

  x = layers.BatchNormalization(axis=bn_axis, momentum=bn_decay, epsilon=bn_epsilon,name=bn_name+'2a')(x)

  x = layers.Activation('relu')(x)
  
  x = layers.Conv2D(filters,(3,3),use_bias=False,padding='same',kernel_initializer='he_normal',
                    kernel_regularizer=_gen_l2_regularizer(use_l2_regularizer),
                    name = conv_name+'2b')(x)

  x = layers.BatchNormalization(axis=bn_axis, momentum=bn_decay, epsilon=bn_epsilon,name=bn_name+'2b')(x)


  shortcut = layers.Conv2D(filters,(3,3),strides=strides,padding='same',use_bias=False,kernel_initializer='he_normal',
                           kernel_regularizer=_gen_l2_regularizer(use_l2_regularizer),
                           name = conv_name+'1')(input_tensor)

  shortcut = layers.BatchNormalization(axis=bn_axis, momentum=bn_decay, epsilon=bn_epsilon,name=bn_name+'1')(shortcut)

  x = layers.add([x, shortcut])

  x = layers.Activation('relu')(x)

  return x

# %%
def identity_block(input_tensor,
                   filters,
                   stage,
                   block,
                   use_l2_regularizer=True,
                   bn_decay=0.9,
                   bn_epsilon=1e-5):
  
  if backend.image_data_format() == 'channels_last':
    bn_axis=3
  else:
    bn_axis=1

  id_name='id'+str(stage)+block+'_branch'
  bn_name='bn'+str(stage)+block+'_branch'

  x = layers.Conv2D(filters,(3,3),padding='same',use_bias=False,kernel_initializer='he_normal',
                    kernel_regularizer=_gen_l2_regularizer(use_l2_regularizer),
                    name = id_name+'2a')(input_tensor)

  x = layers.BatchNormalization(axis=bn_axis,momentum=bn_decay, epsilon=bn_epsilon,name=bn_name+'2a')(x)

  x = layers.Activation('relu')(x)

  x = layers.Conv2D(filters,(3,3),padding='same',use_bias=False,kernel_initializer='he_normal',
                    kernel_regularizer=_gen_l2_regularizer(use_l2_regularizer),
                    name = id_name+'2b')(x)

  x = layers.BatchNormalization(axis=bn_axis,momentum=bn_decay, epsilon=bn_epsilon,name=bn_name+'2b')(x)

  x = layers.add([x,input_tensor])
  
  x = layers.Activation('relu')(x)

  return x

# %%
def resnet34(num_classes,
             batch_size=None,
             use_l2_regularizer=True,
             rescale_inputs=False,
             bn_decay=0.9,
             bn_epsilon=1e-5):

  input_shape = (32, 32, 3)
  img_input = layers.Input(shape=input_shape, batch_size=batch_size)
  if rescale_inputs:
    x = layers.Lambda(
        lambda x: x * 255.0 - backend.constant(
            imagenet_preprocessing.CHANNEL_MEANS,
            shape=[1, 1, 3],
            dtype=x.dtype),
        name='rescale')(
            img_input)
  else:
    x = img_input

  if backend.image_data_format() == 'channels_first':
    x = layers.Permute((3, 1, 2))(x)
    bn_axis = 1
  else:  
    bn_axis = 3

  block_config = dict(
      use_l2_regularizer=use_l2_regularizer,
      bn_decay=bn_decay,
      bn_epsilon=bn_epsilon)
  x = layers.ZeroPadding2D(padding=(3, 3), name='conv1_pad')(x)
  x = layers.Conv2D(
      64, (7, 7),
      strides=(2, 2),
      padding='valid',
      use_bias=False,
      kernel_initializer='he_normal',
      kernel_regularizer=_gen_l2_regularizer(use_l2_regularizer),
      name='conv1')(
          x)
  x = layers.BatchNormalization(
      axis=bn_axis,
      momentum=bn_decay,
      epsilon=bn_epsilon,
      name='bn_conv1')(
          x)
  x = layers.Activation('relu')(x)
  x = layers.MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)

  x = identity_block(x, 64, stage=2, block='a', **block_config)
  x = identity_block(x, 64, stage=2, block='b', **block_config)
  x = identity_block(x, 64, stage=2, block='c', **block_config)

  x = conv_block(x,128, stage=3, block='a', **block_config)
  x = identity_block(x, 128, stage=3, block='b', **block_config)
  x = identity_block(x, 128, stage=3, block='c', **block_config)
  x = identity_block(x, 128, stage=3, block='d', **block_config)

  x = conv_block(x,256, stage=4, block='a', **block_config)
  x = identity_block(x,256, stage=4, block='b', **block_config)
  x = identity_block(x, 256, stage=4, block='c', **block_config)
  x = identity_block(x, 256, stage=4, block='d', **block_config)
  x = identity_block(x, 256, stage=4, block='e', **block_config)
  x = identity_block(x, 256, stage=4, block='f', **block_config)

  x = conv_block(x,512, stage=5, block='a', **block_config)
  x = identity_block(x, 512, stage=5, block='b', **block_config)
  x = identity_block(x, 512, stage=5, block='c', **block_config)

  x = layers.GlobalAveragePooling2D()(x)
  x = layers.Dense(
      num_classes,
      kernel_initializer=initializers.RandomNormal(stddev=0.01),
      kernel_regularizer=_gen_l2_regularizer(use_l2_regularizer),
      bias_regularizer=_gen_l2_regularizer(use_l2_regularizer),
      name='fc1000')(
          x)

  x = layers.Activation('softmax', dtype='float32')(x)

  return models.Model(img_input, x, name='resnet34')

# %%
resnet_34 = resnet34(num_classes=10)
resnet_34.summary()
# Out:
# Model: "resnet34"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 32, 32, 3)]  0           []
#
#  conv1_pad (ZeroPadding2D)      (None, 38, 38, 3)    0           ['input_2[0][0]']
#
#  conv1 (Conv2D)                 (None, 16, 16, 64)   9408        ['conv1_pad[0][0]']
#
#  bn_conv1 (BatchNormalization)  (None, 16, 16, 64)   256         ['conv1[0][0]']
#
#  activation_34 (Activation)     (None, 16, 16, 64)   0           ['bn_conv1[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 8, 8, 64)    0           ['activation_34[0][0]']
#
#  id2a_branch2a (Conv2D)         (None, 8, 8, 64)     36864       ['max_pooling2d_1[0][0]']
#
#  bn2a_branch2a (BatchNormalizat  (None, 8, 8, 64)    256         ['id2a_branch2a[0][0]']
#  ion)
#
#  activation_35 (Activation)     (None, 8, 8, 64)     0           ['bn2a_branch2a[0][0]']
#
#  id2a_branch2b (Conv2D)         (None, 8, 8, 64)     36864       ['activation_35[0][0]']
#
#  bn2a_branch2b (BatchNormalizat  (None, 8, 8, 64)    256         ['id2a_branch2b[0][0]']
#  ion)
#
#  add (Add)                      (None, 8, 8, 64)     0           ['bn2a_branch2b[0][0]',
#                                                                   'max_pooling2d_1[0][0]']
#
#  activation_36 (Activation)     (None, 8, 8, 64)     0           ['add[0][0]']
#
#  id2b_branch2a (Conv2D)         (None, 8, 8, 64)     36864       ['activation_36[0][0]']
#
#  bn2b_branch2a (BatchNormalizat  (None, 8, 8, 64)    256         ['id2b_branch2a[0][0]']
#  ion)
#
#  activation_37 (Activation)     (None, 8, 8, 64)     0           ['bn2b_branch2a[0][0]']
#
#  id2b_branch2b (Conv2D)         (None, 8, 8, 64)     36864       ['activation_37[0][0]']
#
#  bn2b_branch2b (BatchNormalizat  (None, 8, 8, 64)    256         ['id2b_branch2b[0][0]']
#  ion)
#
#  add_1 (Add)                    (None, 8, 8, 64)     0           ['bn2b_branch2b[0][0]',
#                                                                   'activation_36[0][0]']
#
#  activation_38 (Activation)     (None, 8, 8, 64)     0           ['add_1[0][0]']
#
#  id2c_branch2a (Conv2D)         (None, 8, 8, 64)     36864       ['activation_38[0][0]']
#
#  bn2c_branch2a (BatchNormalizat  (None, 8, 8, 64)    256         ['id2c_branch2a[0][0]']
#  ion)
#
#  activation_39 (Activation)     (None, 8, 8, 64)     0           ['bn2c_branch2a[0][0]']
#
#  id2c_branch2b (Conv2D)         (None, 8, 8, 64)     36864       ['activation_39[0][0]']
#
#  bn2c_branch2b (BatchNormalizat  (None, 8, 8, 64)    256         ['id2c_branch2b[0][0]']
#  ion)
#
#  add_2 (Add)                    (None, 8, 8, 64)     0           ['bn2c_branch2b[0][0]',
#                                                                   'activation_38[0][0]']
#
#  activation_40 (Activation)     (None, 8, 8, 64)     0           ['add_2[0][0]']
#
#  conv3a_branch2a (Conv2D)       (None, 4, 4, 128)    73728       ['activation_40[0][0]']
#
#  bn3a_branch2a (BatchNormalizat  (None, 4, 4, 128)   512         ['conv3a_branch2a[0][0]']
#  ion)
#
#  activation_41 (Activation)     (None, 4, 4, 128)    0           ['bn3a_branch2a[0][0]']
#
#  conv3a_branch2b (Conv2D)       (None, 4, 4, 128)    147456      ['activation_41[0][0]']
#
#  conv3a_branch1 (Conv2D)        (None, 4, 4, 128)    73728       ['activation_40[0][0]']
#
#  bn3a_branch2b (BatchNormalizat  (None, 4, 4, 128)   512         ['conv3a_branch2b[0][0]']
#  ion)
#
#  bn3a_branch1 (BatchNormalizati  (None, 4, 4, 128)   512         ['conv3a_branch1[0][0]']
#  on)
#
#  add_3 (Add)                    (None, 4, 4, 128)    0           ['bn3a_branch2b[0][0]',
#                                                                   'bn3a_branch1[0][0]']
#
#  activation_42 (Activation)     (None, 4, 4, 128)    0           ['add_3[0][0]']
#
#  id3b_branch2a (Conv2D)         (None, 4, 4, 128)    147456      ['activation_42[0][0]']
#
#  bn3b_branch2a (BatchNormalizat  (None, 4, 4, 128)   512         ['id3b_branch2a[0][0]']
#  ion)
#
#  activation_43 (Activation)     (None, 4, 4, 128)    0           ['bn3b_branch2a[0][0]']
#
#  id3b_branch2b (Conv2D)         (None, 4, 4, 128)    147456      ['activation_43[0][0]']
#
#  bn3b_branch2b (BatchNormalizat  (None, 4, 4, 128)   512         ['id3b_branch2b[0][0]']
#  ion)
#
#  add_4 (Add)                    (None, 4, 4, 128)    0           ['bn3b_branch2b[0][0]',
#                                                                   'activation_42[0][0]']
#
#  activation_44 (Activation)     (None, 4, 4, 128)    0           ['add_4[0][0]']
#
#  id3c_branch2a (Conv2D)         (None, 4, 4, 128)    147456      ['activation_44[0][0]']
#
#  bn3c_branch2a (BatchNormalizat  (None, 4, 4, 128)   512         ['id3c_branch2a[0][0]']
#  ion)
#
#  activation_45 (Activation)     (None, 4, 4, 128)    0           ['bn3c_branch2a[0][0]']
#
#  id3c_branch2b (Conv2D)         (None, 4, 4, 128)    147456      ['activation_45[0][0]']
#
#  bn3c_branch2b (BatchNormalizat  (None, 4, 4, 128)   512         ['id3c_branch2b[0][0]']
#  ion)
#
#  add_5 (Add)                    (None, 4, 4, 128)    0           ['bn3c_branch2b[0][0]',
#                                                                   'activation_44[0][0]']
#
#  activation_46 (Activation)     (None, 4, 4, 128)    0           ['add_5[0][0]']
#
#  id3d_branch2a (Conv2D)         (None, 4, 4, 128)    147456      ['activation_46[0][0]']
#
#  bn3d_branch2a (BatchNormalizat  (None, 4, 4, 128)   512         ['id3d_branch2a[0][0]']
#  ion)
#
#  activation_47 (Activation)     (None, 4, 4, 128)    0           ['bn3d_branch2a[0][0]']
#
#  id3d_branch2b (Conv2D)         (None, 4, 4, 128)    147456      ['activation_47[0][0]']
#
#  bn3d_branch2b (BatchNormalizat  (None, 4, 4, 128)   512         ['id3d_branch2b[0][0]']
#  ion)
#
#  add_6 (Add)                    (None, 4, 4, 128)    0           ['bn3d_branch2b[0][0]',
#                                                                   'activation_46[0][0]']
#
#  activation_48 (Activation)     (None, 4, 4, 128)    0           ['add_6[0][0]']
#
#  conv4a_branch2a (Conv2D)       (None, 2, 2, 256)    294912      ['activation_48[0][0]']
#
#  bn4a_branch2a (BatchNormalizat  (None, 2, 2, 256)   1024        ['conv4a_branch2a[0][0]']
#  ion)
#
#  activation_49 (Activation)     (None, 2, 2, 256)    0           ['bn4a_branch2a[0][0]']
#
#  conv4a_branch2b (Conv2D)       (None, 2, 2, 256)    589824      ['activation_49[0][0]']
#
#  conv4a_branch1 (Conv2D)        (None, 2, 2, 256)    294912      ['activation_48[0][0]']
#
#  bn4a_branch2b (BatchNormalizat  (None, 2, 2, 256)   1024        ['conv4a_branch2b[0][0]']
#  ion)
#
#  bn4a_branch1 (BatchNormalizati  (None, 2, 2, 256)   1024        ['conv4a_branch1[0][0]']
#  on)
#
#  add_7 (Add)                    (None, 2, 2, 256)    0           ['bn4a_branch2b[0][0]',
#                                                                   'bn4a_branch1[0][0]']
#
#  activation_50 (Activation)     (None, 2, 2, 256)    0           ['add_7[0][0]']
#
#  id4b_branch2a (Conv2D)         (None, 2, 2, 256)    589824      ['activation_50[0][0]']
#
#  bn4b_branch2a (BatchNormalizat  (None, 2, 2, 256)   1024        ['id4b_branch2a[0][0]']
#  ion)
#
#  activation_51 (Activation)     (None, 2, 2, 256)    0           ['bn4b_branch2a[0][0]']
#
#  id4b_branch2b (Conv2D)         (None, 2, 2, 256)    589824      ['activation_51[0][0]']
#
#  bn4b_branch2b (BatchNormalizat  (None, 2, 2, 256)   1024        ['id4b_branch2b[0][0]']
#  ion)
#
#  add_8 (Add)                    (None, 2, 2, 256)    0           ['bn4b_branch2b[0][0]',
#                                                                   'activation_50[0][0]']
#
#  activation_52 (Activation)     (None, 2, 2, 256)    0           ['add_8[0][0]']
#
#  id4c_branch2a (Conv2D)         (None, 2, 2, 256)    589824      ['activation_52[0][0]']
#
#  bn4c_branch2a (BatchNormalizat  (None, 2, 2, 256)   1024        ['id4c_branch2a[0][0]']
#  ion)
#
#  activation_53 (Activation)     (None, 2, 2, 256)    0           ['bn4c_branch2a[0][0]']
#
#  id4c_branch2b (Conv2D)         (None, 2, 2, 256)    589824      ['activation_53[0][0]']
#
#  bn4c_branch2b (BatchNormalizat  (None, 2, 2, 256)   1024        ['id4c_branch2b[0][0]']
#  ion)
#
#  add_9 (Add)                    (None, 2, 2, 256)    0           ['bn4c_branch2b[0][0]',
#                                                                   'activation_52[0][0]']
#
#  activation_54 (Activation)     (None, 2, 2, 256)    0           ['add_9[0][0]']
#
#  id4d_branch2a (Conv2D)         (None, 2, 2, 256)    589824      ['activation_54[0][0]']
#
#  bn4d_branch2a (BatchNormalizat  (None, 2, 2, 256)   1024        ['id4d_branch2a[0][0]']
#  ion)
#
#  activation_55 (Activation)     (None, 2, 2, 256)    0           ['bn4d_branch2a[0][0]']
#
#  id4d_branch2b (Conv2D)         (None, 2, 2, 256)    589824      ['activation_55[0][0]']
#
#  bn4d_branch2b (BatchNormalizat  (None, 2, 2, 256)   1024        ['id4d_branch2b[0][0]']
#  ion)
#
#  add_10 (Add)                   (None, 2, 2, 256)    0           ['bn4d_branch2b[0][0]',
#                                                                   'activation_54[0][0]']
#
#  activation_56 (Activation)     (None, 2, 2, 256)    0           ['add_10[0][0]']
#
#  id4e_branch2a (Conv2D)         (None, 2, 2, 256)    589824      ['activation_56[0][0]']
#
#  bn4e_branch2a (BatchNormalizat  (None, 2, 2, 256)   1024        ['id4e_branch2a[0][0]']
#  ion)
#
#  activation_57 (Activation)     (None, 2, 2, 256)    0           ['bn4e_branch2a[0][0]']
#
#  id4e_branch2b (Conv2D)         (None, 2, 2, 256)    589824      ['activation_57[0][0]']
#
#  bn4e_branch2b (BatchNormalizat  (None, 2, 2, 256)   1024        ['id4e_branch2b[0][0]']
#  ion)
#
#  add_11 (Add)                   (None, 2, 2, 256)    0           ['bn4e_branch2b[0][0]',
#                                                                   'activation_56[0][0]']
#
#  activation_58 (Activation)     (None, 2, 2, 256)    0           ['add_11[0][0]']
#
#  id4f_branch2a (Conv2D)         (None, 2, 2, 256)    589824      ['activation_58[0][0]']
#
#  bn4f_branch2a (BatchNormalizat  (None, 2, 2, 256)   1024        ['id4f_branch2a[0][0]']
#  ion)
#
#  activation_59 (Activation)     (None, 2, 2, 256)    0           ['bn4f_branch2a[0][0]']
#
#  id4f_branch2b (Conv2D)         (None, 2, 2, 256)    589824      ['activation_59[0][0]']
#
#  bn4f_branch2b (BatchNormalizat  (None, 2, 2, 256)   1024        ['id4f_branch2b[0][0]']
#  ion)
#
#  add_12 (Add)                   (None, 2, 2, 256)    0           ['bn4f_branch2b[0][0]',
#                                                                   'activation_58[0][0]']
#
#  activation_60 (Activation)     (None, 2, 2, 256)    0           ['add_12[0][0]']
#
#  conv5a_branch2a (Conv2D)       (None, 1, 1, 512)    1179648     ['activation_60[0][0]']
#
#  bn5a_branch2a (BatchNormalizat  (None, 1, 1, 512)   2048        ['conv5a_branch2a[0][0]']
#  ion)
#
#  activation_61 (Activation)     (None, 1, 1, 512)    0           ['bn5a_branch2a[0][0]']
#
#  conv5a_branch2b (Conv2D)       (None, 1, 1, 512)    2359296     ['activation_61[0][0]']
#
#  conv5a_branch1 (Conv2D)        (None, 1, 1, 512)    1179648     ['activation_60[0][0]']
#
#  bn5a_branch2b (BatchNormalizat  (None, 1, 1, 512)   2048        ['conv5a_branch2b[0][0]']
#  ion)
#
#  bn5a_branch1 (BatchNormalizati  (None, 1, 1, 512)   2048        ['conv5a_branch1[0][0]']
#  on)
#
#  add_13 (Add)                   (None, 1, 1, 512)    0           ['bn5a_branch2b[0][0]',
#                                                                   'bn5a_branch1[0][0]']
#
#  activation_62 (Activation)     (None, 1, 1, 512)    0           ['add_13[0][0]']
#
#  id5b_branch2a (Conv2D)         (None, 1, 1, 512)    2359296     ['activation_62[0][0]']
#
#  bn5b_branch2a (BatchNormalizat  (None, 1, 1, 512)   2048        ['id5b_branch2a[0][0]']
#  ion)
#
#  activation_63 (Activation)     (None, 1, 1, 512)    0           ['bn5b_branch2a[0][0]']
#
#  id5b_branch2b (Conv2D)         (None, 1, 1, 512)    2359296     ['activation_63[0][0]']
#
#  bn5b_branch2b (BatchNormalizat  (None, 1, 1, 512)   2048        ['id5b_branch2b[0][0]']
#  ion)
#
#  add_14 (Add)                   (None, 1, 1, 512)    0           ['bn5b_branch2b[0][0]',
#                                                                   'activation_62[0][0]']
#
#  activation_64 (Activation)     (None, 1, 1, 512)    0           ['add_14[0][0]']
#
#  id5c_branch2a (Conv2D)         (None, 1, 1, 512)    2359296     ['activation_64[0][0]']
#
#  bn5c_branch2a (BatchNormalizat  (None, 1, 1, 512)   2048        ['id5c_branch2a[0][0]']
#  ion)
#
#  activation_65 (Activation)     (None, 1, 1, 512)    0           ['bn5c_branch2a[0][0]']
#
#  id5c_branch2b (Conv2D)         (None, 1, 1, 512)    2359296     ['activation_65[0][0]']
#
#  bn5c_branch2b (BatchNormalizat  (None, 1, 1, 512)   2048        ['id5c_branch2b[0][0]']
#  ion)
#
#  add_15 (Add)                   (None, 1, 1, 512)    0           ['bn5c_branch2b[0][0]',
#                                                                   'activation_64[0][0]']
#
#  activation_66 (Activation)     (None, 1, 1, 512)    0           ['add_15[0][0]']
#
#  global_average_pooling2d_1 (Gl  (None, 512)         0           ['activation_66[0][0]']
#  obalAveragePooling2D)
#
#  fc1000 (Dense)                 (None, 10)           5130        ['global_average_pooling2d_1[0][0
#                                                                  ]']
#
#  activation_67 (Activation)     (None, 10)           0           ['fc1000[0][0]']
#
# ==================================================================================================
# Total params: 22,683,082
# Trainable params: 22,666,058
# Non-trainable params: 17,024
# __________________________________________________________________________________________________

# %%
plot_model(resnet_34, show_shapes=True)

# %%
resnet_34.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

history_resnet34 = resnet_34.fit(x_train, y_train, epochs=100)
# Out:
# Epoch 1/100
# 1563/1563 [==============================] - 48s 28ms/step - loss: 2.1805 - accuracy: 0.4797
# Epoch 2/100
# 1563/1563 [==============================] - 44s 28ms/step - loss: 1.3765 - accuracy: 0.6339
# Epoch 3/100
# 1563/1563 [==============================] - 44s 28ms/step - loss: 1.1709 - accuracy: 0.6920
# Epoch 4/100
# 1563/1563 [==============================] - 44s 28ms/step - loss: 1.0750 - accuracy: 0.7276
# Epoch 5/100
# 1563/1563 [==============================] - 44s 28ms/step - loss: 1.0101 - accuracy: 0.7568
# Epoch 6/100
# 1563/1563 [==============================] - 44s 28ms/step - loss: 0.9561 - accuracy: 0.7778
# Epoch 7/100
# 1563/1563 [==============================] - 44s 28ms/step - loss: 0.9203 - accuracy: 0.7947
# Epoch 8/100
# 1563/1563 [==============================] - 44s 28ms/step - loss: 0.8691 - accuracy: 0.8147
# Epoch 9/100
# 1563/1563 [==============================] - 44s 28ms/step - loss: 0.8289 - accuracy: 0.8326
# Epoch 10/100
# 1563/1563 [==============================] - 44s 28ms/step - loss: 0.7910 - accuracy: 0.8435
# Epoch 11/100
# 1563/1563 [==============================] - 44s 28ms/step - loss: 0.7643 - accuracy: 0.8583
# Epoch 12/100
# 1563/1563 [==============================] - 44s 28ms/step - loss: 0.7324 - accuracy: 0.8674
# Epoch 13/100
# 1563/1563 [==============================] - 44s 28ms/step - loss: 0.7023 - accuracy: 0.8809
# Epoch 14/100
# 1563/1563 [==============================] - 44s 28ms/step - loss: 0.6865 - accuracy: 0.8893
# Epoch 15/100
# 1563/1563 [==============================] - 45s 29ms/step - loss: 0.6688 - accuracy: 0.8987
# Epoch 16/100
# 1563/1563 [==============================] - 45s 29ms/step - loss: 0.6630 - accuracy: 0.9037
# Epoch 17/100
# 1563/1563 [==============================] - 44s 28ms/step - loss: 0.6442 - accuracy: 0.9105
# Epoch 18/100
# 1563/1563 [==============================] - 44s 28ms/step - loss: 0.6376 - accuracy: 0.9137
# Epoch 19/100
# 1563/1563 [==============================] - 45s 29ms/step - loss: 0.6330 - accuracy: 0.9185
# Epoch 20/100
# 1563/1563 [==============================] - 44s 28ms/step - loss: 0.6249 - accuracy: 0.9216
# Epoch 21/100
# 1563/1563 [==============================] - 44s 28ms/step - loss: 0.6209 - accuracy: 0.9234
# Epoch 22/100
# 1563/1563 [==============================] - 45s 29ms/step - loss: 0.6222 - accuracy: 0.9236
# Epoch 23/100
# 1563/1563 [==============================] - 45s 29ms/step - loss: 0.6074 - accuracy: 0.9282
# Epoch 24/100
# 1563/1563 [==============================] - 45s 29ms/step - loss: 0.6130 - accuracy: 0.9287
# Epoch 25/100
# 1563/1563 [==============================] - 45s 29ms/step - loss: 0.6016 - accuracy: 0.9342
# Epoch 26/100
# 1563/1563 [==============================] - 44s 28ms/step - loss: 0.5988 - accuracy: 0.9328
# Epoch 27/100
# 1563/1563 [==============================] - 45s 29ms/step - loss: 0.5890 - accuracy: 0.9357
# Epoch 28/100
# 1563/1563 [==============================] - 45s 29ms/step - loss: 0.5903 - accuracy: 0.9350
# Epoch 29/100
# 1563/1563 [==============================] - 44s 28ms/step - loss: 0.5898 - accuracy: 0.9373
# Epoch 30/100
# 1563/1563 [==============================] - 44s 28ms/step - loss: 0.5858 - accuracy: 0.9364
# Epoch 31/100
# 1563/1563 [==============================] - 44s 28ms/step - loss: 0.5811 - accuracy: 0.9389
# Epoch 32/100
# 1563/1563 [==============================] - 44s 28ms/step - loss: 0.5740 - accuracy: 0.9411
# Epoch 33/100
# 1563/1563 [==============================] - 44s 28ms/step - loss: 0.5779 - accuracy: 0.9401
# Epoch 34/100
# 1563/1563 [==============================] - 44s 28ms/step - loss: 0.5725 - accuracy: 0.9425
# Epoch 35/100
# 1563/1563 [==============================] - 45s 29ms/step - loss: 0.5736 - accuracy: 0.9405
# Epoch 36/100
# 1563/1563 [==============================] - 44s 28ms/step - loss: 0.5696 - accuracy: 0.9418
# Epoch 37/100
# 1563/1563 [==============================] - 45s 29ms/step - loss: 0.5663 - accuracy: 0.9434
# Epoch 38/100
# 1563/1563 [==============================] - 45s 29ms/step - loss: 0.5677 - accuracy: 0.9418
# Epoch 39/100
# 1563/1563 [==============================] - 45s 29ms/step - loss: 0.5605 - accuracy: 0.9457
# Epoch 40/100
# 1563/1563 [==============================] - 44s 28ms/step - loss: 0.5593 - accuracy: 0.9440
# Epoch 41/100
# 1563/1563 [==============================] - 44s 28ms/step - loss: 0.5519 - accuracy: 0.9467
# Epoch 42/100
# 1563/1563 [==============================] - 44s 28ms/step - loss: 0.5614 - accuracy: 0.9431
# Epoch 43/100
# 1563/1563 [==============================] - 44s 28ms/step - loss: 0.5467 - accuracy: 0.9479
# Epoch 44/100
# 1563/1563 [==============================] - 44s 28ms/step - loss: 0.5563 - accuracy: 0.9454
# Epoch 45/100
# 1563/1563 [==============================] - 44s 28ms/step - loss: 0.5529 - accuracy: 0.9475
# Epoch 46/100
# 1563/1563 [==============================] - 44s 28ms/step - loss: 0.5454 - accuracy: 0.9477
# Epoch 47/100
# 1563/1563 [==============================] - 45s 29ms/step - loss: 0.5465 - accuracy: 0.9471
# Epoch 48/100
# 1563/1563 [==============================] - 45s 29ms/step - loss: 0.5424 - accuracy: 0.9477
# Epoch 49/100
# 1563/1563 [==============================] - 45s 29ms/step - loss: 0.5432 - accuracy: 0.9477
# Epoch 50/100
# 1563/1563 [==============================] - 44s 28ms/step - loss: 0.5479 - accuracy: 0.9465
# Epoch 51/100
# 1563/1563 [==============================] - 45s 29ms/step - loss: 0.5425 - accuracy: 0.9484
# Epoch 52/100
# 1563/1563 [==============================] - 45s 29ms/step - loss: 0.5420 - accuracy: 0.9476
# Epoch 53/100
# 1563/1563 [==============================] - 44s 28ms/step - loss: 0.5360 - accuracy: 0.9488
# Epoch 54/100
# 1563/1563 [==============================] - 44s 28ms/step - loss: 0.5309 - accuracy: 0.9508
# Epoch 55/100
# 1563/1563 [==============================] - 44s 28ms/step - loss: 0.5379 - accuracy: 0.9480
# Epoch 56/100
# 1563/1563 [==============================] - 44s 28ms/step - loss: 0.5380 - accuracy: 0.9494
# Epoch 57/100
# 1563/1563 [==============================] - 44s 28ms/step - loss: 0.5263 - accuracy: 0.9503
# Epoch 58/100
# 1563/1563 [==============================] - 44s 28ms/step - loss: 0.5329 - accuracy: 0.9487
# Epoch 59/100
# 1563/1563 [==============================] - 44s 28ms/step - loss: 0.5257 - accuracy: 0.9512
# Epoch 60/100
# 1563/1563 [==============================] - 45s 28ms/step - loss: 0.5295 - accuracy: 0.9506
# Epoch 61/100
# 1563/1563 [==============================] - 44s 28ms/step - loss: 0.5176 - accuracy: 0.9537
# Epoch 62/100
# 1563/1563 [==============================] - 44s 28ms/step - loss: 0.5276 - accuracy: 0.9496
# Epoch 63/100
# 1563/1563 [==============================] - 44s 28ms/step - loss: 0.5223 - accuracy: 0.9517
# Epoch 64/100
# 1563/1563 [==============================] - 44s 28ms/step - loss: 0.5246 - accuracy: 0.9514
# Epoch 65/100
# 1563/1563 [==============================] - 44s 28ms/step - loss: 0.5177 - accuracy: 0.9538
# Epoch 66/100
# 1563/1563 [==============================] - 44s 28ms/step - loss: 0.5208 - accuracy: 0.9524
# Epoch 67/100
# 1563/1563 [==============================] - 45s 29ms/step - loss: 0.5178 - accuracy: 0.9525
# Epoch 68/100
# 1563/1563 [==============================] - 45s 29ms/step - loss: 0.5151 - accuracy: 0.9525
# Epoch 69/100
# 1563/1563 [==============================] - 44s 28ms/step - loss: 0.5158 - accuracy: 0.9526
# Epoch 70/100
# 1563/1563 [==============================] - 44s 28ms/step - loss: 0.5169 - accuracy: 0.9516
# Epoch 71/100
# 1563/1563 [==============================] - 44s 28ms/step - loss: 0.5162 - accuracy: 0.9508
# Epoch 72/100
# 1563/1563 [==============================] - 44s 28ms/step - loss: 0.5112 - accuracy: 0.9524
# Epoch 73/100
# 1563/1563 [==============================] - 44s 28ms/step - loss: 0.5145 - accuracy: 0.9524
# Epoch 74/100
# 1563/1563 [==============================] - 44s 28ms/step - loss: 0.5101 - accuracy: 0.9536
# Epoch 75/100
# 1563/1563 [==============================] - 44s 28ms/step - loss: 0.5053 - accuracy: 0.9546
# Epoch 76/100
# 1563/1563 [==============================] - 44s 28ms/step - loss: 0.5098 - accuracy: 0.9525
# Epoch 77/100
# 1563/1563 [==============================] - 44s 28ms/step - loss: 0.5097 - accuracy: 0.9521
# Epoch 78/100
# 1563/1563 [==============================] - 44s 28ms/step - loss: 0.5092 - accuracy: 0.9516
# Epoch 79/100
# 1563/1563 [==============================] - 44s 28ms/step - loss: 0.5067 - accuracy: 0.9532
# Epoch 80/100
# 1563/1563 [==============================] - 44s 28ms/step - loss: 0.4992 - accuracy: 0.9545
# Epoch 81/100
# 1563/1563 [==============================] - 44s 28ms/step - loss: 0.5030 - accuracy: 0.9540
# Epoch 82/100
# 1563/1563 [==============================] - 44s 28ms/step - loss: 0.5026 - accuracy: 0.9531
# Epoch 83/100
# 1563/1563 [==============================] - 44s 28ms/step - loss: 0.4914 - accuracy: 0.9569
# Epoch 84/100
# 1563/1563 [==============================] - 44s 28ms/step - loss: 0.5063 - accuracy: 0.9523
# Epoch 85/100
# 1563/1563 [==============================] - 44s 28ms/step - loss: 0.4969 - accuracy: 0.9542
# Epoch 86/100
# 1563/1563 [==============================] - 44s 28ms/step - loss: 0.4972 - accuracy: 0.9554
# Epoch 87/100
# 1563/1563 [==============================] - 44s 28ms/step - loss: 0.4982 - accuracy: 0.9537
# Epoch 88/100
# 1563/1563 [==============================] - 44s 28ms/step - loss: 0.4978 - accuracy: 0.9551
# Epoch 89/100
# 1563/1563 [==============================] - 44s 28ms/step - loss: 0.4980 - accuracy: 0.9530
# Epoch 90/100
# 1563/1563 [==============================] - 44s 28ms/step - loss: 0.4911 - accuracy: 0.9563
# Epoch 91/100
# 1563/1563 [==============================] - 44s 28ms/step - loss: 0.4940 - accuracy: 0.9547
# Epoch 92/100
# 1563/1563 [==============================] - 44s 28ms/step - loss: 0.4979 - accuracy: 0.9540
# Epoch 93/100
# 1563/1563 [==============================] - 45s 28ms/step - loss: 0.4863 - accuracy: 0.9575
# Epoch 94/100
# 1563/1563 [==============================] - 44s 28ms/step - loss: 0.4887 - accuracy: 0.9559
# Epoch 95/100
# 1563/1563 [==============================] - 44s 28ms/step - loss: 0.4907 - accuracy: 0.9542
# Epoch 96/100
# 1563/1563 [==============================] - 44s 28ms/step - loss: 0.4860 - accuracy: 0.9557
# Epoch 97/100
# 1563/1563 [==============================] - 44s 28ms/step - loss: 0.4855 - accuracy: 0.9559
# Epoch 98/100
# 1563/1563 [==============================] - 45s 28ms/step - loss: 0.4867 - accuracy: 0.9563
# Epoch 99/100
# 1563/1563 [==============================] - 44s 28ms/step - loss: 0.4886 - accuracy: 0.9551
# Epoch 100/100
# 1563/1563 [==============================] - 44s 28ms/step - loss: 0.4847 - accuracy: 0.9566

# %%
import matplotlib.pyplot as plt

plt.plot(history_resnet34.history['loss'], 'r')
plt.plot(history_plain34.history['loss'], 'b')
plt.title('Model training loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['ResNet34','Plain34'], loc='upper left')
plt.show()

# %%
plt.plot(history_resnet34.history['accuracy'], 'r')
plt.plot(history_plain34.history['accuracy'], 'b')
plt.title('Model validation accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['ResNet34', 'Plain34'], loc='upper left')
plt.show()
