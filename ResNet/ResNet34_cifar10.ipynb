# %%
import tensorflow as tf 
from tensorflow.keras import backend, regularizers, initializers, models
from tensorflow.keras import layers
from tensorflow import keras
from tensorflow.keras.utils import plot_model


def _gen_l2_regularizer(use_l2_regularizer=True, l2_weight_decay=1e-4):
  return regularizers.l2(l2_weight_decay) if use_l2_regularizer else None

# %%
cifar10 = keras.datasets.cifar10

(x_train, y_train), (x_test, y_test) = cifar10.load_data()
x_train, x_test = x_train / 255.0, x_test / 255.0

print("x_train:", len(x_train), "x_test:", len(x_test))
# Out:
# x_train: 50000 x_test: 10000

# %%
def plain_conv_block(input_tensor,
               filters,
               stage,
               block,
               strides=(2,2),
               use_l2_regularizer=True,
               bn_decay=0.9,
               bn_epsilon=1e-5):
  

  if backend.image_data_format() == 'channels_last':
    bn_axis=3
  else:
    bn_axis=1

  conv_name='conv'+str(stage)+block+'_branch'
  bn_name='bn'+str(stage)+block+'_branch'

  x = layers.Conv2D(filters,(3,3),strides=strides,padding='same',use_bias=False,kernel_initializer='he_normal',
                    kernel_regularizer=_gen_l2_regularizer(use_l2_regularizer),
                    name = conv_name+'2a')(input_tensor)

  x = layers.BatchNormalization(axis=bn_axis, momentum=bn_decay, epsilon=bn_epsilon,name=bn_name+'2a')(x)

  x = layers.Activation('relu')(x)
  
  x = layers.Conv2D(filters,(3,3),use_bias=False,padding='same',kernel_initializer='he_normal',
                    kernel_regularizer=_gen_l2_regularizer(use_l2_regularizer),
                    name = conv_name+'2b')(x)

  x = layers.BatchNormalization(axis=bn_axis, momentum=bn_decay, epsilon=bn_epsilon,name=bn_name+'2b')(x)

  x = layers.Activation('relu')(x)

  return x

# %%
def plain_identity_block(input_tensor,
                   filters,
                   stage,
                   block,
                   use_l2_regularizer=True,
                   bn_decay=0.9,
                   bn_epsilon=1e-5):
  
  if backend.image_data_format() == 'channels_last':
    bn_axis=3
  else:
    bn_axis=1

  id_name='id'+str(stage)+block+'_branch'
  bn_name='bn'+str(stage)+block+'_branch'

  x = layers.Conv2D(filters,(3,3),padding='same',use_bias=False,kernel_initializer='he_normal',
                    kernel_regularizer=_gen_l2_regularizer(use_l2_regularizer),
                    name = id_name+'2a')(input_tensor)

  x = layers.BatchNormalization(axis=bn_axis,momentum=bn_decay, epsilon=bn_epsilon,name=bn_name+'2a')(x)

  x = layers.Activation('relu')(x)

  x = layers.Conv2D(filters,(3,3),padding='same',use_bias=False,kernel_initializer='he_normal',
                    kernel_regularizer=_gen_l2_regularizer(use_l2_regularizer),
                    name = id_name+'2b')(x)

  x = layers.BatchNormalization(axis=bn_axis,momentum=bn_decay, epsilon=bn_epsilon,name=bn_name+'2b')(x)
  
  x = layers.Activation('relu')(x)

  return x

# %%
def plain34(num_classes,
             batch_size=None,
             use_l2_regularizer=True,
             rescale_inputs=False,
             bn_decay=0.9,
             bn_epsilon=1e-5):
 

  input_shape = (32, 32, 3) 
  img_input = layers.Input(shape=input_shape, batch_size=batch_size)
  if rescale_inputs:
  
    x = layers.Lambda(
        lambda x: x * 255.0 - backend.constant(
            imagenet_preprocessing.CHANNEL_MEANS,
            shape=[1, 1, 3],
            dtype=x.dtype),
        name='rescale')(
            img_input)
  else:
    x = img_input

  if backend.image_data_format() == 'channels_first':
    x = layers.Permute((3, 1, 2))(x)
    bn_axis = 1
  else:  # channels_last
    bn_axis = 3

  block_config = dict(
      use_l2_regularizer=use_l2_regularizer,
      bn_decay=bn_decay,
      bn_epsilon=bn_epsilon)
  x = layers.ZeroPadding2D(padding=(3, 3), name='conv1_pad')(x)
  x = layers.Conv2D(
      64, (7, 7),
      strides=(2, 2),
      padding='valid',
      use_bias=False,
      kernel_initializer='he_normal',
      kernel_regularizer=_gen_l2_regularizer(use_l2_regularizer),
      name='conv1')(
          x)
  x = layers.BatchNormalization(
      axis=bn_axis,
      momentum=bn_decay,
      epsilon=bn_epsilon,
      name='bn_conv1')(
          x)
  x = layers.Activation('relu')(x)
  x = layers.MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)

  x = plain_identity_block(x, 64, stage=2, block='a', **block_config)
  x = plain_identity_block(x, 64, stage=2, block='b', **block_config)
  x = plain_identity_block(x, 64, stage=2, block='c', **block_config)

  x = plain_conv_block(x,128, stage=3, block='a', **block_config)
  x = plain_identity_block(x, 128, stage=3, block='b', **block_config)
  x = plain_identity_block(x, 128, stage=3, block='c', **block_config)
  x = plain_identity_block(x, 128, stage=3, block='d', **block_config)

  x = plain_conv_block(x,256, stage=4, block='a', **block_config)
  x = plain_identity_block(x,256, stage=4, block='b', **block_config)
  x = plain_identity_block(x, 256, stage=4, block='c', **block_config)
  x = plain_identity_block(x, 256, stage=4, block='d', **block_config)
  x = plain_identity_block(x, 256, stage=4, block='e', **block_config)
  x = plain_identity_block(x, 256, stage=4, block='f', **block_config)

  x = plain_conv_block(x,512, stage=5, block='a', **block_config)
  x = plain_identity_block(x, 512, stage=5, block='b', **block_config)
  x = plain_identity_block(x, 512, stage=5, block='c', **block_config)

  x = layers.GlobalAveragePooling2D()(x)
  x = layers.Dense(
      num_classes,
      kernel_initializer=initializers.RandomNormal(stddev=0.01),
      kernel_regularizer=_gen_l2_regularizer(use_l2_regularizer),
      bias_regularizer=_gen_l2_regularizer(use_l2_regularizer),
      name='fc1000')(x)

  x = layers.Activation('softmax', dtype='float32')(x)

  return models.Model(img_input, x, name='plain34')

# %%
plain_34 = plain34(num_classes=100)
plain_34.summary()
# Out:
# Model: "plain34"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_6 (InputLayer)        [(None, 32, 32, 3)]       0
#
#  conv1_pad (ZeroPadding2D)   (None, 38, 38, 3)         0
#
#  conv1 (Conv2D)              (None, 16, 16, 64)        9408
#
#  bn_conv1 (BatchNormalizatio  (None, 16, 16, 64)       256
#  n)
#
#  activation_170 (Activation)  (None, 16, 16, 64)       0
#
#  max_pooling2d_5 (MaxPooling  (None, 8, 8, 64)         0
#  2D)
#
#  id2a_branch2a (Conv2D)      (None, 8, 8, 64)          36864
#
#  bn2a_branch2a (BatchNormali  (None, 8, 8, 64)         256
#  zation)
#
#  activation_171 (Activation)  (None, 8, 8, 64)         0
#
#  id2a_branch2b (Conv2D)      (None, 8, 8, 64)          36864
#
#  bn2a_branch2b (BatchNormali  (None, 8, 8, 64)         256
#  zation)
#
#  activation_172 (Activation)  (None, 8, 8, 64)         0
#
#  id2b_branch2a (Conv2D)      (None, 8, 8, 64)          36864
#
#  bn2b_branch2a (BatchNormali  (None, 8, 8, 64)         256
#  zation)
#
#  activation_173 (Activation)  (None, 8, 8, 64)         0
#
#  id2b_branch2b (Conv2D)      (None, 8, 8, 64)          36864
#
#  bn2b_branch2b (BatchNormali  (None, 8, 8, 64)         256
#  zation)
#
#  activation_174 (Activation)  (None, 8, 8, 64)         0
#
#  id2c_branch2a (Conv2D)      (None, 8, 8, 64)          36864
#
#  bn2c_branch2a (BatchNormali  (None, 8, 8, 64)         256
#  zation)
#
#  activation_175 (Activation)  (None, 8, 8, 64)         0
#
#  id2c_branch2b (Conv2D)      (None, 8, 8, 64)          36864
#
#  bn2c_branch2b (BatchNormali  (None, 8, 8, 64)         256
#  zation)
#
#  activation_176 (Activation)  (None, 8, 8, 64)         0
#
#  conv3a_branch2a (Conv2D)    (None, 4, 4, 128)         73728
#
#  bn3a_branch2a (BatchNormali  (None, 4, 4, 128)        512
#  zation)
#
#  activation_177 (Activation)  (None, 4, 4, 128)        0
#
#  conv3a_branch2b (Conv2D)    (None, 4, 4, 128)         147456
#
#  bn3a_branch2b (BatchNormali  (None, 4, 4, 128)        512
#  zation)
#
#  activation_178 (Activation)  (None, 4, 4, 128)        0
#
#  id3b_branch2a (Conv2D)      (None, 4, 4, 128)         147456
#
#  bn3b_branch2a (BatchNormali  (None, 4, 4, 128)        512
#  zation)
#
#  activation_179 (Activation)  (None, 4, 4, 128)        0
#
#  id3b_branch2b (Conv2D)      (None, 4, 4, 128)         147456
#
#  bn3b_branch2b (BatchNormali  (None, 4, 4, 128)        512
#  zation)
#
#  activation_180 (Activation)  (None, 4, 4, 128)        0
#
#  id3c_branch2a (Conv2D)      (None, 4, 4, 128)         147456
#
#  bn3c_branch2a (BatchNormali  (None, 4, 4, 128)        512
#  zation)
#
#  activation_181 (Activation)  (None, 4, 4, 128)        0
#
#  id3c_branch2b (Conv2D)      (None, 4, 4, 128)         147456
#
#  bn3c_branch2b (BatchNormali  (None, 4, 4, 128)        512
#  zation)
#
#  activation_182 (Activation)  (None, 4, 4, 128)        0
#
#  id3d_branch2a (Conv2D)      (None, 4, 4, 128)         147456
#
#  bn3d_branch2a (BatchNormali  (None, 4, 4, 128)        512
#  zation)
#
#  activation_183 (Activation)  (None, 4, 4, 128)        0
#
#  id3d_branch2b (Conv2D)      (None, 4, 4, 128)         147456
#
#  bn3d_branch2b (BatchNormali  (None, 4, 4, 128)        512
#  zation)
#
#  activation_184 (Activation)  (None, 4, 4, 128)        0
#
#  conv4a_branch2a (Conv2D)    (None, 2, 2, 256)         294912
#
#  bn4a_branch2a (BatchNormali  (None, 2, 2, 256)        1024
#  zation)
#
#  activation_185 (Activation)  (None, 2, 2, 256)        0
#
#  conv4a_branch2b (Conv2D)    (None, 2, 2, 256)         589824
#
#  bn4a_branch2b (BatchNormali  (None, 2, 2, 256)        1024
#  zation)
#
#  activation_186 (Activation)  (None, 2, 2, 256)        0
#
#  id4b_branch2a (Conv2D)      (None, 2, 2, 256)         589824
#
#  bn4b_branch2a (BatchNormali  (None, 2, 2, 256)        1024
#  zation)
#
#  activation_187 (Activation)  (None, 2, 2, 256)        0
#
#  id4b_branch2b (Conv2D)      (None, 2, 2, 256)         589824
#
#  bn4b_branch2b (BatchNormali  (None, 2, 2, 256)        1024
#  zation)
#
#  activation_188 (Activation)  (None, 2, 2, 256)        0
#
#  id4c_branch2a (Conv2D)      (None, 2, 2, 256)         589824
#
#  bn4c_branch2a (BatchNormali  (None, 2, 2, 256)        1024
#  zation)
#
#  activation_189 (Activation)  (None, 2, 2, 256)        0
#
#  id4c_branch2b (Conv2D)      (None, 2, 2, 256)         589824
#
#  bn4c_branch2b (BatchNormali  (None, 2, 2, 256)        1024
#  zation)
#
#  activation_190 (Activation)  (None, 2, 2, 256)        0
#
#  id4d_branch2a (Conv2D)      (None, 2, 2, 256)         589824
#
#  bn4d_branch2a (BatchNormali  (None, 2, 2, 256)        1024
#  zation)
#
#  activation_191 (Activation)  (None, 2, 2, 256)        0
#
#  id4d_branch2b (Conv2D)      (None, 2, 2, 256)         589824
#
#  bn4d_branch2b (BatchNormali  (None, 2, 2, 256)        1024
#  zation)
#
#  activation_192 (Activation)  (None, 2, 2, 256)        0
#
#  id4e_branch2a (Conv2D)      (None, 2, 2, 256)         589824
#
#  bn4e_branch2a (BatchNormali  (None, 2, 2, 256)        1024
#  zation)
#
#  activation_193 (Activation)  (None, 2, 2, 256)        0
#
#  id4e_branch2b (Conv2D)      (None, 2, 2, 256)         589824
#
#  bn4e_branch2b (BatchNormali  (None, 2, 2, 256)        1024
#  zation)
#
#  activation_194 (Activation)  (None, 2, 2, 256)        0
#
#  id4f_branch2a (Conv2D)      (None, 2, 2, 256)         589824
#
#  bn4f_branch2a (BatchNormali  (None, 2, 2, 256)        1024
#  zation)
#
#  activation_195 (Activation)  (None, 2, 2, 256)        0
#
#  id4f_branch2b (Conv2D)      (None, 2, 2, 256)         589824
#
#  bn4f_branch2b (BatchNormali  (None, 2, 2, 256)        1024
#  zation)
#
#  activation_196 (Activation)  (None, 2, 2, 256)        0
#
#  conv5a_branch2a (Conv2D)    (None, 1, 1, 512)         1179648
#
#  bn5a_branch2a (BatchNormali  (None, 1, 1, 512)        2048
#  zation)
#
#  activation_197 (Activation)  (None, 1, 1, 512)        0
#
#  conv5a_branch2b (Conv2D)    (None, 1, 1, 512)         2359296
#
#  bn5a_branch2b (BatchNormali  (None, 1, 1, 512)        2048
#  zation)
#
#  activation_198 (Activation)  (None, 1, 1, 512)        0
#
#  id5b_branch2a (Conv2D)      (None, 1, 1, 512)         2359296
#
#  bn5b_branch2a (BatchNormali  (None, 1, 1, 512)        2048
#  zation)
#
#  activation_199 (Activation)  (None, 1, 1, 512)        0
#
#  id5b_branch2b (Conv2D)      (None, 1, 1, 512)         2359296
#
#  bn5b_branch2b (BatchNormali  (None, 1, 1, 512)        2048
#  zation)
#
#  activation_200 (Activation)  (None, 1, 1, 512)        0
#
#  id5c_branch2a (Conv2D)      (None, 1, 1, 512)         2359296
#
#  bn5c_branch2a (BatchNormali  (None, 1, 1, 512)        2048
#  zation)
#
#  activation_201 (Activation)  (None, 1, 1, 512)        0
#
#  id5c_branch2b (Conv2D)      (None, 1, 1, 512)         2359296
#
#  bn5c_branch2b (BatchNormali  (None, 1, 1, 512)        2048
#  zation)
#
#  activation_202 (Activation)  (None, 1, 1, 512)        0
#
#  global_average_pooling2d_5   (None, 512)              0
#  (GlobalAveragePooling2D)
#
#  fc1000 (Dense)              (None, 100)               51300
#
#  activation_203 (Activation)  (None, 100)              0
#
# =================================================================
# Total params: 21,177,380
# Trainable params: 21,162,148
# Non-trainable params: 15,232
# _________________________________________________________________

# %%
plot_model(plain_34,show_shapes=True)

# %%
plain_34.compile(optimizer=keras.optimizers.SGD(lr=0.1, momentum=0.9, decay=0.1),
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

history_plain34 = plain_34.fit(x_train, y_train, epochs=100)
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/gradient_descent.py:102: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(SGD, self).__init__(name, **kwargs)
# Epoch 1/100
# 1563/1563 [==============================] - 49s 29ms/step - loss: 8.4276 - accuracy: 0.1209
# Epoch 2/100
# 1563/1563 [==============================] - 44s 28ms/step - loss: 8.3894 - accuracy: 0.1274
# Epoch 3/100
# 1563/1563 [==============================] - 44s 28ms/step - loss: 8.3672 - accuracy: 0.1321
# Epoch 4/100
# 1563/1563 [==============================] - 44s 28ms/step - loss: 8.3553 - accuracy: 0.1328
# Epoch 5/100
# 1563/1563 [==============================] - 43s 28ms/step - loss: 8.3469 - accuracy: 0.1364
# Epoch 6/100
# 1563/1563 [==============================] - 42s 27ms/step - loss: 8.3435 - accuracy: 0.1321
# Epoch 7/100
# 1563/1563 [==============================] - 44s 28ms/step - loss: 8.3383 - accuracy: 0.1339
# Epoch 8/100
# 1563/1563 [==============================] - 44s 28ms/step - loss: 8.3321 - accuracy: 0.1348
# Epoch 9/100
# 1563/1563 [==============================] - 44s 28ms/step - loss: 8.3260 - accuracy: 0.1366
# Epoch 10/100
# 1563/1563 [==============================] - 44s 28ms/step - loss: 8.3226 - accuracy: 0.1366
# Epoch 11/100
# 1563/1563 [==============================] - 44s 28ms/step - loss: 8.3209 - accuracy: 0.1350
# Epoch 12/100
# 1563/1563 [==============================] - 45s 28ms/step - loss: 8.3162 - accuracy: 0.1361
# Epoch 13/100
# 1563/1563 [==============================] - 45s 28ms/step - loss: 8.3157 - accuracy: 0.1345
# Epoch 14/100
# 1563/1563 [==============================] - 43s 28ms/step - loss: 8.3118 - accuracy: 0.1393
# Epoch 15/100
# 1563/1563 [==============================] - 43s 27ms/step - loss: 8.3081 - accuracy: 0.1398
# Epoch 16/100
# 1563/1563 [==============================] - 44s 28ms/step - loss: 8.3076 - accuracy: 0.1371
# Epoch 17/100
# 1563/1563 [==============================] - 44s 28ms/step - loss: 8.3041 - accuracy: 0.1370
# Epoch 18/100
# 1563/1563 [==============================] - 44s 28ms/step - loss: 8.3017 - accuracy: 0.1402
# Epoch 19/100
# 1563/1563 [==============================] - 44s 28ms/step - loss: 8.3000 - accuracy: 0.1398
# Epoch 20/100
# 1563/1563 [==============================] - 44s 28ms/step - loss: 8.2991 - accuracy: 0.1388
# Epoch 21/100
# 1563/1563 [==============================] - 44s 28ms/step - loss: 8.2984 - accuracy: 0.1395
# Epoch 22/100
# 1563/1563 [==============================] - 43s 27ms/step - loss: 8.2940 - accuracy: 0.1400
# Epoch 23/100
# 1563/1563 [==============================] - 43s 27ms/step - loss: 8.2926 - accuracy: 0.1404
# Epoch 24/100
# 1563/1563 [==============================] - 43s 28ms/step - loss: 8.2902 - accuracy: 0.1413
# Epoch 25/100
# 1563/1563 [==============================] - 45s 29ms/step - loss: 8.2895 - accuracy: 0.1395
# Epoch 26/100
# 1563/1563 [==============================] - 45s 29ms/step - loss: 8.2901 - accuracy: 0.1382
# Epoch 27/100
# 1563/1563 [==============================] - 44s 28ms/step - loss: 8.2853 - accuracy: 0.1418
# Epoch 28/100
# 1563/1563 [==============================] - 44s 28ms/step - loss: 8.2898 - accuracy: 0.1380
# Epoch 29/100
# 1563/1563 [==============================] - 45s 29ms/step - loss: 8.2867 - accuracy: 0.1404
# Epoch 30/100
# 1563/1563 [==============================] - 44s 28ms/step - loss: 8.2850 - accuracy: 0.1388
# Epoch 31/100
# 1563/1563 [==============================] - 44s 28ms/step - loss: 8.2814 - accuracy: 0.1414
# Epoch 32/100
# 1563/1563 [==============================] - 44s 28ms/step - loss: 8.2826 - accuracy: 0.1402
# Epoch 33/100
# 1563/1563 [==============================] - 43s 27ms/step - loss: 8.2826 - accuracy: 0.1409
# Epoch 34/100
# 1563/1563 [==============================] - 43s 27ms/step - loss: 8.2779 - accuracy: 0.1421
# Epoch 35/100
# 1563/1563 [==============================] - 43s 27ms/step - loss: 8.2790 - accuracy: 0.1416
# Epoch 36/100
# 1563/1563 [==============================] - 43s 27ms/step - loss: 8.2817 - accuracy: 0.1384
# Epoch 37/100
# 1563/1563 [==============================] - 43s 27ms/step - loss: 8.2798 - accuracy: 0.1412
# Epoch 38/100
# 1563/1563 [==============================] - 43s 27ms/step - loss: 8.2785 - accuracy: 0.1418
# Epoch 39/100
# 1563/1563 [==============================] - 43s 27ms/step - loss: 8.2781 - accuracy: 0.1392
# Epoch 40/100
# 1563/1563 [==============================] - 43s 27ms/step - loss: 8.2788 - accuracy: 0.1409
# Epoch 41/100
# 1563/1563 [==============================] - 43s 28ms/step - loss: 8.2752 - accuracy: 0.1401
# Epoch 42/100
# 1563/1563 [==============================] - 43s 28ms/step - loss: 8.2782 - accuracy: 0.1392
# Epoch 43/100
# 1563/1563 [==============================] - 43s 27ms/step - loss: 8.2736 - accuracy: 0.1428
# Epoch 44/100
# 1563/1563 [==============================] - 43s 28ms/step - loss: 8.2730 - accuracy: 0.1415
# Epoch 45/100
# 1563/1563 [==============================] - 45s 28ms/step - loss: 8.2740 - accuracy: 0.1397
# Epoch 46/100
# 1563/1563 [==============================] - 45s 28ms/step - loss: 8.2717 - accuracy: 0.1441
# Epoch 47/100
# 1563/1563 [==============================] - 44s 28ms/step - loss: 8.2707 - accuracy: 0.1432
# Epoch 48/100
# 1563/1563 [==============================] - 45s 29ms/step - loss: 8.2686 - accuracy: 0.1457
# Epoch 49/100
# 1563/1563 [==============================] - 44s 28ms/step - loss: 8.2691 - accuracy: 0.1444
# Epoch 50/100
# 1563/1563 [==============================] - 44s 28ms/step - loss: 8.2693 - accuracy: 0.1454
# Epoch 51/100
# 1563/1563 [==============================] - 44s 28ms/step - loss: 8.2691 - accuracy: 0.1453
# Epoch 52/100
# 1563/1563 [==============================] - 44s 28ms/step - loss: 8.2686 - accuracy: 0.1438
# Epoch 53/100
# 1563/1563 [==============================] - 44s 28ms/step - loss: 8.2667 - accuracy: 0.1436
# Epoch 54/100
# 1563/1563 [==============================] - 44s 28ms/step - loss: 8.2687 - accuracy: 0.1457
# Epoch 55/100
# 1563/1563 [==============================] - 45s 29ms/step - loss: 8.2666 - accuracy: 0.1466
# Epoch 56/100
# 1563/1563 [==============================] - 44s 28ms/step - loss: 8.2646 - accuracy: 0.1473
# Epoch 57/100
# 1563/1563 [==============================] - 44s 28ms/step - loss: 8.2664 - accuracy: 0.1431
# Epoch 58/100
# 1563/1563 [==============================] - 44s 28ms/step - loss: 8.2628 - accuracy: 0.1444
# Epoch 59/100
# 1563/1563 [==============================] - 45s 28ms/step - loss: 8.2676 - accuracy: 0.1398
# Epoch 60/100
# 1563/1563 [==============================] - 44s 28ms/step - loss: 8.2644 - accuracy: 0.1453
# Epoch 61/100
# 1563/1563 [==============================] - 43s 27ms/step - loss: 8.2678 - accuracy: 0.1427
# Epoch 62/100
# 1563/1563 [==============================] - 43s 27ms/step - loss: 8.2666 - accuracy: 0.1438
# Epoch 63/100
# 1563/1563 [==============================] - 43s 27ms/step - loss: 8.2661 - accuracy: 0.1438
# Epoch 64/100
# 1563/1563 [==============================] - 43s 27ms/step - loss: 8.2638 - accuracy: 0.1437
# Epoch 65/100
# 1563/1563 [==============================] - 43s 27ms/step - loss: 8.2634 - accuracy: 0.1449
# Epoch 66/100
# 1563/1563 [==============================] - 43s 27ms/step - loss: 8.2625 - accuracy: 0.1464
# Epoch 67/100
# 1563/1563 [==============================] - 43s 27ms/step - loss: 8.2615 - accuracy: 0.1469
# Epoch 68/100
# 1563/1563 [==============================] - 43s 27ms/step - loss: 8.2580 - accuracy: 0.1465
# Epoch 69/100
# 1563/1563 [==============================] - 43s 27ms/step - loss: 8.2599 - accuracy: 0.1459
# Epoch 70/100
# 1563/1563 [==============================] - 43s 27ms/step - loss: 8.2611 - accuracy: 0.1457
# Epoch 71/100
# 1563/1563 [==============================] - 43s 27ms/step - loss: 8.2608 - accuracy: 0.1462
# Epoch 72/100
# 1563/1563 [==============================] - 43s 27ms/step - loss: 8.2627 - accuracy: 0.1441
# Epoch 73/100
# 1563/1563 [==============================] - 43s 27ms/step - loss: 8.2584 - accuracy: 0.1478
# Epoch 74/100
# 1563/1563 [==============================] - 43s 27ms/step - loss: 8.2569 - accuracy: 0.1486
# Epoch 75/100
# 1563/1563 [==============================] - 43s 27ms/step - loss: 8.2580 - accuracy: 0.1467
# Epoch 76/100
# 1563/1563 [==============================] - 43s 27ms/step - loss: 8.2608 - accuracy: 0.1475
# Epoch 77/100
# 1563/1563 [==============================] - 42s 27ms/step - loss: 8.2595 - accuracy: 0.1457
# Epoch 78/100
# 1563/1563 [==============================] - 42s 27ms/step - loss: 8.2582 - accuracy: 0.1443
# Epoch 79/100
# 1563/1563 [==============================] - 42s 27ms/step - loss: 8.2608 - accuracy: 0.1463
# Epoch 80/100
# 1563/1563 [==============================] - 42s 27ms/step - loss: 8.2590 - accuracy: 0.1460
# Epoch 81/100
# 1563/1563 [==============================] - 42s 27ms/step - loss: 8.2573 - accuracy: 0.1468
# Epoch 82/100
# 1563/1563 [==============================] - 42s 27ms/step - loss: 8.2579 - accuracy: 0.1434
# Epoch 83/100
# 1563/1563 [==============================] - 42s 27ms/step - loss: 8.2574 - accuracy: 0.1462
# Epoch 84/100
# 1563/1563 [==============================] - 42s 27ms/step - loss: 8.2567 - accuracy: 0.1458
# Epoch 85/100
# 1563/1563 [==============================] - 42s 27ms/step - loss: 8.2579 - accuracy: 0.1496
# Epoch 86/100
# 1563/1563 [==============================] - 42s 27ms/step - loss: 8.2572 - accuracy: 0.1467
# Epoch 87/100
# 1563/1563 [==============================] - 42s 27ms/step - loss: 8.2542 - accuracy: 0.1497
# Epoch 88/100
# 1563/1563 [==============================] - 42s 27ms/step - loss: 8.2557 - accuracy: 0.1484
# Epoch 89/100
# 1563/1563 [==============================] - 42s 27ms/step - loss: 8.2534 - accuracy: 0.1477
# Epoch 90/100
# 1563/1563 [==============================] - 42s 27ms/step - loss: 8.2556 - accuracy: 0.1469
# Epoch 91/100
# 1563/1563 [==============================] - 42s 27ms/step - loss: 8.2535 - accuracy: 0.1492
# Epoch 92/100
# 1563/1563 [==============================] - 42s 27ms/step - loss: 8.2544 - accuracy: 0.1482
# Epoch 93/100
# 1563/1563 [==============================] - 42s 27ms/step - loss: 8.2507 - accuracy: 0.1506
# Epoch 94/100
# 1563/1563 [==============================] - 42s 27ms/step - loss: 8.2504 - accuracy: 0.1479
# Epoch 95/100
# 1563/1563 [==============================] - 42s 27ms/step - loss: 8.2526 - accuracy: 0.1488
# Epoch 96/100
# 1563/1563 [==============================] - 42s 27ms/step - loss: 8.2550 - accuracy: 0.1470
# Epoch 97/100
# 1563/1563 [==============================] - 42s 27ms/step - loss: 8.2535 - accuracy: 0.1472
# Epoch 98/100
# 1563/1563 [==============================] - 42s 27ms/step - loss: 8.2533 - accuracy: 0.1462
# Epoch 99/100
# 1563/1563 [==============================] - 42s 27ms/step - loss: 8.2505 - accuracy: 0.1473
# Epoch 100/100
# 1563/1563 [==============================] - 42s 27ms/step - loss: 8.2523 - accuracy: 0.1492

# %%
def conv_block(input_tensor,
               filters,
               stage,
               block,
               strides=(2,2),
               use_l2_regularizer=True,
               bn_decay=0.9,
               bn_epsilon=1e-5):
  

  if backend.image_data_format() == 'channels_last':
    bn_axis=3
  else:
    bn_axis=1

  conv_name='conv'+str(stage)+block+'_branch'
  bn_name='bn'+str(stage)+block+'_branch'

  x = layers.Conv2D(filters,(3,3),strides=strides,padding='same',use_bias=False,kernel_initializer='he_normal',
                    kernel_regularizer=_gen_l2_regularizer(use_l2_regularizer),
                    name = conv_name+'2a')(input_tensor)

  x = layers.BatchNormalization(axis=bn_axis, momentum=bn_decay, epsilon=bn_epsilon,name=bn_name+'2a')(x)

  x = layers.Activation('relu')(x)
  
  x = layers.Conv2D(filters,(3,3),use_bias=False,padding='same',kernel_initializer='he_normal',
                    kernel_regularizer=_gen_l2_regularizer(use_l2_regularizer),
                    name = conv_name+'2b')(x)

  x = layers.BatchNormalization(axis=bn_axis, momentum=bn_decay, epsilon=bn_epsilon,name=bn_name+'2b')(x)


  shortcut = layers.Conv2D(filters,(3,3),strides=strides,padding='same',use_bias=False,kernel_initializer='he_normal',
                           kernel_regularizer=_gen_l2_regularizer(use_l2_regularizer),
                           name = conv_name+'1')(input_tensor)

  shortcut = layers.BatchNormalization(axis=bn_axis, momentum=bn_decay, epsilon=bn_epsilon,name=bn_name+'1')(shortcut)

  x = layers.add([x, shortcut])

  x = layers.Activation('relu')(x)

  return x

# %%
def identity_block(input_tensor,
                   filters,
                   stage,
                   block,
                   use_l2_regularizer=True,
                   bn_decay=0.9,
                   bn_epsilon=1e-5):
  
  if backend.image_data_format() == 'channels_last':
    bn_axis=3
  else:
    bn_axis=1

  id_name='id'+str(stage)+block+'_branch'
  bn_name='bn'+str(stage)+block+'_branch'

  x = layers.Conv2D(filters,(3,3),padding='same',use_bias=False,kernel_initializer='he_normal',
                    kernel_regularizer=_gen_l2_regularizer(use_l2_regularizer),
                    name = id_name+'2a')(input_tensor)

  x = layers.BatchNormalization(axis=bn_axis,momentum=bn_decay, epsilon=bn_epsilon,name=bn_name+'2a')(x)

  x = layers.Activation('relu')(x)

  x = layers.Conv2D(filters,(3,3),padding='same',use_bias=False,kernel_initializer='he_normal',
                    kernel_regularizer=_gen_l2_regularizer(use_l2_regularizer),
                    name = id_name+'2b')(x)

  x = layers.BatchNormalization(axis=bn_axis,momentum=bn_decay, epsilon=bn_epsilon,name=bn_name+'2b')(x)

  x = layers.add([x,input_tensor])
  
  x = layers.Activation('relu')(x)

  return x

# %%
def resnet34(num_classes,
             batch_size=None,
             use_l2_regularizer=True,
             rescale_inputs=False,
             bn_decay=0.9,
             bn_epsilon=1e-5):

  input_shape = (32, 32, 3)
  img_input = layers.Input(shape=input_shape, batch_size=batch_size)
  if rescale_inputs:
    x = layers.Lambda(
        lambda x: x * 255.0 - backend.constant(
            imagenet_preprocessing.CHANNEL_MEANS,
            shape=[1, 1, 3],
            dtype=x.dtype),
        name='rescale')(
            img_input)
  else:
    x = img_input

  if backend.image_data_format() == 'channels_first':
    x = layers.Permute((3, 1, 2))(x)
    bn_axis = 1
  else:  
    bn_axis = 3

  block_config = dict(
      use_l2_regularizer=use_l2_regularizer,
      bn_decay=bn_decay,
      bn_epsilon=bn_epsilon)
  x = layers.ZeroPadding2D(padding=(3, 3), name='conv1_pad')(x)
  x = layers.Conv2D(
      64, (7, 7),
      strides=(2, 2),
      padding='valid',
      use_bias=False,
      kernel_initializer='he_normal',
      kernel_regularizer=_gen_l2_regularizer(use_l2_regularizer),
      name='conv1')(
          x)
  x = layers.BatchNormalization(
      axis=bn_axis,
      momentum=bn_decay,
      epsilon=bn_epsilon,
      name='bn_conv1')(
          x)
  x = layers.Activation('relu')(x)
  x = layers.MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)

  x = identity_block(x, 64, stage=2, block='a', **block_config)
  x = identity_block(x, 64, stage=2, block='b', **block_config)
  x = identity_block(x, 64, stage=2, block='c', **block_config)

  x = conv_block(x,128, stage=3, block='a', **block_config)
  x = identity_block(x, 128, stage=3, block='b', **block_config)
  x = identity_block(x, 128, stage=3, block='c', **block_config)
  x = identity_block(x, 128, stage=3, block='d', **block_config)

  x = conv_block(x,256, stage=4, block='a', **block_config)
  x = identity_block(x,256, stage=4, block='b', **block_config)
  x = identity_block(x, 256, stage=4, block='c', **block_config)
  x = identity_block(x, 256, stage=4, block='d', **block_config)
  x = identity_block(x, 256, stage=4, block='e', **block_config)
  x = identity_block(x, 256, stage=4, block='f', **block_config)

  x = conv_block(x,512, stage=5, block='a', **block_config)
  x = identity_block(x, 512, stage=5, block='b', **block_config)
  x = identity_block(x, 512, stage=5, block='c', **block_config)

  x = layers.GlobalAveragePooling2D()(x)
  x = layers.Dense(
      num_classes,
      kernel_initializer=initializers.RandomNormal(stddev=0.01),
      kernel_regularizer=_gen_l2_regularizer(use_l2_regularizer),
      bias_regularizer=_gen_l2_regularizer(use_l2_regularizer),
      name='fc1000')(
          x)

  x = layers.Activation('softmax', dtype='float32')(x)

  return models.Model(img_input, x, name='resnet34')

# %%
resnet_34 = resnet34(num_classes=100)
resnet_34.summary()
# Out:
# Model: "resnet34"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_7 (InputLayer)           [(None, 32, 32, 3)]  0           []
#
#  conv1_pad (ZeroPadding2D)      (None, 38, 38, 3)    0           ['input_7[0][0]']
#
#  conv1 (Conv2D)                 (None, 16, 16, 64)   9408        ['conv1_pad[0][0]']
#
#  bn_conv1 (BatchNormalization)  (None, 16, 16, 64)   256         ['conv1[0][0]']
#
#  activation_204 (Activation)    (None, 16, 16, 64)   0           ['bn_conv1[0][0]']
#
#  max_pooling2d_6 (MaxPooling2D)  (None, 8, 8, 64)    0           ['activation_204[0][0]']
#
#  id2a_branch2a (Conv2D)         (None, 8, 8, 64)     36864       ['max_pooling2d_6[0][0]']
#
#  bn2a_branch2a (BatchNormalizat  (None, 8, 8, 64)    256         ['id2a_branch2a[0][0]']
#  ion)
#
#  activation_205 (Activation)    (None, 8, 8, 64)     0           ['bn2a_branch2a[0][0]']
#
#  id2a_branch2b (Conv2D)         (None, 8, 8, 64)     36864       ['activation_205[0][0]']
#
#  bn2a_branch2b (BatchNormalizat  (None, 8, 8, 64)    256         ['id2a_branch2b[0][0]']
#  ion)
#
#  add (Add)                      (None, 8, 8, 64)     0           ['bn2a_branch2b[0][0]',
#                                                                   'max_pooling2d_6[0][0]']
#
#  activation_206 (Activation)    (None, 8, 8, 64)     0           ['add[0][0]']
#
#  id2b_branch2a (Conv2D)         (None, 8, 8, 64)     36864       ['activation_206[0][0]']
#
#  bn2b_branch2a (BatchNormalizat  (None, 8, 8, 64)    256         ['id2b_branch2a[0][0]']
#  ion)
#
#  activation_207 (Activation)    (None, 8, 8, 64)     0           ['bn2b_branch2a[0][0]']
#
#  id2b_branch2b (Conv2D)         (None, 8, 8, 64)     36864       ['activation_207[0][0]']
#
#  bn2b_branch2b (BatchNormalizat  (None, 8, 8, 64)    256         ['id2b_branch2b[0][0]']
#  ion)
#
#  add_1 (Add)                    (None, 8, 8, 64)     0           ['bn2b_branch2b[0][0]',
#                                                                   'activation_206[0][0]']
#
#  activation_208 (Activation)    (None, 8, 8, 64)     0           ['add_1[0][0]']
#
#  id2c_branch2a (Conv2D)         (None, 8, 8, 64)     36864       ['activation_208[0][0]']
#
#  bn2c_branch2a (BatchNormalizat  (None, 8, 8, 64)    256         ['id2c_branch2a[0][0]']
#  ion)
#
#  activation_209 (Activation)    (None, 8, 8, 64)     0           ['bn2c_branch2a[0][0]']
#
#  id2c_branch2b (Conv2D)         (None, 8, 8, 64)     36864       ['activation_209[0][0]']
#
#  bn2c_branch2b (BatchNormalizat  (None, 8, 8, 64)    256         ['id2c_branch2b[0][0]']
#  ion)
#
#  add_2 (Add)                    (None, 8, 8, 64)     0           ['bn2c_branch2b[0][0]',
#                                                                   'activation_208[0][0]']
#
#  activation_210 (Activation)    (None, 8, 8, 64)     0           ['add_2[0][0]']
#
#  conv3a_branch2a (Conv2D)       (None, 4, 4, 128)    73728       ['activation_210[0][0]']
#
#  bn3a_branch2a (BatchNormalizat  (None, 4, 4, 128)   512         ['conv3a_branch2a[0][0]']
#  ion)
#
#  activation_211 (Activation)    (None, 4, 4, 128)    0           ['bn3a_branch2a[0][0]']
#
#  conv3a_branch2b (Conv2D)       (None, 4, 4, 128)    147456      ['activation_211[0][0]']
#
#  conv3a_branch1 (Conv2D)        (None, 4, 4, 128)    73728       ['activation_210[0][0]']
#
#  bn3a_branch2b (BatchNormalizat  (None, 4, 4, 128)   512         ['conv3a_branch2b[0][0]']
#  ion)
#
#  bn3a_branch1 (BatchNormalizati  (None, 4, 4, 128)   512         ['conv3a_branch1[0][0]']
#  on)
#
#  add_3 (Add)                    (None, 4, 4, 128)    0           ['bn3a_branch2b[0][0]',
#                                                                   'bn3a_branch1[0][0]']
#
#  activation_212 (Activation)    (None, 4, 4, 128)    0           ['add_3[0][0]']
#
#  id3b_branch2a (Conv2D)         (None, 4, 4, 128)    147456      ['activation_212[0][0]']
#
#  bn3b_branch2a (BatchNormalizat  (None, 4, 4, 128)   512         ['id3b_branch2a[0][0]']
#  ion)
#
#  activation_213 (Activation)    (None, 4, 4, 128)    0           ['bn3b_branch2a[0][0]']
#
#  id3b_branch2b (Conv2D)         (None, 4, 4, 128)    147456      ['activation_213[0][0]']
#
#  bn3b_branch2b (BatchNormalizat  (None, 4, 4, 128)   512         ['id3b_branch2b[0][0]']
#  ion)
#
#  add_4 (Add)                    (None, 4, 4, 128)    0           ['bn3b_branch2b[0][0]',
#                                                                   'activation_212[0][0]']
#
#  activation_214 (Activation)    (None, 4, 4, 128)    0           ['add_4[0][0]']
#
#  id3c_branch2a (Conv2D)         (None, 4, 4, 128)    147456      ['activation_214[0][0]']
#
#  bn3c_branch2a (BatchNormalizat  (None, 4, 4, 128)   512         ['id3c_branch2a[0][0]']
#  ion)
#
#  activation_215 (Activation)    (None, 4, 4, 128)    0           ['bn3c_branch2a[0][0]']
#
#  id3c_branch2b (Conv2D)         (None, 4, 4, 128)    147456      ['activation_215[0][0]']
#
#  bn3c_branch2b (BatchNormalizat  (None, 4, 4, 128)   512         ['id3c_branch2b[0][0]']
#  ion)
#
#  add_5 (Add)                    (None, 4, 4, 128)    0           ['bn3c_branch2b[0][0]',
#                                                                   'activation_214[0][0]']
#
#  activation_216 (Activation)    (None, 4, 4, 128)    0           ['add_5[0][0]']
#
#  id3d_branch2a (Conv2D)         (None, 4, 4, 128)    147456      ['activation_216[0][0]']
#
#  bn3d_branch2a (BatchNormalizat  (None, 4, 4, 128)   512         ['id3d_branch2a[0][0]']
#  ion)
#
#  activation_217 (Activation)    (None, 4, 4, 128)    0           ['bn3d_branch2a[0][0]']
#
#  id3d_branch2b (Conv2D)         (None, 4, 4, 128)    147456      ['activation_217[0][0]']
#
#  bn3d_branch2b (BatchNormalizat  (None, 4, 4, 128)   512         ['id3d_branch2b[0][0]']
#  ion)
#
#  add_6 (Add)                    (None, 4, 4, 128)    0           ['bn3d_branch2b[0][0]',
#                                                                   'activation_216[0][0]']
#
#  activation_218 (Activation)    (None, 4, 4, 128)    0           ['add_6[0][0]']
#
#  conv4a_branch2a (Conv2D)       (None, 2, 2, 256)    294912      ['activation_218[0][0]']
#
#  bn4a_branch2a (BatchNormalizat  (None, 2, 2, 256)   1024        ['conv4a_branch2a[0][0]']
#  ion)
#
#  activation_219 (Activation)    (None, 2, 2, 256)    0           ['bn4a_branch2a[0][0]']
#
#  conv4a_branch2b (Conv2D)       (None, 2, 2, 256)    589824      ['activation_219[0][0]']
#
#  conv4a_branch1 (Conv2D)        (None, 2, 2, 256)    294912      ['activation_218[0][0]']
#
#  bn4a_branch2b (BatchNormalizat  (None, 2, 2, 256)   1024        ['conv4a_branch2b[0][0]']
#  ion)
#
#  bn4a_branch1 (BatchNormalizati  (None, 2, 2, 256)   1024        ['conv4a_branch1[0][0]']
#  on)
#
#  add_7 (Add)                    (None, 2, 2, 256)    0           ['bn4a_branch2b[0][0]',
#                                                                   'bn4a_branch1[0][0]']
#
#  activation_220 (Activation)    (None, 2, 2, 256)    0           ['add_7[0][0]']
#
#  id4b_branch2a (Conv2D)         (None, 2, 2, 256)    589824      ['activation_220[0][0]']
#
#  bn4b_branch2a (BatchNormalizat  (None, 2, 2, 256)   1024        ['id4b_branch2a[0][0]']
#  ion)
#
#  activation_221 (Activation)    (None, 2, 2, 256)    0           ['bn4b_branch2a[0][0]']
#
#  id4b_branch2b (Conv2D)         (None, 2, 2, 256)    589824      ['activation_221[0][0]']
#
#  bn4b_branch2b (BatchNormalizat  (None, 2, 2, 256)   1024        ['id4b_branch2b[0][0]']
#  ion)
#
#  add_8 (Add)                    (None, 2, 2, 256)    0           ['bn4b_branch2b[0][0]',
#                                                                   'activation_220[0][0]']
#
#  activation_222 (Activation)    (None, 2, 2, 256)    0           ['add_8[0][0]']
#
#  id4c_branch2a (Conv2D)         (None, 2, 2, 256)    589824      ['activation_222[0][0]']
#
#  bn4c_branch2a (BatchNormalizat  (None, 2, 2, 256)   1024        ['id4c_branch2a[0][0]']
#  ion)
#
#  activation_223 (Activation)    (None, 2, 2, 256)    0           ['bn4c_branch2a[0][0]']
#
#  id4c_branch2b (Conv2D)         (None, 2, 2, 256)    589824      ['activation_223[0][0]']
#
#  bn4c_branch2b (BatchNormalizat  (None, 2, 2, 256)   1024        ['id4c_branch2b[0][0]']
#  ion)
#
#  add_9 (Add)                    (None, 2, 2, 256)    0           ['bn4c_branch2b[0][0]',
#                                                                   'activation_222[0][0]']
#
#  activation_224 (Activation)    (None, 2, 2, 256)    0           ['add_9[0][0]']
#
#  id4d_branch2a (Conv2D)         (None, 2, 2, 256)    589824      ['activation_224[0][0]']
#
#  bn4d_branch2a (BatchNormalizat  (None, 2, 2, 256)   1024        ['id4d_branch2a[0][0]']
#  ion)
#
#  activation_225 (Activation)    (None, 2, 2, 256)    0           ['bn4d_branch2a[0][0]']
#
#  id4d_branch2b (Conv2D)         (None, 2, 2, 256)    589824      ['activation_225[0][0]']
#
#  bn4d_branch2b (BatchNormalizat  (None, 2, 2, 256)   1024        ['id4d_branch2b[0][0]']
#  ion)
#
#  add_10 (Add)                   (None, 2, 2, 256)    0           ['bn4d_branch2b[0][0]',
#                                                                   'activation_224[0][0]']
#
#  activation_226 (Activation)    (None, 2, 2, 256)    0           ['add_10[0][0]']
#
#  id4e_branch2a (Conv2D)         (None, 2, 2, 256)    589824      ['activation_226[0][0]']
#
#  bn4e_branch2a (BatchNormalizat  (None, 2, 2, 256)   1024        ['id4e_branch2a[0][0]']
#  ion)
#
#  activation_227 (Activation)    (None, 2, 2, 256)    0           ['bn4e_branch2a[0][0]']
#
#  id4e_branch2b (Conv2D)         (None, 2, 2, 256)    589824      ['activation_227[0][0]']
#
#  bn4e_branch2b (BatchNormalizat  (None, 2, 2, 256)   1024        ['id4e_branch2b[0][0]']
#  ion)
#
#  add_11 (Add)                   (None, 2, 2, 256)    0           ['bn4e_branch2b[0][0]',
#                                                                   'activation_226[0][0]']
#
#  activation_228 (Activation)    (None, 2, 2, 256)    0           ['add_11[0][0]']
#
#  id4f_branch2a (Conv2D)         (None, 2, 2, 256)    589824      ['activation_228[0][0]']
#
#  bn4f_branch2a (BatchNormalizat  (None, 2, 2, 256)   1024        ['id4f_branch2a[0][0]']
#  ion)
#
#  activation_229 (Activation)    (None, 2, 2, 256)    0           ['bn4f_branch2a[0][0]']
#
#  id4f_branch2b (Conv2D)         (None, 2, 2, 256)    589824      ['activation_229[0][0]']
#
#  bn4f_branch2b (BatchNormalizat  (None, 2, 2, 256)   1024        ['id4f_branch2b[0][0]']
#  ion)
#
#  add_12 (Add)                   (None, 2, 2, 256)    0           ['bn4f_branch2b[0][0]',
#                                                                   'activation_228[0][0]']
#
#  activation_230 (Activation)    (None, 2, 2, 256)    0           ['add_12[0][0]']
#
#  conv5a_branch2a (Conv2D)       (None, 1, 1, 512)    1179648     ['activation_230[0][0]']
#
#  bn5a_branch2a (BatchNormalizat  (None, 1, 1, 512)   2048        ['conv5a_branch2a[0][0]']
#  ion)
#
#  activation_231 (Activation)    (None, 1, 1, 512)    0           ['bn5a_branch2a[0][0]']
#
#  conv5a_branch2b (Conv2D)       (None, 1, 1, 512)    2359296     ['activation_231[0][0]']
#
#  conv5a_branch1 (Conv2D)        (None, 1, 1, 512)    1179648     ['activation_230[0][0]']
#
#  bn5a_branch2b (BatchNormalizat  (None, 1, 1, 512)   2048        ['conv5a_branch2b[0][0]']
#  ion)
#
#  bn5a_branch1 (BatchNormalizati  (None, 1, 1, 512)   2048        ['conv5a_branch1[0][0]']
#  on)
#
#  add_13 (Add)                   (None, 1, 1, 512)    0           ['bn5a_branch2b[0][0]',
#                                                                   'bn5a_branch1[0][0]']
#
#  activation_232 (Activation)    (None, 1, 1, 512)    0           ['add_13[0][0]']
#
#  id5b_branch2a (Conv2D)         (None, 1, 1, 512)    2359296     ['activation_232[0][0]']
#
#  bn5b_branch2a (BatchNormalizat  (None, 1, 1, 512)   2048        ['id5b_branch2a[0][0]']
#  ion)
#
#  activation_233 (Activation)    (None, 1, 1, 512)    0           ['bn5b_branch2a[0][0]']
#
#  id5b_branch2b (Conv2D)         (None, 1, 1, 512)    2359296     ['activation_233[0][0]']
#
#  bn5b_branch2b (BatchNormalizat  (None, 1, 1, 512)   2048        ['id5b_branch2b[0][0]']
#  ion)
#
#  add_14 (Add)                   (None, 1, 1, 512)    0           ['bn5b_branch2b[0][0]',
#                                                                   'activation_232[0][0]']
#
#  activation_234 (Activation)    (None, 1, 1, 512)    0           ['add_14[0][0]']
#
#  id5c_branch2a (Conv2D)         (None, 1, 1, 512)    2359296     ['activation_234[0][0]']
#
#  bn5c_branch2a (BatchNormalizat  (None, 1, 1, 512)   2048        ['id5c_branch2a[0][0]']
#  ion)
#
#  activation_235 (Activation)    (None, 1, 1, 512)    0           ['bn5c_branch2a[0][0]']
#
#  id5c_branch2b (Conv2D)         (None, 1, 1, 512)    2359296     ['activation_235[0][0]']
#
#  bn5c_branch2b (BatchNormalizat  (None, 1, 1, 512)   2048        ['id5c_branch2b[0][0]']
#  ion)
#
#  add_15 (Add)                   (None, 1, 1, 512)    0           ['bn5c_branch2b[0][0]',
#                                                                   'activation_234[0][0]']
#
#  activation_236 (Activation)    (None, 1, 1, 512)    0           ['add_15[0][0]']
#
#  global_average_pooling2d_6 (Gl  (None, 512)         0           ['activation_236[0][0]']
#  obalAveragePooling2D)
#
#  fc1000 (Dense)                 (None, 100)          51300       ['global_average_pooling2d_6[0][0
#                                                                  ]']
#
#  activation_237 (Activation)    (None, 100)          0           ['fc1000[0][0]']
#
# ==================================================================================================
# Total params: 22,729,252
# Trainable params: 22,712,228
# Non-trainable params: 17,024
# __________________________________________________________________________________________________

# %%
plot_model(resnet_34, show_shapes=True)

# %%
resnet_34.compile(optimizer=keras.optimizers.SGD(lr=0.1, momentum=0.9, decay=0.1),
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

history_resnet34 = resnet_34.fit(x_train, y_train, epochs=100)
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/gradient_descent.py:102: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(SGD, self).__init__(name, **kwargs)
# Epoch 1/100
# 1563/1563 [==============================] - 50s 30ms/step - loss: 4.8907 - accuracy: 0.1367
# Epoch 2/100
# 1563/1563 [==============================] - 46s 30ms/step - loss: 4.5190 - accuracy: 0.1729
# Epoch 3/100
# 1563/1563 [==============================] - 46s 30ms/step - loss: 4.4586 - accuracy: 0.1937
# Epoch 4/100
# 1563/1563 [==============================] - 46s 30ms/step - loss: 4.4077 - accuracy: 0.2065
# Epoch 5/100
# 1563/1563 [==============================] - 46s 30ms/step - loss: 4.3679 - accuracy: 0.2188
# Epoch 6/100
# 1563/1563 [==============================] - 46s 30ms/step - loss: 4.3326 - accuracy: 0.2253
# Epoch 7/100
# 1563/1563 [==============================] - 46s 30ms/step - loss: 4.3053 - accuracy: 0.2320
# Epoch 8/100
# 1563/1563 [==============================] - 46s 30ms/step - loss: 4.2858 - accuracy: 0.2411
# Epoch 9/100
# 1563/1563 [==============================] - 46s 30ms/step - loss: 4.2713 - accuracy: 0.2380
# Epoch 10/100
# 1563/1563 [==============================] - 46s 30ms/step - loss: 4.2623 - accuracy: 0.2417
# Epoch 11/100
# 1563/1563 [==============================] - 46s 30ms/step - loss: 4.2535 - accuracy: 0.2461
# Epoch 12/100
# 1563/1563 [==============================] - 46s 30ms/step - loss: 4.2467 - accuracy: 0.2485
# Epoch 13/100
# 1563/1563 [==============================] - 46s 30ms/step - loss: 4.2392 - accuracy: 0.2503
# Epoch 14/100
# 1563/1563 [==============================] - 46s 30ms/step - loss: 4.2348 - accuracy: 0.2504
# Epoch 15/100
# 1563/1563 [==============================] - 46s 30ms/step - loss: 4.2270 - accuracy: 0.2566
# Epoch 16/100
# 1563/1563 [==============================] - 46s 30ms/step - loss: 4.2276 - accuracy: 0.2541
# Epoch 17/100
# 1563/1563 [==============================] - 46s 30ms/step - loss: 4.2201 - accuracy: 0.2602
# Epoch 18/100
# 1563/1563 [==============================] - 46s 30ms/step - loss: 4.2198 - accuracy: 0.2571
# Epoch 19/100
# 1563/1563 [==============================] - 46s 30ms/step - loss: 4.2111 - accuracy: 0.2626
# Epoch 20/100
# 1563/1563 [==============================] - 46s 29ms/step - loss: 4.2087 - accuracy: 0.2652
# Epoch 21/100
# 1563/1563 [==============================] - 46s 30ms/step - loss: 4.2026 - accuracy: 0.2668
# Epoch 22/100
# 1563/1563 [==============================] - 46s 30ms/step - loss: 4.1981 - accuracy: 0.2705
# Epoch 23/100
# 1563/1563 [==============================] - 46s 30ms/step - loss: 4.1910 - accuracy: 0.2762
# Epoch 24/100
# 1563/1563 [==============================] - 46s 30ms/step - loss: 4.1867 - accuracy: 0.2755
# Epoch 25/100
# 1563/1563 [==============================] - 46s 30ms/step - loss: 4.1839 - accuracy: 0.2793
# Epoch 26/100
# 1563/1563 [==============================] - 46s 29ms/step - loss: 4.1802 - accuracy: 0.2798
# Epoch 27/100
# 1563/1563 [==============================] - 46s 29ms/step - loss: 4.1753 - accuracy: 0.2840
# Epoch 28/100
# 1563/1563 [==============================] - 46s 29ms/step - loss: 4.1723 - accuracy: 0.2828
# Epoch 29/100
# 1563/1563 [==============================] - 46s 29ms/step - loss: 4.1674 - accuracy: 0.2849
# Epoch 30/100
# 1563/1563 [==============================] - 46s 30ms/step - loss: 4.1627 - accuracy: 0.2865
# Epoch 31/100
# 1563/1563 [==============================] - 46s 30ms/step - loss: 4.1604 - accuracy: 0.2891
# Epoch 32/100
# 1563/1563 [==============================] - 46s 29ms/step - loss: 4.1553 - accuracy: 0.2908
# Epoch 33/100
# 1563/1563 [==============================] - 46s 29ms/step - loss: 4.1537 - accuracy: 0.2912
# Epoch 34/100
# 1563/1563 [==============================] - 46s 29ms/step - loss: 4.1506 - accuracy: 0.2902
# Epoch 35/100
# 1563/1563 [==============================] - 46s 29ms/step - loss: 4.1485 - accuracy: 0.2911
# Epoch 36/100
# 1563/1563 [==============================] - 46s 29ms/step - loss: 4.1408 - accuracy: 0.2961
# Epoch 37/100
# 1563/1563 [==============================] - 46s 29ms/step - loss: 4.1405 - accuracy: 0.2935
# Epoch 38/100
# 1563/1563 [==============================] - 46s 29ms/step - loss: 4.1400 - accuracy: 0.2945
# Epoch 39/100
# 1563/1563 [==============================] - 46s 30ms/step - loss: 4.1376 - accuracy: 0.2931
# Epoch 40/100
# 1563/1563 [==============================] - 46s 30ms/step - loss: 4.1326 - accuracy: 0.2972
# Epoch 41/100
# 1563/1563 [==============================] - 46s 30ms/step - loss: 4.1273 - accuracy: 0.2983
# Epoch 42/100
# 1563/1563 [==============================] - 46s 30ms/step - loss: 4.1231 - accuracy: 0.3001
# Epoch 43/100
# 1563/1563 [==============================] - 46s 30ms/step - loss: 4.1225 - accuracy: 0.3009
# Epoch 44/100
# 1563/1563 [==============================] - 46s 30ms/step - loss: 4.1200 - accuracy: 0.3037
# Epoch 45/100
# 1563/1563 [==============================] - 46s 30ms/step - loss: 4.1150 - accuracy: 0.3047
# Epoch 46/100
# 1563/1563 [==============================] - 46s 30ms/step - loss: 4.1143 - accuracy: 0.3044
# Epoch 47/100
# 1563/1563 [==============================] - 46s 30ms/step - loss: 4.1100 - accuracy: 0.3068
# Epoch 48/100
# 1563/1563 [==============================] - 46s 30ms/step - loss: 4.1052 - accuracy: 0.3091
# Epoch 49/100
# 1563/1563 [==============================] - 46s 30ms/step - loss: 4.1054 - accuracy: 0.3120
# Epoch 50/100
# 1563/1563 [==============================] - 46s 30ms/step - loss: 4.0994 - accuracy: 0.3118
# Epoch 51/100
# 1563/1563 [==============================] - 46s 30ms/step - loss: 4.0939 - accuracy: 0.3160
# Epoch 52/100
# 1563/1563 [==============================] - 46s 30ms/step - loss: 4.0907 - accuracy: 0.3157
# Epoch 53/100
# 1563/1563 [==============================] - 46s 30ms/step - loss: 4.0905 - accuracy: 0.3159
# Epoch 54/100
# 1563/1563 [==============================] - 46s 30ms/step - loss: 4.0832 - accuracy: 0.3220
# Epoch 55/100
# 1563/1563 [==============================] - 47s 30ms/step - loss: 4.0828 - accuracy: 0.3230
# Epoch 56/100
# 1563/1563 [==============================] - 47s 30ms/step - loss: 4.0786 - accuracy: 0.3232
# Epoch 57/100
# 1563/1563 [==============================] - 46s 30ms/step - loss: 4.0761 - accuracy: 0.3236
# Epoch 58/100
# 1563/1563 [==============================] - 46s 29ms/step - loss: 4.0741 - accuracy: 0.3230
# Epoch 59/100
# 1563/1563 [==============================] - 46s 29ms/step - loss: 4.0705 - accuracy: 0.3277
# Epoch 60/100
# 1563/1563 [==============================] - 46s 29ms/step - loss: 4.0664 - accuracy: 0.3265
# Epoch 61/100
# 1563/1563 [==============================] - 46s 29ms/step - loss: 4.0673 - accuracy: 0.3290
# Epoch 62/100
# 1563/1563 [==============================] - 46s 29ms/step - loss: 4.0616 - accuracy: 0.3307
# Epoch 63/100
# 1563/1563 [==============================] - 46s 29ms/step - loss: 4.0577 - accuracy: 0.3343
# Epoch 64/100
# 1563/1563 [==============================] - 46s 29ms/step - loss: 4.0602 - accuracy: 0.3335
# Epoch 65/100
# 1563/1563 [==============================] - 46s 29ms/step - loss: 4.0532 - accuracy: 0.3354
# Epoch 66/100
# 1563/1563 [==============================] - 46s 29ms/step - loss: 4.0544 - accuracy: 0.3349
# Epoch 67/100
# 1563/1563 [==============================] - 46s 29ms/step - loss: 4.0495 - accuracy: 0.3360
# Epoch 68/100
# 1563/1563 [==============================] - 46s 29ms/step - loss: 4.0479 - accuracy: 0.3366
# Epoch 69/100
# 1563/1563 [==============================] - 46s 29ms/step - loss: 4.0448 - accuracy: 0.3389
# Epoch 70/100
# 1563/1563 [==============================] - 46s 29ms/step - loss: 4.0443 - accuracy: 0.3409
# Epoch 71/100
# 1563/1563 [==============================] - 46s 29ms/step - loss: 4.0417 - accuracy: 0.3406
# Epoch 72/100
# 1563/1563 [==============================] - 46s 29ms/step - loss: 4.0414 - accuracy: 0.3420
# Epoch 73/100
# 1563/1563 [==============================] - 46s 29ms/step - loss: 4.0350 - accuracy: 0.3443
# Epoch 74/100
# 1563/1563 [==============================] - 46s 29ms/step - loss: 4.0381 - accuracy: 0.3415
# Epoch 75/100
# 1563/1563 [==============================] - 46s 29ms/step - loss: 4.0348 - accuracy: 0.3423
# Epoch 76/100
# 1563/1563 [==============================] - 46s 29ms/step - loss: 4.0292 - accuracy: 0.3449
# Epoch 77/100
# 1563/1563 [==============================] - 46s 30ms/step - loss: 4.0271 - accuracy: 0.3457
# Epoch 78/100
# 1563/1563 [==============================] - 46s 29ms/step - loss: 4.0299 - accuracy: 0.3450
# Epoch 79/100
# 1563/1563 [==============================] - 46s 30ms/step - loss: 4.0247 - accuracy: 0.3475
# Epoch 80/100
# 1563/1563 [==============================] - 46s 29ms/step - loss: 4.0243 - accuracy: 0.3464
# Epoch 81/100
# 1563/1563 [==============================] - 46s 29ms/step - loss: 4.0204 - accuracy: 0.3491
# Epoch 82/100
# 1563/1563 [==============================] - 46s 29ms/step - loss: 4.0180 - accuracy: 0.3496
# Epoch 83/100
# 1563/1563 [==============================] - 46s 30ms/step - loss: 4.0160 - accuracy: 0.3521
# Epoch 84/100
# 1563/1563 [==============================] - 47s 30ms/step - loss: 4.0172 - accuracy: 0.3491
# Epoch 85/100
# 1563/1563 [==============================] - 47s 30ms/step - loss: 4.0177 - accuracy: 0.3487
# Epoch 86/100
# 1563/1563 [==============================] - 47s 30ms/step - loss: 4.0139 - accuracy: 0.3510
# Epoch 87/100
# 1563/1563 [==============================] - 47s 30ms/step - loss: 4.0121 - accuracy: 0.3512
# Epoch 88/100
# 1563/1563 [==============================] - 47s 30ms/step - loss: 4.0111 - accuracy: 0.3513
# Epoch 89/100
# 1563/1563 [==============================] - 47s 30ms/step - loss: 4.0081 - accuracy: 0.3532
# Epoch 90/100
# 1563/1563 [==============================] - 47s 30ms/step - loss: 4.0063 - accuracy: 0.3557
# Epoch 91/100
# 1563/1563 [==============================] - 47s 30ms/step - loss: 4.0091 - accuracy: 0.3572
# Epoch 92/100
# 1563/1563 [==============================] - 47s 30ms/step - loss: 4.0064 - accuracy: 0.3555
# Epoch 93/100
# 1563/1563 [==============================] - 47s 30ms/step - loss: 4.0033 - accuracy: 0.3559
# Epoch 94/100
# 1563/1563 [==============================] - 47s 30ms/step - loss: 4.0061 - accuracy: 0.3534
# Epoch 95/100
# 1563/1563 [==============================] - 47s 30ms/step - loss: 4.0029 - accuracy: 0.3558
# Epoch 96/100
# 1563/1563 [==============================] - 47s 30ms/step - loss: 4.0024 - accuracy: 0.3553
# Epoch 97/100
# 1563/1563 [==============================] - 47s 30ms/step - loss: 3.9996 - accuracy: 0.3566
# Epoch 98/100
# 1563/1563 [==============================] - 47s 30ms/step - loss: 3.9959 - accuracy: 0.3583
# Epoch 99/100
# 1563/1563 [==============================] - 47s 30ms/step - loss: 3.9980 - accuracy: 0.3584
# Epoch 100/100
# 1563/1563 [==============================] - 47s 30ms/step - loss: 4.0005 - accuracy: 0.3581

# %%
import matplotlib.pyplot as plt

plt.plot(history_resnet34.history['loss'], 'r')
plt.plot(history_plain34.history['loss'], 'b')
plt.title('Model training loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['ResNet18','Plain18'], loc='upper left')
plt.show()

# %%
plt.plot(history_resnet34.history['accuracy'], 'r')
plt.plot(history_plain34.history['accuracy'], 'b')
plt.title('Model validation accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['ResNet18', 'Plain18'], loc='upper left')
plt.show()
