# %%
import tensorflow as tf 
from tensorflow.keras import backend, regularizers, initializers, models
from tensorflow.keras import layers
from tensorflow import keras
from tensorflow.keras.utils import plot_model


def _gen_l2_regularizer(use_l2_regularizer=True, l2_weight_decay=1e-4):
  return regularizers.l2(l2_weight_decay) if use_l2_regularizer else None

# %%
cifar100 = keras.datasets.cifar100

(x_train, y_train), (x_test, y_test) = cifar100.load_data()
x_train, x_test = x_train / 255.0, x_test / 255.0

print("x_train:", len(x_train), "x_test:", len(x_test))
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz
# 169009152/169001437 [==============================] - 7s 0us/step
# 169017344/169001437 [==============================] - 7s 0us/step
# x_train: 50000 x_test: 10000

# %%
def plain_conv_block(input_tensor,
               filters,
               stage,
               block,
               strides=(2,2),
               use_l2_regularizer=True,
               bn_decay=0.9,
               bn_epsilon=1e-5):
  

  if backend.image_data_format() == 'channels_last':
    bn_axis=3
  else:
    bn_axis=1

  conv_name='conv'+str(stage)+block+'_branch'
  bn_name='bn'+str(stage)+block+'_branch'

  x = layers.Conv2D(filters,(3,3),strides=strides,padding='same',use_bias=False,kernel_initializer='he_normal',
                    kernel_regularizer=_gen_l2_regularizer(use_l2_regularizer),
                    name = conv_name+'2a')(input_tensor)

  x = layers.BatchNormalization(axis=bn_axis, momentum=bn_decay, epsilon=bn_epsilon,name=bn_name+'2a')(x)

  x = layers.Activation('relu')(x)
  
  x = layers.Conv2D(filters,(3,3),use_bias=False,padding='same',kernel_initializer='he_normal',
                    kernel_regularizer=_gen_l2_regularizer(use_l2_regularizer),
                    name = conv_name+'2b')(x)

  x = layers.BatchNormalization(axis=bn_axis, momentum=bn_decay, epsilon=bn_epsilon,name=bn_name+'2b')(x)

  x = layers.Activation('relu')(x)

  return x

# %%
def plain_identity_block(input_tensor,
                   filters,
                   stage,
                   block,
                   use_l2_regularizer=True,
                   bn_decay=0.9,
                   bn_epsilon=1e-5):
  
  if backend.image_data_format() == 'channels_last':
    bn_axis=3
  else:
    bn_axis=1

  id_name='id'+str(stage)+block+'_branch'
  bn_name='bn'+str(stage)+block+'_branch'

  x = layers.Conv2D(filters,(3,3),padding='same',use_bias=False,kernel_initializer='he_normal',
                    kernel_regularizer=_gen_l2_regularizer(use_l2_regularizer),
                    name = id_name+'2a')(input_tensor)

  x = layers.BatchNormalization(axis=bn_axis,momentum=bn_decay, epsilon=bn_epsilon,name=bn_name+'2a')(x)

  x = layers.Activation('relu')(x)

  x = layers.Conv2D(filters,(3,3),padding='same',use_bias=False,kernel_initializer='he_normal',
                    kernel_regularizer=_gen_l2_regularizer(use_l2_regularizer),
                    name = id_name+'2b')(input_tensor)

  x = layers.BatchNormalization(axis=bn_axis,momentum=bn_decay, epsilon=bn_epsilon,name=bn_name+'2b')(x)
  
  x = layers.Activation('relu')(x)

  return x

# %%
def plain18(num_classes,
             batch_size=None,
             use_l2_regularizer=True,
             rescale_inputs=False,
             bn_decay=0.9,
             bn_epsilon=1e-5):
 

  input_shape = (32, 32, 3) 
  img_input = layers.Input(shape=input_shape, batch_size=batch_size)
  if rescale_inputs:
  
    x = layers.Lambda(
        lambda x: x * 255.0 - backend.constant(
            imagenet_preprocessing.CHANNEL_MEANS,
            shape=[1, 1, 3],
            dtype=x.dtype),
        name='rescale')(
            img_input)
  else:
    x = img_input

  if backend.image_data_format() == 'channels_first':
    x = layers.Permute((3, 1, 2))(x)
    bn_axis = 1
  else:  # channels_last
    bn_axis = 3

  block_config = dict(
      use_l2_regularizer=use_l2_regularizer,
      bn_decay=bn_decay,
      bn_epsilon=bn_epsilon)
  x = layers.ZeroPadding2D(padding=(3, 3), name='conv1_pad')(x)
  x = layers.Conv2D(
      64, (7, 7),
      strides=(2, 2),
      padding='valid',
      use_bias=False,
      kernel_initializer='he_normal',
      kernel_regularizer=_gen_l2_regularizer(use_l2_regularizer),
      name='conv1')(
          x)
  x = layers.BatchNormalization(
      axis=bn_axis,
      momentum=bn_decay,
      epsilon=bn_epsilon,
      name='bn_conv1')(
          x)
  x = layers.Activation('relu')(x)
  x = layers.MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)

  x = plain_identity_block(x, 64, stage=2, block='a', **block_config)
  x = plain_identity_block(x, 64, stage=2, block='b', **block_config)

  x = plain_conv_block(x,128, stage=3, block='a', **block_config)
  x = plain_identity_block(x, 128, stage=3, block='b', **block_config)

  x = plain_conv_block(x,256, stage=4, block='a', **block_config)
  x = plain_identity_block(x,256, stage=4, block='b', **block_config)

  x = plain_conv_block(x,512, stage=5, block='a', **block_config)
  x = plain_identity_block(x, 512, stage=5, block='b', **block_config)

  x = layers.GlobalAveragePooling2D()(x)
  x = layers.Dense(
      num_classes,
      kernel_initializer=initializers.RandomNormal(stddev=0.01),
      kernel_regularizer=_gen_l2_regularizer(use_l2_regularizer),
      bias_regularizer=_gen_l2_regularizer(use_l2_regularizer),
      name='fc1000')(
          x)

  x = layers.Activation('softmax', dtype='float32')(x)

  return models.Model(img_input, x, name='plain18')

# %%
plain_18 = plain18(num_classes=100)
plain_18.summary()
# Out:
# Model: "plain18"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 32, 32, 3)]       0
#
#  conv1_pad (ZeroPadding2D)   (None, 38, 38, 3)         0
#
#  conv1 (Conv2D)              (None, 16, 16, 64)        9408
#
#  bn_conv1 (BatchNormalizatio  (None, 16, 16, 64)       256
#  n)
#
#  activation (Activation)     (None, 16, 16, 64)        0
#
#  max_pooling2d (MaxPooling2D  (None, 8, 8, 64)         0
#  )
#
#  id2a_branch2b (Conv2D)      (None, 8, 8, 64)          36864
#
#  bn2a_branch2b (BatchNormali  (None, 8, 8, 64)         256
#  zation)
#
#  activation_2 (Activation)   (None, 8, 8, 64)          0
#
#  id2b_branch2b (Conv2D)      (None, 8, 8, 64)          36864
#
#  bn2b_branch2b (BatchNormali  (None, 8, 8, 64)         256
#  zation)
#
#  activation_4 (Activation)   (None, 8, 8, 64)          0
#
#  conv3a_branch2a (Conv2D)    (None, 4, 4, 128)         73728
#
#  bn3a_branch2a (BatchNormali  (None, 4, 4, 128)        512
#  zation)
#
#  activation_5 (Activation)   (None, 4, 4, 128)         0
#
#  conv3a_branch2b (Conv2D)    (None, 4, 4, 128)         147456
#
#  bn3a_branch2b (BatchNormali  (None, 4, 4, 128)        512
#  zation)
#
#  activation_6 (Activation)   (None, 4, 4, 128)         0
#
#  id3b_branch2b (Conv2D)      (None, 4, 4, 128)         147456
#
#  bn3b_branch2b (BatchNormali  (None, 4, 4, 128)        512
#  zation)
#
#  activation_8 (Activation)   (None, 4, 4, 128)         0
#
#  conv4a_branch2a (Conv2D)    (None, 2, 2, 256)         294912
#
#  bn4a_branch2a (BatchNormali  (None, 2, 2, 256)        1024
#  zation)
#
#  activation_9 (Activation)   (None, 2, 2, 256)         0
#
#  conv4a_branch2b (Conv2D)    (None, 2, 2, 256)         589824
#
#  bn4a_branch2b (BatchNormali  (None, 2, 2, 256)        1024
#  zation)
#
#  activation_10 (Activation)  (None, 2, 2, 256)         0
#
#  id4b_branch2b (Conv2D)      (None, 2, 2, 256)         589824
#
#  bn4b_branch2b (BatchNormali  (None, 2, 2, 256)        1024
#  zation)
#
#  activation_12 (Activation)  (None, 2, 2, 256)         0
#
#  conv5a_branch2a (Conv2D)    (None, 1, 1, 512)         1179648
#
#  bn5a_branch2a (BatchNormali  (None, 1, 1, 512)        2048
#  zation)
#
#  activation_13 (Activation)  (None, 1, 1, 512)         0
#
#  conv5a_branch2b (Conv2D)    (None, 1, 1, 512)         2359296
#
#  bn5a_branch2b (BatchNormali  (None, 1, 1, 512)        2048
#  zation)
#
#  activation_14 (Activation)  (None, 1, 1, 512)         0
#
#  id5b_branch2b (Conv2D)      (None, 1, 1, 512)         2359296
#
#  bn5b_branch2b (BatchNormali  (None, 1, 1, 512)        2048
#  zation)
#
#  activation_16 (Activation)  (None, 1, 1, 512)         0
#
#  global_average_pooling2d (G  (None, 512)              0
#  lobalAveragePooling2D)
#
#  fc1000 (Dense)              (None, 100)               51300
#
#  activation_17 (Activation)  (None, 100)               0
#
# =================================================================
# Total params: 7,887,396
# Trainable params: 7,881,636
# Non-trainable params: 5,760
# _________________________________________________________________

# %%
plot_model(plain_18,show_shapes=True)

# %%
plain_18.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

history_plain18 = plain_18.fit(x_train, y_train, epochs=1000)

# %%
def conv_block(input_tensor,
               filters,
               stage,
               block,
               strides=(2,2),
               use_l2_regularizer=True,
               bn_decay=0.9,
               bn_epsilon=1e-5):
  

  if backend.image_data_format() == 'channels_last':
    bn_axis=3
  else:
    bn_axis=1

  conv_name='conv'+str(stage)+block+'_branch'
  bn_name='bn'+str(stage)+block+'_branch'

  x = layers.Conv2D(filters,(3,3),strides=strides,padding='same',use_bias=False,kernel_initializer='he_normal',
                    kernel_regularizer=_gen_l2_regularizer(use_l2_regularizer),
                    name = conv_name+'2a')(input_tensor)

  x = layers.BatchNormalization(axis=bn_axis, momentum=bn_decay, epsilon=bn_epsilon,name=bn_name+'2a')(x)

  x = layers.Activation('relu')(x)
  
  x = layers.Conv2D(filters,(3,3),use_bias=False,padding='same',kernel_initializer='he_normal',
                    kernel_regularizer=_gen_l2_regularizer(use_l2_regularizer),
                    name = conv_name+'2b')(x)

  x = layers.BatchNormalization(axis=bn_axis, momentum=bn_decay, epsilon=bn_epsilon,name=bn_name+'2b')(x)


  shortcut = layers.Conv2D(filters,(3,3),strides=strides,padding='same',use_bias=False,kernel_initializer='he_normal',
                           kernel_regularizer=_gen_l2_regularizer(use_l2_regularizer),
                           name = conv_name+'1')(input_tensor)

  shortcut = layers.BatchNormalization(axis=bn_axis, momentum=bn_decay, epsilon=bn_epsilon,name=bn_name+'1')(shortcut)

  x = layers.add([x, shortcut])

  x = layers.Activation('relu')(x)

  return x

# %%
def identity_block(input_tensor,
                   filters,
                   stage,
                   block,
                   use_l2_regularizer=True,
                   bn_decay=0.9,
                   bn_epsilon=1e-5):
  
  if backend.image_data_format() == 'channels_last':
    bn_axis=3
  else:
    bn_axis=1

  id_name='id'+str(stage)+block+'_branch'
  bn_name='bn'+str(stage)+block+'_branch'

  x = layers.Conv2D(filters,(3,3),padding='same',use_bias=False,kernel_initializer='he_normal',
                    kernel_regularizer=_gen_l2_regularizer(use_l2_regularizer),
                    name = id_name+'2a')(input_tensor)

  x = layers.BatchNormalization(axis=bn_axis,momentum=bn_decay, epsilon=bn_epsilon,name=bn_name+'2a')(x)

  x = layers.Activation('relu')(x)

  x = layers.Conv2D(filters,(3,3),padding='same',use_bias=False,kernel_initializer='he_normal',
                    kernel_regularizer=_gen_l2_regularizer(use_l2_regularizer),
                    name = id_name+'2b')(x)

  x = layers.BatchNormalization(axis=bn_axis,momentum=bn_decay, epsilon=bn_epsilon,name=bn_name+'2b')(x)

  x = layers.add([x,input_tensor])
  
  x = layers.Activation('relu')(x)

  return x

# %%
def resnet18(num_classes,
             batch_size=None,
             use_l2_regularizer=True,
             rescale_inputs=False,
             bn_decay=0.9,
             bn_epsilon=1e-5):

  input_shape = (32, 32, 3)
  img_input = layers.Input(shape=input_shape, batch_size=batch_size)
  if rescale_inputs:
    x = layers.Lambda(
        lambda x: x * 255.0 - backend.constant(
            imagenet_preprocessing.CHANNEL_MEANS,
            shape=[1, 1, 3],
            dtype=x.dtype),
        name='rescale')(
            img_input)
  else:
    x = img_input

  if backend.image_data_format() == 'channels_first':
    x = layers.Permute((3, 1, 2))(x)
    bn_axis = 1
  else:  
    bn_axis = 3

  block_config = dict(
      use_l2_regularizer=use_l2_regularizer,
      bn_decay=bn_decay,
      bn_epsilon=bn_epsilon)
  x = layers.ZeroPadding2D(padding=(3, 3), name='conv1_pad')(x)
  x = layers.Conv2D(
      64, (7, 7),
      strides=(2, 2),
      padding='valid',
      use_bias=False,
      kernel_initializer='he_normal',
      kernel_regularizer=_gen_l2_regularizer(use_l2_regularizer),
      name='conv1')(
          x)
  x = layers.BatchNormalization(
      axis=bn_axis,
      momentum=bn_decay,
      epsilon=bn_epsilon,
      name='bn_conv1')(
          x)
  x = layers.Activation('relu')(x)
  x = layers.MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)

  x = identity_block(x, 64, stage=2, block='a', **block_config)
  x = identity_block(x, 64, stage=2, block='b', **block_config)

  x = conv_block(x,128, stage=3, block='a', **block_config)
  x = identity_block(x, 128, stage=3, block='b', **block_config)

  x = conv_block(x,256, stage=4, block='a', **block_config)
  x = identity_block(x,256, stage=4, block='b', **block_config)

  x = conv_block(x,512, stage=5, block='a', **block_config)
  x = identity_block(x, 512, stage=5, block='b', **block_config)

  x = layers.GlobalAveragePooling2D()(x)
  x = layers.Dense(
      num_classes,
      kernel_initializer=initializers.RandomNormal(stddev=0.01),
      kernel_regularizer=_gen_l2_regularizer(use_l2_regularizer),
      bias_regularizer=_gen_l2_regularizer(use_l2_regularizer),
      name='fc1000')(
          x)

  x = layers.Activation('softmax', dtype='float32')(x)

  return models.Model(img_input, x, name='resnet18')

# %%
resnet_18 = resnet18(num_classes=100)
resnet_18.summary()
# Out:
# Model: "resnet18"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 32, 32, 3)]  0           []
#
#  conv1_pad (ZeroPadding2D)      (None, 38, 38, 3)    0           ['input_2[0][0]']
#
#  conv1 (Conv2D)                 (None, 16, 16, 64)   9408        ['conv1_pad[0][0]']
#
#  bn_conv1 (BatchNormalization)  (None, 16, 16, 64)   256         ['conv1[0][0]']
#
#  activation_18 (Activation)     (None, 16, 16, 64)   0           ['bn_conv1[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 8, 8, 64)    0           ['activation_18[0][0]']
#
#  id2a_branch2a (Conv2D)         (None, 8, 8, 64)     36864       ['max_pooling2d_1[0][0]']
#
#  bn2a_branch2a (BatchNormalizat  (None, 8, 8, 64)    256         ['id2a_branch2a[0][0]']
#  ion)
#
#  activation_19 (Activation)     (None, 8, 8, 64)     0           ['bn2a_branch2a[0][0]']
#
#  id2a_branch2b (Conv2D)         (None, 8, 8, 64)     36864       ['activation_19[0][0]']
#
#  bn2a_branch2b (BatchNormalizat  (None, 8, 8, 64)    256         ['id2a_branch2b[0][0]']
#  ion)
#
#  add (Add)                      (None, 8, 8, 64)     0           ['bn2a_branch2b[0][0]',
#                                                                   'max_pooling2d_1[0][0]']
#
#  activation_20 (Activation)     (None, 8, 8, 64)     0           ['add[0][0]']
#
#  id2b_branch2a (Conv2D)         (None, 8, 8, 64)     36864       ['activation_20[0][0]']
#
#  bn2b_branch2a (BatchNormalizat  (None, 8, 8, 64)    256         ['id2b_branch2a[0][0]']
#  ion)
#
#  activation_21 (Activation)     (None, 8, 8, 64)     0           ['bn2b_branch2a[0][0]']
#
#  id2b_branch2b (Conv2D)         (None, 8, 8, 64)     36864       ['activation_21[0][0]']
#
#  bn2b_branch2b (BatchNormalizat  (None, 8, 8, 64)    256         ['id2b_branch2b[0][0]']
#  ion)
#
#  add_1 (Add)                    (None, 8, 8, 64)     0           ['bn2b_branch2b[0][0]',
#                                                                   'activation_20[0][0]']
#
#  activation_22 (Activation)     (None, 8, 8, 64)     0           ['add_1[0][0]']
#
#  conv3a_branch2a (Conv2D)       (None, 4, 4, 128)    73728       ['activation_22[0][0]']
#
#  bn3a_branch2a (BatchNormalizat  (None, 4, 4, 128)   512         ['conv3a_branch2a[0][0]']
#  ion)
#
#  activation_23 (Activation)     (None, 4, 4, 128)    0           ['bn3a_branch2a[0][0]']
#
#  conv3a_branch2b (Conv2D)       (None, 4, 4, 128)    147456      ['activation_23[0][0]']
#
#  conv3a_branch1 (Conv2D)        (None, 4, 4, 128)    73728       ['activation_22[0][0]']
#
#  bn3a_branch2b (BatchNormalizat  (None, 4, 4, 128)   512         ['conv3a_branch2b[0][0]']
#  ion)
#
#  bn3a_branch1 (BatchNormalizati  (None, 4, 4, 128)   512         ['conv3a_branch1[0][0]']
#  on)
#
#  add_2 (Add)                    (None, 4, 4, 128)    0           ['bn3a_branch2b[0][0]',
#                                                                   'bn3a_branch1[0][0]']
#
#  activation_24 (Activation)     (None, 4, 4, 128)    0           ['add_2[0][0]']
#
#  id3b_branch2a (Conv2D)         (None, 4, 4, 128)    147456      ['activation_24[0][0]']
#
#  bn3b_branch2a (BatchNormalizat  (None, 4, 4, 128)   512         ['id3b_branch2a[0][0]']
#  ion)
#
#  activation_25 (Activation)     (None, 4, 4, 128)    0           ['bn3b_branch2a[0][0]']
#
#  id3b_branch2b (Conv2D)         (None, 4, 4, 128)    147456      ['activation_25[0][0]']
#
#  bn3b_branch2b (BatchNormalizat  (None, 4, 4, 128)   512         ['id3b_branch2b[0][0]']
#  ion)
#
#  add_3 (Add)                    (None, 4, 4, 128)    0           ['bn3b_branch2b[0][0]',
#                                                                   'activation_24[0][0]']
#
#  activation_26 (Activation)     (None, 4, 4, 128)    0           ['add_3[0][0]']
#
#  conv4a_branch2a (Conv2D)       (None, 2, 2, 256)    294912      ['activation_26[0][0]']
#
#  bn4a_branch2a (BatchNormalizat  (None, 2, 2, 256)   1024        ['conv4a_branch2a[0][0]']
#  ion)
#
#  activation_27 (Activation)     (None, 2, 2, 256)    0           ['bn4a_branch2a[0][0]']
#
#  conv4a_branch2b (Conv2D)       (None, 2, 2, 256)    589824      ['activation_27[0][0]']
#
#  conv4a_branch1 (Conv2D)        (None, 2, 2, 256)    294912      ['activation_26[0][0]']
#
#  bn4a_branch2b (BatchNormalizat  (None, 2, 2, 256)   1024        ['conv4a_branch2b[0][0]']
#  ion)
#
#  bn4a_branch1 (BatchNormalizati  (None, 2, 2, 256)   1024        ['conv4a_branch1[0][0]']
#  on)
#
#  add_4 (Add)                    (None, 2, 2, 256)    0           ['bn4a_branch2b[0][0]',
#                                                                   'bn4a_branch1[0][0]']
#
#  activation_28 (Activation)     (None, 2, 2, 256)    0           ['add_4[0][0]']
#
#  id4b_branch2a (Conv2D)         (None, 2, 2, 256)    589824      ['activation_28[0][0]']
#
#  bn4b_branch2a (BatchNormalizat  (None, 2, 2, 256)   1024        ['id4b_branch2a[0][0]']
#  ion)
#
#  activation_29 (Activation)     (None, 2, 2, 256)    0           ['bn4b_branch2a[0][0]']
#
#  id4b_branch2b (Conv2D)         (None, 2, 2, 256)    589824      ['activation_29[0][0]']
#
#  bn4b_branch2b (BatchNormalizat  (None, 2, 2, 256)   1024        ['id4b_branch2b[0][0]']
#  ion)
#
#  add_5 (Add)                    (None, 2, 2, 256)    0           ['bn4b_branch2b[0][0]',
#                                                                   'activation_28[0][0]']
#
#  activation_30 (Activation)     (None, 2, 2, 256)    0           ['add_5[0][0]']
#
#  conv5a_branch2a (Conv2D)       (None, 1, 1, 512)    1179648     ['activation_30[0][0]']
#
#  bn5a_branch2a (BatchNormalizat  (None, 1, 1, 512)   2048        ['conv5a_branch2a[0][0]']
#  ion)
#
#  activation_31 (Activation)     (None, 1, 1, 512)    0           ['bn5a_branch2a[0][0]']
#
#  conv5a_branch2b (Conv2D)       (None, 1, 1, 512)    2359296     ['activation_31[0][0]']
#
#  conv5a_branch1 (Conv2D)        (None, 1, 1, 512)    1179648     ['activation_30[0][0]']
#
#  bn5a_branch2b (BatchNormalizat  (None, 1, 1, 512)   2048        ['conv5a_branch2b[0][0]']
#  ion)
#
#  bn5a_branch1 (BatchNormalizati  (None, 1, 1, 512)   2048        ['conv5a_branch1[0][0]']
#  on)
#
#  add_6 (Add)                    (None, 1, 1, 512)    0           ['bn5a_branch2b[0][0]',
#                                                                   'bn5a_branch1[0][0]']
#
#  activation_32 (Activation)     (None, 1, 1, 512)    0           ['add_6[0][0]']
#
#  id5b_branch2a (Conv2D)         (None, 1, 1, 512)    2359296     ['activation_32[0][0]']
#
#  bn5b_branch2a (BatchNormalizat  (None, 1, 1, 512)   2048        ['id5b_branch2a[0][0]']
#  ion)
#
#  activation_33 (Activation)     (None, 1, 1, 512)    0           ['bn5b_branch2a[0][0]']
#
#  id5b_branch2b (Conv2D)         (None, 1, 1, 512)    2359296     ['activation_33[0][0]']
#
#  bn5b_branch2b (BatchNormalizat  (None, 1, 1, 512)   2048        ['id5b_branch2b[0][0]']
#  ion)
#
#  add_7 (Add)                    (None, 1, 1, 512)    0           ['bn5b_branch2b[0][0]',
#                                                                   'activation_32[0][0]']
#
#  activation_34 (Activation)     (None, 1, 1, 512)    0           ['add_7[0][0]']
#
#  global_average_pooling2d_1 (Gl  (None, 512)         0           ['activation_34[0][0]']
#  obalAveragePooling2D)
#
#  fc1000 (Dense)                 (None, 100)          51300       ['global_average_pooling2d_1[0][0
#                                                                  ]']
#
#  activation_35 (Activation)     (None, 100)          0           ['fc1000[0][0]']
#
# ==================================================================================================
# Total params: 12,613,668
# Trainable params: 12,604,068
# Non-trainable params: 9,600
# __________________________________________________________________________________________________

# %%
plot_model(resnet_18, show_shapes=True)

# %%
resnet_18.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

history_resnet18 = resnet_18.fit(x_train, y_train, epochs=1000)

# %%
import matplotlib.pyplot as plt

plt.plot(history_resnet18.history['loss'], 'r')
plt.plot(history_plain18.history['loss'], 'b')
plt.title('Model training loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['ResNet18','Plain18'], loc='upper left')
plt.show()

# %%
plt.plot(history_resnet18.history['accuracy'], 'r')
plt.plot(history_plain18.history['accuracy'], 'b')
plt.title('Model validation accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['ResNet18', 'Plain18'], loc='upper left')
plt.show()
