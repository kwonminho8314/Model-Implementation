# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import backend, regularizers, initializers, models
from tensorflow.keras import layers
from tensorflow.keras.utils import plot_model

# %%
cifar100 = keras.datasets.cifar100

(x_train, y_train), (x_test, y_test) = cifar100.load_data()
x_train, x_test = x_train / 255.0, x_test / 255.0

print("x_train:", len(x_train), "x_test:", len(x_test))
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz
# 169009152/169001437 [==============================] - 4s 0us/step
# 169017344/169001437 [==============================] - 4s 0us/step
# x_train: 50000 x_test: 10000

# %%
def conv_block(input_tensor,
               filters,
               stage,
               block,
               strides=(2,2),
               use_l2_regularizer=True,
               bn_decay=0.9,
               bn_epsilon=1e-5):
  

  if backend.image_data_format() == 'channels_last':
    bn_axis=3
  else:
    bn_axis=1

  conv_name='conv'+str(stage)+block+'_branch'
  bn_name='bn'+str(stage)+block+'_branch'

  x = layers.Conv2D(filters,(3,3),strides=strides,padding='same',use_bias=False,kernel_initializer='he_normal',
                    kernel_regularizer=keras.regularizers.l2(1e-4),
                    name = conv_name+'2a')(input_tensor)

  x = layers.BatchNormalization(axis=bn_axis, momentum=bn_decay, epsilon=bn_epsilon,name=bn_name+'2a')(x)

  x = layers.Activation('relu')(x)
  
  x = layers.Conv2D(filters,(3,3),use_bias=False,padding='same',kernel_initializer='he_normal',
                    kernel_regularizer=keras.regularizers.l2(1e-4),
                    name = conv_name+'2b')(x)

  x = layers.BatchNormalization(axis=bn_axis, momentum=bn_decay, epsilon=bn_epsilon,name=bn_name+'2b')(x)


  shortcut = layers.Conv2D(filters,(3,3),strides=strides,padding='same',use_bias=False,kernel_initializer='he_normal',
                           kernel_regularizer=keras.regularizers.l2(1e-4),
                           name = conv_name+'1')(input_tensor)

  shortcut = layers.BatchNormalization(axis=bn_axis, momentum=bn_decay, epsilon=bn_epsilon,name=bn_name+'1')(shortcut)

  x = layers.add([x, shortcut])

  x = layers.Activation('relu')(x)

  return x

# %%
def identity_block(input_tensor,
                   filters,
                   stage,
                   block,
                   use_l2_regularizer=True,
                   bn_decay=0.9,
                   bn_epsilon=1e-5):
  
  if backend.image_data_format() == 'channels_last':
    bn_axis=3
  else:
    bn_axis=1

  id_name='id'+str(stage)+block+'_branch'
  bn_name='bn'+str(stage)+block+'_branch'

  x = layers.Conv2D(filters,(3,3),padding='same',use_bias=False,kernel_initializer='he_normal',
                    kernel_regularizer=keras.regularizers.l2(1e-4),
                    name = id_name+'2a')(input_tensor)

  x = layers.BatchNormalization(axis=bn_axis,momentum=bn_decay, epsilon=bn_epsilon,name=bn_name+'2a')(x)

  x = layers.Activation('relu')(x)

  x = layers.Conv2D(filters,(3,3),padding='same',use_bias=False,kernel_initializer='he_normal',
                    kernel_regularizer=keras.regularizers.l2(1e-4),
                    name = id_name+'2b')(x)

  x = layers.BatchNormalization(axis=bn_axis,momentum=bn_decay, epsilon=bn_epsilon,name=bn_name+'2b')(x)

  x = layers.add([x,input_tensor])
  
  x = layers.Activation('relu')(x)

  return x

# %%
def resnet18(num_classes,
             batch_size=None,
             use_l2_regularizer=True,
             rescale_inputs=False,
             bn_decay=0.9,
             bn_epsilon=1e-5):

  input_shape = (32, 32, 3)
  img_input = layers.Input(shape=input_shape, batch_size=batch_size)
  if rescale_inputs:
    x = layers.Lambda(
        lambda x: x * 255.0 - backend.constant(
            imagenet_preprocessing.CHANNEL_MEANS,
            shape=[1, 1, 3],
            dtype=x.dtype),
        name='rescale')(
            img_input)
  else:
    x = img_input

  if backend.image_data_format() == 'channels_first':
    x = layers.Permute((3, 1, 2))(x)
    bn_axis = 1
  else:  
    bn_axis = 3

  block_config = dict(
      use_l2_regularizer=use_l2_regularizer,
      bn_decay=bn_decay,
      bn_epsilon=bn_epsilon)
  x = layers.ZeroPadding2D(padding=(3, 3), name='conv1_pad')(x)
  x = layers.Conv2D(
      64, (7, 7),
      strides=(2, 2),
      padding='valid',
      use_bias=False,
      kernel_initializer='he_normal',
      kernel_regularizer=keras.regularizers.l2(1e-4),
      name='conv1')(
          x)
  x = layers.BatchNormalization(
      axis=bn_axis,
      momentum=bn_decay,
      epsilon=bn_epsilon,
      name='bn_conv1')(
          x)
  x = layers.Activation('relu')(x)
  x = layers.MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)

  x = identity_block(x, 64, stage=2, block='a', **block_config)
  x = identity_block(x, 64, stage=2, block='b', **block_config)

  x = conv_block(x,128, stage=3, block='a', **block_config)
  x = identity_block(x, 128, stage=3, block='b', **block_config)

  x = conv_block(x,256, stage=4, block='a', **block_config)
  x = identity_block(x,256, stage=4, block='b', **block_config)

  x = conv_block(x,512, stage=5, block='a', **block_config)
  x = identity_block(x, 512, stage=5, block='b', **block_config)

  x = layers.GlobalAveragePooling2D()(x)
  x = layers.Dense(
      num_classes,
      kernel_initializer=initializers.RandomNormal(stddev=0.01),
      kernel_regularizer=keras.regularizers.l2(1e-4),
      bias_regularizer=keras.regularizers.l2(1e-4),
      name='fc1000')(
          x)

  x = layers.Activation('softmax', dtype='float32')(x)

  return models.Model(img_input, x, name='resnet18')

# %%
resnet18 = resnet18(num_classes=100)
resnet18.summary()
# Out:
# Model: "resnet18"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 32, 32, 3)]  0           []
#
#  conv1_pad (ZeroPadding2D)      (None, 38, 38, 3)    0           ['input_1[0][0]']
#
#  conv1 (Conv2D)                 (None, 16, 16, 64)   9408        ['conv1_pad[0][0]']
#
#  bn_conv1 (BatchNormalization)  (None, 16, 16, 64)   256         ['conv1[0][0]']
#
#  activation (Activation)        (None, 16, 16, 64)   0           ['bn_conv1[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, 8, 8, 64)     0           ['activation[0][0]']
#
#  id2a_branch2a (Conv2D)         (None, 8, 8, 64)     36864       ['max_pooling2d[0][0]']
#
#  bn2a_branch2a (BatchNormalizat  (None, 8, 8, 64)    256         ['id2a_branch2a[0][0]']
#  ion)
#
#  activation_1 (Activation)      (None, 8, 8, 64)     0           ['bn2a_branch2a[0][0]']
#
#  id2a_branch2b (Conv2D)         (None, 8, 8, 64)     36864       ['activation_1[0][0]']
#
#  bn2a_branch2b (BatchNormalizat  (None, 8, 8, 64)    256         ['id2a_branch2b[0][0]']
#  ion)
#
#  add (Add)                      (None, 8, 8, 64)     0           ['bn2a_branch2b[0][0]',
#                                                                   'max_pooling2d[0][0]']
#
#  activation_2 (Activation)      (None, 8, 8, 64)     0           ['add[0][0]']
#
#  id2b_branch2a (Conv2D)         (None, 8, 8, 64)     36864       ['activation_2[0][0]']
#
#  bn2b_branch2a (BatchNormalizat  (None, 8, 8, 64)    256         ['id2b_branch2a[0][0]']
#  ion)
#
#  activation_3 (Activation)      (None, 8, 8, 64)     0           ['bn2b_branch2a[0][0]']
#
#  id2b_branch2b (Conv2D)         (None, 8, 8, 64)     36864       ['activation_3[0][0]']
#
#  bn2b_branch2b (BatchNormalizat  (None, 8, 8, 64)    256         ['id2b_branch2b[0][0]']
#  ion)
#
#  add_1 (Add)                    (None, 8, 8, 64)     0           ['bn2b_branch2b[0][0]',
#                                                                   'activation_2[0][0]']
#
#  activation_4 (Activation)      (None, 8, 8, 64)     0           ['add_1[0][0]']
#
#  conv3a_branch2a (Conv2D)       (None, 4, 4, 128)    73728       ['activation_4[0][0]']
#
#  bn3a_branch2a (BatchNormalizat  (None, 4, 4, 128)   512         ['conv3a_branch2a[0][0]']
#  ion)
#
#  activation_5 (Activation)      (None, 4, 4, 128)    0           ['bn3a_branch2a[0][0]']
#
#  conv3a_branch2b (Conv2D)       (None, 4, 4, 128)    147456      ['activation_5[0][0]']
#
#  conv3a_branch1 (Conv2D)        (None, 4, 4, 128)    73728       ['activation_4[0][0]']
#
#  bn3a_branch2b (BatchNormalizat  (None, 4, 4, 128)   512         ['conv3a_branch2b[0][0]']
#  ion)
#
#  bn3a_branch1 (BatchNormalizati  (None, 4, 4, 128)   512         ['conv3a_branch1[0][0]']
#  on)
#
#  add_2 (Add)                    (None, 4, 4, 128)    0           ['bn3a_branch2b[0][0]',
#                                                                   'bn3a_branch1[0][0]']
#
#  activation_6 (Activation)      (None, 4, 4, 128)    0           ['add_2[0][0]']
#
#  id3b_branch2a (Conv2D)         (None, 4, 4, 128)    147456      ['activation_6[0][0]']
#
#  bn3b_branch2a (BatchNormalizat  (None, 4, 4, 128)   512         ['id3b_branch2a[0][0]']
#  ion)
#
#  activation_7 (Activation)      (None, 4, 4, 128)    0           ['bn3b_branch2a[0][0]']
#
#  id3b_branch2b (Conv2D)         (None, 4, 4, 128)    147456      ['activation_7[0][0]']
#
#  bn3b_branch2b (BatchNormalizat  (None, 4, 4, 128)   512         ['id3b_branch2b[0][0]']
#  ion)
#
#  add_3 (Add)                    (None, 4, 4, 128)    0           ['bn3b_branch2b[0][0]',
#                                                                   'activation_6[0][0]']
#
#  activation_8 (Activation)      (None, 4, 4, 128)    0           ['add_3[0][0]']
#
#  conv4a_branch2a (Conv2D)       (None, 2, 2, 256)    294912      ['activation_8[0][0]']
#
#  bn4a_branch2a (BatchNormalizat  (None, 2, 2, 256)   1024        ['conv4a_branch2a[0][0]']
#  ion)
#
#  activation_9 (Activation)      (None, 2, 2, 256)    0           ['bn4a_branch2a[0][0]']
#
#  conv4a_branch2b (Conv2D)       (None, 2, 2, 256)    589824      ['activation_9[0][0]']
#
#  conv4a_branch1 (Conv2D)        (None, 2, 2, 256)    294912      ['activation_8[0][0]']
#
#  bn4a_branch2b (BatchNormalizat  (None, 2, 2, 256)   1024        ['conv4a_branch2b[0][0]']
#  ion)
#
#  bn4a_branch1 (BatchNormalizati  (None, 2, 2, 256)   1024        ['conv4a_branch1[0][0]']
#  on)
#
#  add_4 (Add)                    (None, 2, 2, 256)    0           ['bn4a_branch2b[0][0]',
#                                                                   'bn4a_branch1[0][0]']
#
#  activation_10 (Activation)     (None, 2, 2, 256)    0           ['add_4[0][0]']
#
#  id4b_branch2a (Conv2D)         (None, 2, 2, 256)    589824      ['activation_10[0][0]']
#
#  bn4b_branch2a (BatchNormalizat  (None, 2, 2, 256)   1024        ['id4b_branch2a[0][0]']
#  ion)
#
#  activation_11 (Activation)     (None, 2, 2, 256)    0           ['bn4b_branch2a[0][0]']
#
#  id4b_branch2b (Conv2D)         (None, 2, 2, 256)    589824      ['activation_11[0][0]']
#
#  bn4b_branch2b (BatchNormalizat  (None, 2, 2, 256)   1024        ['id4b_branch2b[0][0]']
#  ion)
#
#  add_5 (Add)                    (None, 2, 2, 256)    0           ['bn4b_branch2b[0][0]',
#                                                                   'activation_10[0][0]']
#
#  activation_12 (Activation)     (None, 2, 2, 256)    0           ['add_5[0][0]']
#
#  conv5a_branch2a (Conv2D)       (None, 1, 1, 512)    1179648     ['activation_12[0][0]']
#
#  bn5a_branch2a (BatchNormalizat  (None, 1, 1, 512)   2048        ['conv5a_branch2a[0][0]']
#  ion)
#
#  activation_13 (Activation)     (None, 1, 1, 512)    0           ['bn5a_branch2a[0][0]']
#
#  conv5a_branch2b (Conv2D)       (None, 1, 1, 512)    2359296     ['activation_13[0][0]']
#
#  conv5a_branch1 (Conv2D)        (None, 1, 1, 512)    1179648     ['activation_12[0][0]']
#
#  bn5a_branch2b (BatchNormalizat  (None, 1, 1, 512)   2048        ['conv5a_branch2b[0][0]']
#  ion)
#
#  bn5a_branch1 (BatchNormalizati  (None, 1, 1, 512)   2048        ['conv5a_branch1[0][0]']
#  on)
#
#  add_6 (Add)                    (None, 1, 1, 512)    0           ['bn5a_branch2b[0][0]',
#                                                                   'bn5a_branch1[0][0]']
#
#  activation_14 (Activation)     (None, 1, 1, 512)    0           ['add_6[0][0]']
#
#  id5b_branch2a (Conv2D)         (None, 1, 1, 512)    2359296     ['activation_14[0][0]']
#
#  bn5b_branch2a (BatchNormalizat  (None, 1, 1, 512)   2048        ['id5b_branch2a[0][0]']
#  ion)
#
#  activation_15 (Activation)     (None, 1, 1, 512)    0           ['bn5b_branch2a[0][0]']
#
#  id5b_branch2b (Conv2D)         (None, 1, 1, 512)    2359296     ['activation_15[0][0]']
#
#  bn5b_branch2b (BatchNormalizat  (None, 1, 1, 512)   2048        ['id5b_branch2b[0][0]']
#  ion)
#
#  add_7 (Add)                    (None, 1, 1, 512)    0           ['bn5b_branch2b[0][0]',
#                                                                   'activation_14[0][0]']
#
#  activation_16 (Activation)     (None, 1, 1, 512)    0           ['add_7[0][0]']
#
#  global_average_pooling2d (Glob  (None, 512)         0           ['activation_16[0][0]']
#  alAveragePooling2D)
#
#  fc1000 (Dense)                 (None, 100)          51300       ['global_average_pooling2d[0][0]'
#                                                                  ]
#
#  activation_17 (Activation)     (None, 100)          0           ['fc1000[0][0]']
#
# ==================================================================================================
# Total params: 12,613,668
# Trainable params: 12,604,068
# Non-trainable params: 9,600
# __________________________________________________________________________________________________

# %%
plot_model(resnet18,show_shapes=True)

# %%
resnet18.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

history_resnet18 = resnet18.fit(x_train, y_train, epochs=100)
# Out:
# Epoch 1/100
# 1563/1563 [==============================] - 40s 18ms/step - loss: 4.0622 - accuracy: 0.1432
# Epoch 2/100
# 1563/1563 [==============================] - 28s 18ms/step - loss: 3.1901 - accuracy: 0.2849
# Epoch 3/100
# 1563/1563 [==============================] - 28s 18ms/step - loss: 2.8393 - accuracy: 0.3609
# Epoch 4/100
# 1563/1563 [==============================] - 28s 18ms/step - loss: 2.6407 - accuracy: 0.4137
# Epoch 5/100
# 1563/1563 [==============================] - 28s 18ms/step - loss: 2.4830 - accuracy: 0.4580
# Epoch 6/100
# 1563/1563 [==============================] - 28s 18ms/step - loss: 2.3423 - accuracy: 0.5047
# Epoch 7/100
# 1563/1563 [==============================] - 28s 18ms/step - loss: 2.2243 - accuracy: 0.5396
# Epoch 8/100
# 1563/1563 [==============================] - 28s 18ms/step - loss: 2.0909 - accuracy: 0.5826
# Epoch 9/100
# 1563/1563 [==============================] - 28s 18ms/step - loss: 1.9884 - accuracy: 0.6205
# Epoch 10/100
# 1563/1563 [==============================] - 28s 18ms/step - loss: 1.8894 - accuracy: 0.6552
# Epoch 11/100
# 1563/1563 [==============================] - 28s 18ms/step - loss: 1.7960 - accuracy: 0.6931
# Epoch 12/100
# 1563/1563 [==============================] - 28s 18ms/step - loss: 1.7209 - accuracy: 0.7240
# Epoch 13/100
# 1563/1563 [==============================] - 28s 18ms/step - loss: 1.6434 - accuracy: 0.7550
# Epoch 14/100
# 1563/1563 [==============================] - 28s 18ms/step - loss: 1.6017 - accuracy: 0.7745
# Epoch 15/100
# 1563/1563 [==============================] - 28s 18ms/step - loss: 1.5670 - accuracy: 0.7940
# Epoch 16/100
# 1563/1563 [==============================] - 28s 18ms/step - loss: 1.5375 - accuracy: 0.8071
# Epoch 17/100
# 1563/1563 [==============================] - 28s 18ms/step - loss: 1.5361 - accuracy: 0.8154
# Epoch 18/100
# 1563/1563 [==============================] - 27s 18ms/step - loss: 1.5234 - accuracy: 0.8223
# Epoch 19/100
# 1563/1563 [==============================] - 27s 18ms/step - loss: 1.4906 - accuracy: 0.8380
# Epoch 20/100
# 1563/1563 [==============================] - 28s 18ms/step - loss: 1.4967 - accuracy: 0.8392
# Epoch 21/100
# 1563/1563 [==============================] - 28s 18ms/step - loss: 1.4961 - accuracy: 0.8440
# Epoch 22/100
# 1563/1563 [==============================] - 28s 18ms/step - loss: 1.4850 - accuracy: 0.8487
# Epoch 23/100
# 1563/1563 [==============================] - 28s 18ms/step - loss: 1.4684 - accuracy: 0.8549
# Epoch 24/100
# 1563/1563 [==============================] - 28s 18ms/step - loss: 1.4747 - accuracy: 0.8559
# Epoch 25/100
# 1563/1563 [==============================] - 28s 18ms/step - loss: 1.4658 - accuracy: 0.8590
# Epoch 26/100
# 1563/1563 [==============================] - 28s 18ms/step - loss: 1.4534 - accuracy: 0.8630
# Epoch 27/100
# 1563/1563 [==============================] - 28s 18ms/step - loss: 1.4658 - accuracy: 0.8613
# Epoch 28/100
# 1563/1563 [==============================] - 28s 18ms/step - loss: 1.4519 - accuracy: 0.8671
# Epoch 29/100
# 1563/1563 [==============================] - 28s 18ms/step - loss: 1.4353 - accuracy: 0.8724
# Epoch 30/100
# 1563/1563 [==============================] - 28s 18ms/step - loss: 1.4481 - accuracy: 0.8681
# Epoch 31/100
# 1563/1563 [==============================] - 28s 18ms/step - loss: 1.4322 - accuracy: 0.8721
# Epoch 32/100
# 1563/1563 [==============================] - 28s 18ms/step - loss: 1.4361 - accuracy: 0.8736
# Epoch 33/100
# 1563/1563 [==============================] - 28s 18ms/step - loss: 1.4220 - accuracy: 0.8762
# Epoch 34/100
# 1563/1563 [==============================] - 28s 18ms/step - loss: 1.4305 - accuracy: 0.8730
# Epoch 35/100
# 1563/1563 [==============================] - 28s 18ms/step - loss: 1.4287 - accuracy: 0.8750
# Epoch 36/100
# 1563/1563 [==============================] - 28s 18ms/step - loss: 1.4125 - accuracy: 0.8791
# Epoch 37/100
# 1563/1563 [==============================] - 28s 18ms/step - loss: 1.4139 - accuracy: 0.8787
# Epoch 38/100
# 1563/1563 [==============================] - 28s 18ms/step - loss: 1.4089 - accuracy: 0.8794
# Epoch 39/100
# 1563/1563 [==============================] - 28s 18ms/step - loss: 1.4068 - accuracy: 0.8803
# Epoch 40/100
# 1563/1563 [==============================] - 28s 18ms/step - loss: 1.4151 - accuracy: 0.8792
# Epoch 41/100
# 1563/1563 [==============================] - 28s 18ms/step - loss: 1.3992 - accuracy: 0.8837
# Epoch 42/100
# 1563/1563 [==============================] - 28s 18ms/step - loss: 1.3944 - accuracy: 0.8821
# Epoch 43/100
# 1563/1563 [==============================] - 28s 18ms/step - loss: 1.4034 - accuracy: 0.8825
# Epoch 44/100
# 1563/1563 [==============================] - 28s 18ms/step - loss: 1.3926 - accuracy: 0.8840
# Epoch 45/100
# 1563/1563 [==============================] - 28s 18ms/step - loss: 1.3919 - accuracy: 0.8858
# Epoch 46/100
# 1563/1563 [==============================] - 28s 18ms/step - loss: 1.3968 - accuracy: 0.8820
# Epoch 47/100
# 1563/1563 [==============================] - 28s 18ms/step - loss: 1.3747 - accuracy: 0.8879
# Epoch 48/100
# 1563/1563 [==============================] - 28s 18ms/step - loss: 1.3798 - accuracy: 0.8864
# Epoch 49/100
# 1563/1563 [==============================] - 28s 18ms/step - loss: 1.3797 - accuracy: 0.8857
# Epoch 50/100
# 1563/1563 [==============================] - 28s 18ms/step - loss: 1.3797 - accuracy: 0.8861
# Epoch 51/100
# 1563/1563 [==============================] - 28s 18ms/step - loss: 1.3645 - accuracy: 0.8901
# Epoch 52/100
# 1563/1563 [==============================] - 28s 18ms/step - loss: 1.3744 - accuracy: 0.8866
# Epoch 53/100
# 1563/1563 [==============================] - 28s 18ms/step - loss: 1.3695 - accuracy: 0.8872
# Epoch 54/100
# 1563/1563 [==============================] - 28s 18ms/step - loss: 1.3602 - accuracy: 0.8888
# Epoch 55/100
# 1563/1563 [==============================] - 28s 18ms/step - loss: 1.3592 - accuracy: 0.8909
# Epoch 56/100
# 1563/1563 [==============================] - 28s 18ms/step - loss: 1.3611 - accuracy: 0.8909
# Epoch 57/100
# 1563/1563 [==============================] - 28s 18ms/step - loss: 1.3483 - accuracy: 0.8935
# Epoch 58/100
# 1563/1563 [==============================] - 28s 18ms/step - loss: 1.3475 - accuracy: 0.8924
# Epoch 59/100
# 1563/1563 [==============================] - 28s 18ms/step - loss: 1.3506 - accuracy: 0.8927
# Epoch 60/100
# 1563/1563 [==============================] - 28s 18ms/step - loss: 1.3523 - accuracy: 0.8908
# Epoch 61/100
# 1563/1563 [==============================] - 28s 18ms/step - loss: 1.3591 - accuracy: 0.8899
# Epoch 62/100
# 1563/1563 [==============================] - 28s 18ms/step - loss: 1.3437 - accuracy: 0.8943
# Epoch 63/100
# 1563/1563 [==============================] - 28s 18ms/step - loss: 1.3445 - accuracy: 0.8914
# Epoch 64/100
# 1563/1563 [==============================] - 28s 18ms/step - loss: 1.3421 - accuracy: 0.8918
# Epoch 65/100
# 1563/1563 [==============================] - 28s 18ms/step - loss: 1.3510 - accuracy: 0.8884
# Epoch 66/100
# 1563/1563 [==============================] - 28s 18ms/step - loss: 1.3323 - accuracy: 0.8939
# Epoch 67/100
# 1563/1563 [==============================] - 28s 18ms/step - loss: 1.3450 - accuracy: 0.8889
# Epoch 68/100
# 1563/1563 [==============================] - 28s 18ms/step - loss: 1.3344 - accuracy: 0.8948
# Epoch 69/100
# 1563/1563 [==============================] - 28s 18ms/step - loss: 1.3362 - accuracy: 0.8925
# Epoch 70/100
# 1563/1563 [==============================] - 28s 18ms/step - loss: 1.3350 - accuracy: 0.8943
# Epoch 71/100
# 1563/1563 [==============================] - 28s 18ms/step - loss: 1.3313 - accuracy: 0.8940
# Epoch 72/100
# 1563/1563 [==============================] - 28s 18ms/step - loss: 1.3359 - accuracy: 0.8931
# Epoch 73/100
# 1563/1563 [==============================] - 28s 18ms/step - loss: 1.3355 - accuracy: 0.8937
# Epoch 74/100
# 1563/1563 [==============================] - 28s 18ms/step - loss: 1.3204 - accuracy: 0.8964
# Epoch 75/100
# 1563/1563 [==============================] - 28s 18ms/step - loss: 1.3292 - accuracy: 0.8942
# Epoch 76/100
# 1563/1563 [==============================] - 28s 18ms/step - loss: 1.3196 - accuracy: 0.8965
# Epoch 77/100
# 1563/1563 [==============================] - 28s 18ms/step - loss: 1.3260 - accuracy: 0.8944
# Epoch 78/100
# 1563/1563 [==============================] - 28s 18ms/step - loss: 1.3165 - accuracy: 0.8976
# Epoch 79/100
# 1563/1563 [==============================] - 28s 18ms/step - loss: 1.3160 - accuracy: 0.8954
# Epoch 80/100
# 1563/1563 [==============================] - 28s 18ms/step - loss: 1.3283 - accuracy: 0.8925
# Epoch 81/100
# 1563/1563 [==============================] - 28s 18ms/step - loss: 1.3013 - accuracy: 0.9016
# Epoch 82/100
# 1563/1563 [==============================] - 28s 18ms/step - loss: 1.3117 - accuracy: 0.8969
# Epoch 83/100
# 1563/1563 [==============================] - 28s 18ms/step - loss: 1.3096 - accuracy: 0.8979
# Epoch 84/100
# 1563/1563 [==============================] - 28s 18ms/step - loss: 1.3099 - accuracy: 0.8965
# Epoch 85/100
# 1563/1563 [==============================] - 28s 18ms/step - loss: 1.3175 - accuracy: 0.8952
# Epoch 86/100
# 1563/1563 [==============================] - 28s 18ms/step - loss: 1.3098 - accuracy: 0.8953
# Epoch 87/100
# 1563/1563 [==============================] - 28s 18ms/step - loss: 1.3064 - accuracy: 0.8979
# Epoch 88/100
# 1563/1563 [==============================] - 28s 18ms/step - loss: 1.3046 - accuracy: 0.8979
# Epoch 89/100
# 1563/1563 [==============================] - 28s 18ms/step - loss: 1.2974 - accuracy: 0.8997
# Epoch 90/100
# 1563/1563 [==============================] - 28s 18ms/step - loss: 1.3145 - accuracy: 0.8965
# Epoch 91/100
# 1563/1563 [==============================] - 28s 18ms/step - loss: 1.2901 - accuracy: 0.9019
# Epoch 92/100
# 1563/1563 [==============================] - 28s 18ms/step - loss: 1.3007 - accuracy: 0.8976
# Epoch 93/100
# 1563/1563 [==============================] - 28s 18ms/step - loss: 1.2988 - accuracy: 0.8984
# Epoch 94/100
# 1563/1563 [==============================] - 28s 18ms/step - loss: 1.2915 - accuracy: 0.9000
# Epoch 95/100
# 1563/1563 [==============================] - 28s 18ms/step - loss: 1.2924 - accuracy: 0.8991
# Epoch 96/100
# 1563/1563 [==============================] - 28s 18ms/step - loss: 1.2913 - accuracy: 0.8974
# Epoch 97/100
# 1563/1563 [==============================] - 28s 18ms/step - loss: 1.3012 - accuracy: 0.8967
# Epoch 98/100
# 1563/1563 [==============================] - 28s 18ms/step - loss: 1.2855 - accuracy: 0.9008
# Epoch 99/100
# 1563/1563 [==============================] - 28s 18ms/step - loss: 1.2958 - accuracy: 0.8986
# Epoch 100/100
# 1563/1563 [==============================] - 28s 18ms/step - loss: 1.2838 - accuracy: 0.9014

# %%
#BN-ReLU-Conv(1×1)-BN-ReLU-Conv(3×3)
def dense_block(input_tensor,
                filters,
                stage,
                block,
                bn_decay=0.9,
                bn_epsilon=1e-5):
  filters1,filters2=filters

  if backend.image_data_format() == 'channels_last':
    bn_axis=3
  else:
    bn_axis=1

  dense_name='dense'+str(stage)+block+'_branch'
  bn_name='bn'+str(stage)+block+'_branch'

  x = layers.BatchNormalization(axis=bn_axis,
                                momentum=bn_decay,
                                epsilon=bn_epsilon,
                                name=bn_name+'2a')(input_tensor)

  x = layers.Activation('relu')(x)

  x = layers.Conv2D(filters1,(1,1),use_bias=False,
                    kernel_initializer='he_normal',
                    kernel_regularizer=keras.regularizers.l2(1e-4),
                    name=dense_name+'2a')(x)

  x = layers.BatchNormalization(axis=bn_axis,
                                momentum=bn_decay,
                                epsilon=bn_epsilon,
                                name=bn_name+'2b')(x)
  
  x = layers.Activation('relu')(x)

  x = layers.Conv2D(filters2,(3,3),padding='same',use_bias=False,
                    kernel_initializer='he_normal',
                    kernel_regularizer=keras.regularizers.l2(1e-4),
                    name=dense_name+'2b')(x)

  x = layers.concatenate([x,input_tensor])

  return x

# %%
#BN → 1×1 convolutional layer → 2×2 average pooling layer
def transition_block(input_tensor,
                     filters,
                     stage,
                     block,
                     bn_decay=0.9,
                     bn_epsilon=1e-5):
  if backend.image_data_format() == 'channels_last':
    bn_axis=3
  else:
    bn_axis=1

  transition_name = 'transition'+str(stage)+block+'_branch'
  bn_name='bn'+str(stage)+block+'_branch'

  x = layers.BatchNormalization(axis=bn_axis,
                                momentum=bn_decay,
                                epsilon=bn_epsilon,
                                name=bn_name+'2a')(input_tensor)

  x = layers.Conv2D(filters,(1,1),use_bias=False,
                    kernel_initializer='he_normal',
                    kernel_regularizer=keras.regularizers.l2(1e-4),
                    name=transition_name+'2a')(x)

  x = layers.AveragePooling2D(pool_size=(2,2),strides=(2,2),padding='same')(x)

  return x

# %%
def DenseNet121(num_classes,
                batch_size=None,
                bn_decay=0.9,
                bn_epsilon=1e-5):
  
  input_shape=(32,32,3)
  input = layers.Input(shape=input_shape,batch_size=batch_size)

  if backend.image_data_format() == 'channels_last':
    bn_axis=3
    x = input
  else:
    x = layers.permute((3,1,2))(input)
    bn_axis=1

  config_block=dict(bn_decay=bn_decay,
                    bn_epsilon=bn_epsilon)
  x = layers.Conv2D(64,(7,7),strides=(2,2),padding='same',
                    kernel_initializer='he_normal',
                    kernel_regularizer=keras.regularizers.l2(1e-4),
                    name='conv1')(x)

  x = layers.MaxPooling2D(pool_size=(3,3),strides=(2,2),padding='same')(x)

  x = dense_block(x,[128,32],stage=2,block='a',**config_block)
  x = dense_block(x,[128,32],stage=2,block='b',**config_block)
  x = dense_block(x,[128,32],stage=2,block='c',**config_block)
  x = dense_block(x,[128,32],stage=2,block='d',**config_block)
  x = dense_block(x,[128,32],stage=2,block='e',**config_block)
  x = dense_block(x,[128,32],stage=2,block='f',**config_block)
  x = transition_block(x,32,stage=2,block='g',**config_block)

  x = dense_block(x,[128,32],stage=3,block='a',**config_block)
  x = dense_block(x,[128,32],stage=3,block='b',**config_block)
  x = dense_block(x,[128,32],stage=3,block='c',**config_block)
  x = dense_block(x,[128,32],stage=3,block='d',**config_block)
  x = dense_block(x,[128,32],stage=3,block='e',**config_block)
  x = dense_block(x,[128,32],stage=3,block='f',**config_block)
  x = dense_block(x,[128,32],stage=3,block='g',**config_block)
  x = dense_block(x,[128,32],stage=3,block='h',**config_block)
  x = dense_block(x,[128,32],stage=3,block='i',**config_block)
  x = dense_block(x,[128,32],stage=3,block='j',**config_block)
  x = dense_block(x,[128,32],stage=3,block='k',**config_block)
  x = dense_block(x,[128,32],stage=3,block='l',**config_block)
  x = transition_block(x,32,stage=3,block='m',**config_block)

  x = dense_block(x,[128,32],stage=4,block='a',**config_block)
  x = dense_block(x,[128,32],stage=4,block='b',**config_block)
  x = dense_block(x,[128,32],stage=4,block='c',**config_block)
  x = dense_block(x,[128,32],stage=4,block='d',**config_block)
  x = dense_block(x,[128,32],stage=4,block='e',**config_block)
  x = dense_block(x,[128,32],stage=4,block='f',**config_block)
  x = dense_block(x,[128,32],stage=4,block='g',**config_block)
  x = dense_block(x,[128,32],stage=4,block='h',**config_block)
  x = dense_block(x,[128,32],stage=4,block='i',**config_block)
  x = dense_block(x,[128,32],stage=4,block='j',**config_block)
  x = dense_block(x,[128,32],stage=4,block='k',**config_block)
  x = dense_block(x,[128,32],stage=4,block='l',**config_block)
  x = dense_block(x,[128,32],stage=4,block='m',**config_block)
  x = dense_block(x,[128,32],stage=4,block='n',**config_block)
  x = dense_block(x,[128,32],stage=4,block='o',**config_block)
  x = dense_block(x,[128,32],stage=4,block='p',**config_block)
  x = dense_block(x,[128,32],stage=4,block='q',**config_block)
  x = dense_block(x,[128,32],stage=4,block='r',**config_block)
  x = dense_block(x,[128,32],stage=4,block='s',**config_block)
  x = dense_block(x,[128,32],stage=4,block='t',**config_block)
  x = dense_block(x,[128,32],stage=4,block='u',**config_block)
  x = dense_block(x,[128,32],stage=4,block='v',**config_block)
  x = dense_block(x,[128,32],stage=4,block='w',**config_block)
  x = dense_block(x,[128,32],stage=4,block='x',**config_block)
  x = transition_block(x,32,stage=4,block='y',**config_block)

  x = dense_block(x,[128,32],stage=5,block='a',**config_block)
  x = dense_block(x,[128,32],stage=5,block='b',**config_block)
  x = dense_block(x,[128,32],stage=5,block='c',**config_block)
  x = dense_block(x,[128,32],stage=5,block='d',**config_block)
  x = dense_block(x,[128,32],stage=5,block='e',**config_block)
  x = dense_block(x,[128,32],stage=5,block='f',**config_block)
  x = dense_block(x,[128,32],stage=5,block='g',**config_block)
  x = dense_block(x,[128,32],stage=5,block='h',**config_block)
  x = dense_block(x,[128,32],stage=5,block='i',**config_block)
  x = dense_block(x,[128,32],stage=5,block='j',**config_block)
  x = dense_block(x,[128,32],stage=5,block='k',**config_block)
  x = dense_block(x,[128,32],stage=5,block='l',**config_block)
  x = dense_block(x,[128,32],stage=5,block='m',**config_block)
  x = dense_block(x,[128,32],stage=5,block='n',**config_block)
  x = dense_block(x,[128,32],stage=5,block='o',**config_block)
  x = dense_block(x,[128,32],stage=5,block='p',**config_block)
  x = transition_block(x,32,stage=5,block='q',**config_block)
  
  x = layers.GlobalAveragePooling2D()(x)
  x = layers.Dense(
      num_classes,
      kernel_initializer='he_normal',
      kernel_regularizer=keras.regularizers.l2(1e-4),
      bias_regularizer=keras.regularizers.l2(1e-4),
      name='1000D_full')(x)
  x = layers.Activation('softmax',dtype='float32')(x)

  return models.Model(input,x,name='DenseNet121')

# %%
densenet121=DenseNet121(num_classes=100)
densenet121.summary()
# Out:
# Model: "DenseNet121"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 32, 32, 3)]  0           []
#
#  conv1 (Conv2D)                 (None, 16, 16, 64)   9472        ['input_2[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 8, 8, 64)    0           ['conv1[0][0]']
#
#  bn2a_branch2a (BatchNormalizat  (None, 8, 8, 64)    256         ['max_pooling2d_1[0][0]']
#  ion)
#
#  activation_18 (Activation)     (None, 8, 8, 64)     0           ['bn2a_branch2a[0][0]']
#
#  dense2a_branch2a (Conv2D)      (None, 8, 8, 128)    8192        ['activation_18[0][0]']
#
#  bn2a_branch2b (BatchNormalizat  (None, 8, 8, 128)   512         ['dense2a_branch2a[0][0]']
#  ion)
#
#  activation_19 (Activation)     (None, 8, 8, 128)    0           ['bn2a_branch2b[0][0]']
#
#  dense2a_branch2b (Conv2D)      (None, 8, 8, 32)     36864       ['activation_19[0][0]']
#
#  concatenate (Concatenate)      (None, 8, 8, 96)     0           ['dense2a_branch2b[0][0]',
#                                                                   'max_pooling2d_1[0][0]']
#
#  bn2b_branch2a (BatchNormalizat  (None, 8, 8, 96)    384         ['concatenate[0][0]']
#  ion)
#
#  activation_20 (Activation)     (None, 8, 8, 96)     0           ['bn2b_branch2a[0][0]']
#
#  dense2b_branch2a (Conv2D)      (None, 8, 8, 128)    12288       ['activation_20[0][0]']
#
#  bn2b_branch2b (BatchNormalizat  (None, 8, 8, 128)   512         ['dense2b_branch2a[0][0]']
#  ion)
#
#  activation_21 (Activation)     (None, 8, 8, 128)    0           ['bn2b_branch2b[0][0]']
#
#  dense2b_branch2b (Conv2D)      (None, 8, 8, 32)     36864       ['activation_21[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 8, 8, 128)    0           ['dense2b_branch2b[0][0]',
#                                                                   'concatenate[0][0]']
#
#  bn2c_branch2a (BatchNormalizat  (None, 8, 8, 128)   512         ['concatenate_1[0][0]']
#  ion)
#
#  activation_22 (Activation)     (None, 8, 8, 128)    0           ['bn2c_branch2a[0][0]']
#
#  dense2c_branch2a (Conv2D)      (None, 8, 8, 128)    16384       ['activation_22[0][0]']
#
#  bn2c_branch2b (BatchNormalizat  (None, 8, 8, 128)   512         ['dense2c_branch2a[0][0]']
#  ion)
#
#  activation_23 (Activation)     (None, 8, 8, 128)    0           ['bn2c_branch2b[0][0]']
#
#  dense2c_branch2b (Conv2D)      (None, 8, 8, 32)     36864       ['activation_23[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 8, 8, 160)    0           ['dense2c_branch2b[0][0]',
#                                                                   'concatenate_1[0][0]']
#
#  bn2d_branch2a (BatchNormalizat  (None, 8, 8, 160)   640         ['concatenate_2[0][0]']
#  ion)
#
#  activation_24 (Activation)     (None, 8, 8, 160)    0           ['bn2d_branch2a[0][0]']
#
#  dense2d_branch2a (Conv2D)      (None, 8, 8, 128)    20480       ['activation_24[0][0]']
#
#  bn2d_branch2b (BatchNormalizat  (None, 8, 8, 128)   512         ['dense2d_branch2a[0][0]']
#  ion)
#
#  activation_25 (Activation)     (None, 8, 8, 128)    0           ['bn2d_branch2b[0][0]']
#
#  dense2d_branch2b (Conv2D)      (None, 8, 8, 32)     36864       ['activation_25[0][0]']
#
#  concatenate_3 (Concatenate)    (None, 8, 8, 192)    0           ['dense2d_branch2b[0][0]',
#                                                                   'concatenate_2[0][0]']
#
#  bn2e_branch2a (BatchNormalizat  (None, 8, 8, 192)   768         ['concatenate_3[0][0]']
#  ion)
#
#  activation_26 (Activation)     (None, 8, 8, 192)    0           ['bn2e_branch2a[0][0]']
#
#  dense2e_branch2a (Conv2D)      (None, 8, 8, 128)    24576       ['activation_26[0][0]']
#
#  bn2e_branch2b (BatchNormalizat  (None, 8, 8, 128)   512         ['dense2e_branch2a[0][0]']
#  ion)
#
#  activation_27 (Activation)     (None, 8, 8, 128)    0           ['bn2e_branch2b[0][0]']
#
#  dense2e_branch2b (Conv2D)      (None, 8, 8, 32)     36864       ['activation_27[0][0]']
#
#  concatenate_4 (Concatenate)    (None, 8, 8, 224)    0           ['dense2e_branch2b[0][0]',
#                                                                   'concatenate_3[0][0]']
#
#  bn2f_branch2a (BatchNormalizat  (None, 8, 8, 224)   896         ['concatenate_4[0][0]']
#  ion)
#
#  activation_28 (Activation)     (None, 8, 8, 224)    0           ['bn2f_branch2a[0][0]']
#
#  dense2f_branch2a (Conv2D)      (None, 8, 8, 128)    28672       ['activation_28[0][0]']
#
#  bn2f_branch2b (BatchNormalizat  (None, 8, 8, 128)   512         ['dense2f_branch2a[0][0]']
#  ion)
#
#  activation_29 (Activation)     (None, 8, 8, 128)    0           ['bn2f_branch2b[0][0]']
#
#  dense2f_branch2b (Conv2D)      (None, 8, 8, 32)     36864       ['activation_29[0][0]']
#
#  concatenate_5 (Concatenate)    (None, 8, 8, 256)    0           ['dense2f_branch2b[0][0]',
#                                                                   'concatenate_4[0][0]']
#
#  bn2g_branch2a (BatchNormalizat  (None, 8, 8, 256)   1024        ['concatenate_5[0][0]']
#  ion)
#
#  transition2g_branch2a (Conv2D)  (None, 8, 8, 32)    8192        ['bn2g_branch2a[0][0]']
#
#  average_pooling2d (AveragePool  (None, 4, 4, 32)    0           ['transition2g_branch2a[0][0]']
#  ing2D)
#
#  bn3a_branch2a (BatchNormalizat  (None, 4, 4, 32)    128         ['average_pooling2d[0][0]']
#  ion)
#
#  activation_30 (Activation)     (None, 4, 4, 32)     0           ['bn3a_branch2a[0][0]']
#
#  dense3a_branch2a (Conv2D)      (None, 4, 4, 128)    4096        ['activation_30[0][0]']
#
#  bn3a_branch2b (BatchNormalizat  (None, 4, 4, 128)   512         ['dense3a_branch2a[0][0]']
#  ion)
#
#  activation_31 (Activation)     (None, 4, 4, 128)    0           ['bn3a_branch2b[0][0]']
#
#  dense3a_branch2b (Conv2D)      (None, 4, 4, 32)     36864       ['activation_31[0][0]']
#
#  concatenate_6 (Concatenate)    (None, 4, 4, 64)     0           ['dense3a_branch2b[0][0]',
#                                                                   'average_pooling2d[0][0]']
#
#  bn3b_branch2a (BatchNormalizat  (None, 4, 4, 64)    256         ['concatenate_6[0][0]']
#  ion)
#
#  activation_32 (Activation)     (None, 4, 4, 64)     0           ['bn3b_branch2a[0][0]']
#
#  dense3b_branch2a (Conv2D)      (None, 4, 4, 128)    8192        ['activation_32[0][0]']
#
#  bn3b_branch2b (BatchNormalizat  (None, 4, 4, 128)   512         ['dense3b_branch2a[0][0]']
#  ion)
#
#  activation_33 (Activation)     (None, 4, 4, 128)    0           ['bn3b_branch2b[0][0]']
#
#  dense3b_branch2b (Conv2D)      (None, 4, 4, 32)     36864       ['activation_33[0][0]']
#
#  concatenate_7 (Concatenate)    (None, 4, 4, 96)     0           ['dense3b_branch2b[0][0]',
#                                                                   'concatenate_6[0][0]']
#
#  bn3c_branch2a (BatchNormalizat  (None, 4, 4, 96)    384         ['concatenate_7[0][0]']
#  ion)
#
#  activation_34 (Activation)     (None, 4, 4, 96)     0           ['bn3c_branch2a[0][0]']
#
#  dense3c_branch2a (Conv2D)      (None, 4, 4, 128)    12288       ['activation_34[0][0]']
#
#  bn3c_branch2b (BatchNormalizat  (None, 4, 4, 128)   512         ['dense3c_branch2a[0][0]']
#  ion)
#
#  activation_35 (Activation)     (None, 4, 4, 128)    0           ['bn3c_branch2b[0][0]']
#
#  dense3c_branch2b (Conv2D)      (None, 4, 4, 32)     36864       ['activation_35[0][0]']
#
#  concatenate_8 (Concatenate)    (None, 4, 4, 128)    0           ['dense3c_branch2b[0][0]',
#                                                                   'concatenate_7[0][0]']
#
#  bn3d_branch2a (BatchNormalizat  (None, 4, 4, 128)   512         ['concatenate_8[0][0]']
#  ion)
#
#  activation_36 (Activation)     (None, 4, 4, 128)    0           ['bn3d_branch2a[0][0]']
#
#  dense3d_branch2a (Conv2D)      (None, 4, 4, 128)    16384       ['activation_36[0][0]']
#
#  bn3d_branch2b (BatchNormalizat  (None, 4, 4, 128)   512         ['dense3d_branch2a[0][0]']
#  ion)
#
#  activation_37 (Activation)     (None, 4, 4, 128)    0           ['bn3d_branch2b[0][0]']
#
#  dense3d_branch2b (Conv2D)      (None, 4, 4, 32)     36864       ['activation_37[0][0]']
#
#  concatenate_9 (Concatenate)    (None, 4, 4, 160)    0           ['dense3d_branch2b[0][0]',
#                                                                   'concatenate_8[0][0]']
#
#  bn3e_branch2a (BatchNormalizat  (None, 4, 4, 160)   640         ['concatenate_9[0][0]']
#  ion)
#
#  activation_38 (Activation)     (None, 4, 4, 160)    0           ['bn3e_branch2a[0][0]']
#
#  dense3e_branch2a (Conv2D)      (None, 4, 4, 128)    20480       ['activation_38[0][0]']
#
#  bn3e_branch2b (BatchNormalizat  (None, 4, 4, 128)   512         ['dense3e_branch2a[0][0]']
#  ion)
#
#  activation_39 (Activation)     (None, 4, 4, 128)    0           ['bn3e_branch2b[0][0]']
#
#  dense3e_branch2b (Conv2D)      (None, 4, 4, 32)     36864       ['activation_39[0][0]']
#
#  concatenate_10 (Concatenate)   (None, 4, 4, 192)    0           ['dense3e_branch2b[0][0]',
#                                                                   'concatenate_9[0][0]']
#
#  bn3f_branch2a (BatchNormalizat  (None, 4, 4, 192)   768         ['concatenate_10[0][0]']
#  ion)
#
#  activation_40 (Activation)     (None, 4, 4, 192)    0           ['bn3f_branch2a[0][0]']
#
#  dense3f_branch2a (Conv2D)      (None, 4, 4, 128)    24576       ['activation_40[0][0]']
#
#  bn3f_branch2b (BatchNormalizat  (None, 4, 4, 128)   512         ['dense3f_branch2a[0][0]']
#  ion)
#
#  activation_41 (Activation)     (None, 4, 4, 128)    0           ['bn3f_branch2b[0][0]']
#
#  dense3f_branch2b (Conv2D)      (None, 4, 4, 32)     36864       ['activation_41[0][0]']
#
#  concatenate_11 (Concatenate)   (None, 4, 4, 224)    0           ['dense3f_branch2b[0][0]',
#                                                                   'concatenate_10[0][0]']
#
#  bn3g_branch2a (BatchNormalizat  (None, 4, 4, 224)   896         ['concatenate_11[0][0]']
#  ion)
#
#  activation_42 (Activation)     (None, 4, 4, 224)    0           ['bn3g_branch2a[0][0]']
#
#  dense3g_branch2a (Conv2D)      (None, 4, 4, 128)    28672       ['activation_42[0][0]']
#
#  bn3g_branch2b (BatchNormalizat  (None, 4, 4, 128)   512         ['dense3g_branch2a[0][0]']
#  ion)
#
#  activation_43 (Activation)     (None, 4, 4, 128)    0           ['bn3g_branch2b[0][0]']
#
#  dense3g_branch2b (Conv2D)      (None, 4, 4, 32)     36864       ['activation_43[0][0]']
#
#  concatenate_12 (Concatenate)   (None, 4, 4, 256)    0           ['dense3g_branch2b[0][0]',
#                                                                   'concatenate_11[0][0]']
#
#  bn3h_branch2a (BatchNormalizat  (None, 4, 4, 256)   1024        ['concatenate_12[0][0]']
#  ion)
#
#  activation_44 (Activation)     (None, 4, 4, 256)    0           ['bn3h_branch2a[0][0]']
#
#  dense3h_branch2a (Conv2D)      (None, 4, 4, 128)    32768       ['activation_44[0][0]']
#
#  bn3h_branch2b (BatchNormalizat  (None, 4, 4, 128)   512         ['dense3h_branch2a[0][0]']
#  ion)
#
#  activation_45 (Activation)     (None, 4, 4, 128)    0           ['bn3h_branch2b[0][0]']
#
#  dense3h_branch2b (Conv2D)      (None, 4, 4, 32)     36864       ['activation_45[0][0]']
#
#  concatenate_13 (Concatenate)   (None, 4, 4, 288)    0           ['dense3h_branch2b[0][0]',
#                                                                   'concatenate_12[0][0]']
#
#  bn3i_branch2a (BatchNormalizat  (None, 4, 4, 288)   1152        ['concatenate_13[0][0]']
#  ion)
#
#  activation_46 (Activation)     (None, 4, 4, 288)    0           ['bn3i_branch2a[0][0]']
#
#  dense3i_branch2a (Conv2D)      (None, 4, 4, 128)    36864       ['activation_46[0][0]']
#
#  bn3i_branch2b (BatchNormalizat  (None, 4, 4, 128)   512         ['dense3i_branch2a[0][0]']
#  ion)
#
#  activation_47 (Activation)     (None, 4, 4, 128)    0           ['bn3i_branch2b[0][0]']
#
#  dense3i_branch2b (Conv2D)      (None, 4, 4, 32)     36864       ['activation_47[0][0]']
#
#  concatenate_14 (Concatenate)   (None, 4, 4, 320)    0           ['dense3i_branch2b[0][0]',
#                                                                   'concatenate_13[0][0]']
#
#  bn3j_branch2a (BatchNormalizat  (None, 4, 4, 320)   1280        ['concatenate_14[0][0]']
#  ion)
#
#  activation_48 (Activation)     (None, 4, 4, 320)    0           ['bn3j_branch2a[0][0]']
#
#  dense3j_branch2a (Conv2D)      (None, 4, 4, 128)    40960       ['activation_48[0][0]']
#
#  bn3j_branch2b (BatchNormalizat  (None, 4, 4, 128)   512         ['dense3j_branch2a[0][0]']
#  ion)
#
#  activation_49 (Activation)     (None, 4, 4, 128)    0           ['bn3j_branch2b[0][0]']
#
#  dense3j_branch2b (Conv2D)      (None, 4, 4, 32)     36864       ['activation_49[0][0]']
#
#  concatenate_15 (Concatenate)   (None, 4, 4, 352)    0           ['dense3j_branch2b[0][0]',
#                                                                   'concatenate_14[0][0]']
#
#  bn3k_branch2a (BatchNormalizat  (None, 4, 4, 352)   1408        ['concatenate_15[0][0]']
#  ion)
#
#  activation_50 (Activation)     (None, 4, 4, 352)    0           ['bn3k_branch2a[0][0]']
#
#  dense3k_branch2a (Conv2D)      (None, 4, 4, 128)    45056       ['activation_50[0][0]']
#
#  bn3k_branch2b (BatchNormalizat  (None, 4, 4, 128)   512         ['dense3k_branch2a[0][0]']
#  ion)
#
#  activation_51 (Activation)     (None, 4, 4, 128)    0           ['bn3k_branch2b[0][0]']
#
#  dense3k_branch2b (Conv2D)      (None, 4, 4, 32)     36864       ['activation_51[0][0]']
#
#  concatenate_16 (Concatenate)   (None, 4, 4, 384)    0           ['dense3k_branch2b[0][0]',
#                                                                   'concatenate_15[0][0]']
#
#  bn3l_branch2a (BatchNormalizat  (None, 4, 4, 384)   1536        ['concatenate_16[0][0]']
#  ion)
#
#  activation_52 (Activation)     (None, 4, 4, 384)    0           ['bn3l_branch2a[0][0]']
#
#  dense3l_branch2a (Conv2D)      (None, 4, 4, 128)    49152       ['activation_52[0][0]']
#
#  bn3l_branch2b (BatchNormalizat  (None, 4, 4, 128)   512         ['dense3l_branch2a[0][0]']
#  ion)
#
#  activation_53 (Activation)     (None, 4, 4, 128)    0           ['bn3l_branch2b[0][0]']
#
#  dense3l_branch2b (Conv2D)      (None, 4, 4, 32)     36864       ['activation_53[0][0]']
#
#  concatenate_17 (Concatenate)   (None, 4, 4, 416)    0           ['dense3l_branch2b[0][0]',
#                                                                   'concatenate_16[0][0]']
#
#  bn3m_branch2a (BatchNormalizat  (None, 4, 4, 416)   1664        ['concatenate_17[0][0]']
#  ion)
#
#  transition3m_branch2a (Conv2D)  (None, 4, 4, 32)    13312       ['bn3m_branch2a[0][0]']
#
#  average_pooling2d_1 (AveragePo  (None, 2, 2, 32)    0           ['transition3m_branch2a[0][0]']
#  oling2D)
#
#  bn4a_branch2a (BatchNormalizat  (None, 2, 2, 32)    128         ['average_pooling2d_1[0][0]']
#  ion)
#
#  activation_54 (Activation)     (None, 2, 2, 32)     0           ['bn4a_branch2a[0][0]']
#
#  dense4a_branch2a (Conv2D)      (None, 2, 2, 128)    4096        ['activation_54[0][0]']
#
#  bn4a_branch2b (BatchNormalizat  (None, 2, 2, 128)   512         ['dense4a_branch2a[0][0]']
#  ion)
#
#  activation_55 (Activation)     (None, 2, 2, 128)    0           ['bn4a_branch2b[0][0]']
#
#  dense4a_branch2b (Conv2D)      (None, 2, 2, 32)     36864       ['activation_55[0][0]']
#
#  concatenate_18 (Concatenate)   (None, 2, 2, 64)     0           ['dense4a_branch2b[0][0]',
#                                                                   'average_pooling2d_1[0][0]']
#
#  bn4b_branch2a (BatchNormalizat  (None, 2, 2, 64)    256         ['concatenate_18[0][0]']
#  ion)
#
#  activation_56 (Activation)     (None, 2, 2, 64)     0           ['bn4b_branch2a[0][0]']
#
#  dense4b_branch2a (Conv2D)      (None, 2, 2, 128)    8192        ['activation_56[0][0]']
#
#  bn4b_branch2b (BatchNormalizat  (None, 2, 2, 128)   512         ['dense4b_branch2a[0][0]']
#  ion)
#
#  activation_57 (Activation)     (None, 2, 2, 128)    0           ['bn4b_branch2b[0][0]']
#
#  dense4b_branch2b (Conv2D)      (None, 2, 2, 32)     36864       ['activation_57[0][0]']
#
#  concatenate_19 (Concatenate)   (None, 2, 2, 96)     0           ['dense4b_branch2b[0][0]',
#                                                                   'concatenate_18[0][0]']
#
#  bn4c_branch2a (BatchNormalizat  (None, 2, 2, 96)    384         ['concatenate_19[0][0]']
#  ion)
#
#  activation_58 (Activation)     (None, 2, 2, 96)     0           ['bn4c_branch2a[0][0]']
#
#  dense4c_branch2a (Conv2D)      (None, 2, 2, 128)    12288       ['activation_58[0][0]']
#
#  bn4c_branch2b (BatchNormalizat  (None, 2, 2, 128)   512         ['dense4c_branch2a[0][0]']
#  ion)
#
#  activation_59 (Activation)     (None, 2, 2, 128)    0           ['bn4c_branch2b[0][0]']
#
#  dense4c_branch2b (Conv2D)      (None, 2, 2, 32)     36864       ['activation_59[0][0]']
#
#  concatenate_20 (Concatenate)   (None, 2, 2, 128)    0           ['dense4c_branch2b[0][0]',
#                                                                   'concatenate_19[0][0]']
#
#  bn4d_branch2a (BatchNormalizat  (None, 2, 2, 128)   512         ['concatenate_20[0][0]']
#  ion)
#
#  activation_60 (Activation)     (None, 2, 2, 128)    0           ['bn4d_branch2a[0][0]']
#
#  dense4d_branch2a (Conv2D)      (None, 2, 2, 128)    16384       ['activation_60[0][0]']
#
#  bn4d_branch2b (BatchNormalizat  (None, 2, 2, 128)   512         ['dense4d_branch2a[0][0]']
#  ion)
#
#  activation_61 (Activation)     (None, 2, 2, 128)    0           ['bn4d_branch2b[0][0]']
#
#  dense4d_branch2b (Conv2D)      (None, 2, 2, 32)     36864       ['activation_61[0][0]']
#
#  concatenate_21 (Concatenate)   (None, 2, 2, 160)    0           ['dense4d_branch2b[0][0]',
#                                                                   'concatenate_20[0][0]']
#
#  bn4e_branch2a (BatchNormalizat  (None, 2, 2, 160)   640         ['concatenate_21[0][0]']
#  ion)
#
#  activation_62 (Activation)     (None, 2, 2, 160)    0           ['bn4e_branch2a[0][0]']
#
#  dense4e_branch2a (Conv2D)      (None, 2, 2, 128)    20480       ['activation_62[0][0]']
#
#  bn4e_branch2b (BatchNormalizat  (None, 2, 2, 128)   512         ['dense4e_branch2a[0][0]']
#  ion)
#
#  activation_63 (Activation)     (None, 2, 2, 128)    0           ['bn4e_branch2b[0][0]']
#
#  dense4e_branch2b (Conv2D)      (None, 2, 2, 32)     36864       ['activation_63[0][0]']
#
#  concatenate_22 (Concatenate)   (None, 2, 2, 192)    0           ['dense4e_branch2b[0][0]',
#                                                                   'concatenate_21[0][0]']
#
#  bn4f_branch2a (BatchNormalizat  (None, 2, 2, 192)   768         ['concatenate_22[0][0]']
#  ion)
#
#  activation_64 (Activation)     (None, 2, 2, 192)    0           ['bn4f_branch2a[0][0]']
#
#  dense4f_branch2a (Conv2D)      (None, 2, 2, 128)    24576       ['activation_64[0][0]']
#
#  bn4f_branch2b (BatchNormalizat  (None, 2, 2, 128)   512         ['dense4f_branch2a[0][0]']
#  ion)
#
#  activation_65 (Activation)     (None, 2, 2, 128)    0           ['bn4f_branch2b[0][0]']
#
#  dense4f_branch2b (Conv2D)      (None, 2, 2, 32)     36864       ['activation_65[0][0]']
#
#  concatenate_23 (Concatenate)   (None, 2, 2, 224)    0           ['dense4f_branch2b[0][0]',
#                                                                   'concatenate_22[0][0]']
#
#  bn4g_branch2a (BatchNormalizat  (None, 2, 2, 224)   896         ['concatenate_23[0][0]']
#  ion)
#
#  activation_66 (Activation)     (None, 2, 2, 224)    0           ['bn4g_branch2a[0][0]']
#
#  dense4g_branch2a (Conv2D)      (None, 2, 2, 128)    28672       ['activation_66[0][0]']
#
#  bn4g_branch2b (BatchNormalizat  (None, 2, 2, 128)   512         ['dense4g_branch2a[0][0]']
#  ion)
#
#  activation_67 (Activation)     (None, 2, 2, 128)    0           ['bn4g_branch2b[0][0]']
#
#  dense4g_branch2b (Conv2D)      (None, 2, 2, 32)     36864       ['activation_67[0][0]']
#
#  concatenate_24 (Concatenate)   (None, 2, 2, 256)    0           ['dense4g_branch2b[0][0]',
#                                                                   'concatenate_23[0][0]']
#
#  bn4h_branch2a (BatchNormalizat  (None, 2, 2, 256)   1024        ['concatenate_24[0][0]']
#  ion)
#
#  activation_68 (Activation)     (None, 2, 2, 256)    0           ['bn4h_branch2a[0][0]']
#
#  dense4h_branch2a (Conv2D)      (None, 2, 2, 128)    32768       ['activation_68[0][0]']
#
#  bn4h_branch2b (BatchNormalizat  (None, 2, 2, 128)   512         ['dense4h_branch2a[0][0]']
#  ion)
#
#  activation_69 (Activation)     (None, 2, 2, 128)    0           ['bn4h_branch2b[0][0]']
#
#  dense4h_branch2b (Conv2D)      (None, 2, 2, 32)     36864       ['activation_69[0][0]']
#
#  concatenate_25 (Concatenate)   (None, 2, 2, 288)    0           ['dense4h_branch2b[0][0]',
#                                                                   'concatenate_24[0][0]']
#
#  bn4i_branch2a (BatchNormalizat  (None, 2, 2, 288)   1152        ['concatenate_25[0][0]']
#  ion)
#
#  activation_70 (Activation)     (None, 2, 2, 288)    0           ['bn4i_branch2a[0][0]']
#
#  dense4i_branch2a (Conv2D)      (None, 2, 2, 128)    36864       ['activation_70[0][0]']
#
#  bn4i_branch2b (BatchNormalizat  (None, 2, 2, 128)   512         ['dense4i_branch2a[0][0]']
#  ion)
#
#  activation_71 (Activation)     (None, 2, 2, 128)    0           ['bn4i_branch2b[0][0]']
#
#  dense4i_branch2b (Conv2D)      (None, 2, 2, 32)     36864       ['activation_71[0][0]']
#
#  concatenate_26 (Concatenate)   (None, 2, 2, 320)    0           ['dense4i_branch2b[0][0]',
#                                                                   'concatenate_25[0][0]']
#
# ...
#
#  dense5h_branch2b (Conv2D)      (None, 1, 1, 32)     36864       ['activation_117[0][0]']
#
#  concatenate_49 (Concatenate)   (None, 1, 1, 288)    0           ['dense5h_branch2b[0][0]',
#                                                                   'concatenate_48[0][0]']
#
#  bn5i_branch2a (BatchNormalizat  (None, 1, 1, 288)   1152        ['concatenate_49[0][0]']
#  ion)
#
#  activation_118 (Activation)    (None, 1, 1, 288)    0           ['bn5i_branch2a[0][0]']
#
#  dense5i_branch2a (Conv2D)      (None, 1, 1, 128)    36864       ['activation_118[0][0]']
#
#  bn5i_branch2b (BatchNormalizat  (None, 1, 1, 128)   512         ['dense5i_branch2a[0][0]']
#  ion)
#
#  activation_119 (Activation)    (None, 1, 1, 128)    0           ['bn5i_branch2b[0][0]']
#
#  dense5i_branch2b (Conv2D)      (None, 1, 1, 32)     36864       ['activation_119[0][0]']
#
#  concatenate_50 (Concatenate)   (None, 1, 1, 320)    0           ['dense5i_branch2b[0][0]',
#                                                                   'concatenate_49[0][0]']
#
#  bn5j_branch2a (BatchNormalizat  (None, 1, 1, 320)   1280        ['concatenate_50[0][0]']
#  ion)
#
#  activation_120 (Activation)    (None, 1, 1, 320)    0           ['bn5j_branch2a[0][0]']
#
#  dense5j_branch2a (Conv2D)      (None, 1, 1, 128)    40960       ['activation_120[0][0]']
#
#  bn5j_branch2b (BatchNormalizat  (None, 1, 1, 128)   512         ['dense5j_branch2a[0][0]']
#  ion)
#
#  activation_121 (Activation)    (None, 1, 1, 128)    0           ['bn5j_branch2b[0][0]']
#
#  dense5j_branch2b (Conv2D)      (None, 1, 1, 32)     36864       ['activation_121[0][0]']
#
#  concatenate_51 (Concatenate)   (None, 1, 1, 352)    0           ['dense5j_branch2b[0][0]',
#                                                                   'concatenate_50[0][0]']
#
#  bn5k_branch2a (BatchNormalizat  (None, 1, 1, 352)   1408        ['concatenate_51[0][0]']
#  ion)
#
#  activation_122 (Activation)    (None, 1, 1, 352)    0           ['bn5k_branch2a[0][0]']
#
#  dense5k_branch2a (Conv2D)      (None, 1, 1, 128)    45056       ['activation_122[0][0]']
#
#  bn5k_branch2b (BatchNormalizat  (None, 1, 1, 128)   512         ['dense5k_branch2a[0][0]']
#  ion)
#
#  activation_123 (Activation)    (None, 1, 1, 128)    0           ['bn5k_branch2b[0][0]']
#
#  dense5k_branch2b (Conv2D)      (None, 1, 1, 32)     36864       ['activation_123[0][0]']
#
#  concatenate_52 (Concatenate)   (None, 1, 1, 384)    0           ['dense5k_branch2b[0][0]',
#                                                                   'concatenate_51[0][0]']
#
#  bn5l_branch2a (BatchNormalizat  (None, 1, 1, 384)   1536        ['concatenate_52[0][0]']
#  ion)
#
#  activation_124 (Activation)    (None, 1, 1, 384)    0           ['bn5l_branch2a[0][0]']
#
#  dense5l_branch2a (Conv2D)      (None, 1, 1, 128)    49152       ['activation_124[0][0]']
#
#  bn5l_branch2b (BatchNormalizat  (None, 1, 1, 128)   512         ['dense5l_branch2a[0][0]']
#  ion)
#
#  activation_125 (Activation)    (None, 1, 1, 128)    0           ['bn5l_branch2b[0][0]']
#
#  dense5l_branch2b (Conv2D)      (None, 1, 1, 32)     36864       ['activation_125[0][0]']
#
#  concatenate_53 (Concatenate)   (None, 1, 1, 416)    0           ['dense5l_branch2b[0][0]',
#                                                                   'concatenate_52[0][0]']
#
#  bn5m_branch2a (BatchNormalizat  (None, 1, 1, 416)   1664        ['concatenate_53[0][0]']
#  ion)
#
#  activation_126 (Activation)    (None, 1, 1, 416)    0           ['bn5m_branch2a[0][0]']
#
#  dense5m_branch2a (Conv2D)      (None, 1, 1, 128)    53248       ['activation_126[0][0]']
#
#  bn5m_branch2b (BatchNormalizat  (None, 1, 1, 128)   512         ['dense5m_branch2a[0][0]']
#  ion)
#
#  activation_127 (Activation)    (None, 1, 1, 128)    0           ['bn5m_branch2b[0][0]']
#
#  dense5m_branch2b (Conv2D)      (None, 1, 1, 32)     36864       ['activation_127[0][0]']
#
#  concatenate_54 (Concatenate)   (None, 1, 1, 448)    0           ['dense5m_branch2b[0][0]',
#                                                                   'concatenate_53[0][0]']
#
#  bn5n_branch2a (BatchNormalizat  (None, 1, 1, 448)   1792        ['concatenate_54[0][0]']
#  ion)
#
#  activation_128 (Activation)    (None, 1, 1, 448)    0           ['bn5n_branch2a[0][0]']
#
#  dense5n_branch2a (Conv2D)      (None, 1, 1, 128)    57344       ['activation_128[0][0]']
#
#  bn5n_branch2b (BatchNormalizat  (None, 1, 1, 128)   512         ['dense5n_branch2a[0][0]']
#  ion)
#
#  activation_129 (Activation)    (None, 1, 1, 128)    0           ['bn5n_branch2b[0][0]']
#
#  dense5n_branch2b (Conv2D)      (None, 1, 1, 32)     36864       ['activation_129[0][0]']
#
#  concatenate_55 (Concatenate)   (None, 1, 1, 480)    0           ['dense5n_branch2b[0][0]',
#                                                                   'concatenate_54[0][0]']
#
#  bn5o_branch2a (BatchNormalizat  (None, 1, 1, 480)   1920        ['concatenate_55[0][0]']
#  ion)
#
#  activation_130 (Activation)    (None, 1, 1, 480)    0           ['bn5o_branch2a[0][0]']
#
#  dense5o_branch2a (Conv2D)      (None, 1, 1, 128)    61440       ['activation_130[0][0]']
#
#  bn5o_branch2b (BatchNormalizat  (None, 1, 1, 128)   512         ['dense5o_branch2a[0][0]']
#  ion)
#
#  activation_131 (Activation)    (None, 1, 1, 128)    0           ['bn5o_branch2b[0][0]']
#
#  dense5o_branch2b (Conv2D)      (None, 1, 1, 32)     36864       ['activation_131[0][0]']
#
#  concatenate_56 (Concatenate)   (None, 1, 1, 512)    0           ['dense5o_branch2b[0][0]',
#                                                                   'concatenate_55[0][0]']
#
#  bn5p_branch2a (BatchNormalizat  (None, 1, 1, 512)   2048        ['concatenate_56[0][0]']
#  ion)
#
#  activation_132 (Activation)    (None, 1, 1, 512)    0           ['bn5p_branch2a[0][0]']
#
#  dense5p_branch2a (Conv2D)      (None, 1, 1, 128)    65536       ['activation_132[0][0]']
#
#  bn5p_branch2b (BatchNormalizat  (None, 1, 1, 128)   512         ['dense5p_branch2a[0][0]']
#  ion)
#
#  activation_133 (Activation)    (None, 1, 1, 128)    0           ['bn5p_branch2b[0][0]']
#
#  dense5p_branch2b (Conv2D)      (None, 1, 1, 32)     36864       ['activation_133[0][0]']
#
#  concatenate_57 (Concatenate)   (None, 1, 1, 544)    0           ['dense5p_branch2b[0][0]',
#                                                                   'concatenate_56[0][0]']
#
#  bn5q_branch2a (BatchNormalizat  (None, 1, 1, 544)   2176        ['concatenate_57[0][0]']
#  ion)
#
#  transition5q_branch2a (Conv2D)  (None, 1, 1, 32)    17408       ['bn5q_branch2a[0][0]']
#
#  average_pooling2d_3 (AveragePo  (None, 1, 1, 32)    0           ['transition5q_branch2a[0][0]']
#  oling2D)
#
#  global_average_pooling2d_1 (Gl  (None, 32)          0           ['average_pooling2d_3[0][0]']
#  obalAveragePooling2D)
#
#  1000D_full (Dense)             (None, 100)          3300        ['global_average_pooling2d_1[0][0
#                                                                  ]']
#
#  activation_134 (Activation)    (None, 100)          0           ['1000D_full[0][0]']
#
# ==================================================================================================
# Total params: 4,538,340
# Trainable params: 4,484,836
# Non-trainable params: 53,504
# __________________________________________________________________________________________________

# %%
plot_model(densenet121,show_shapes=True)
# Out:
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.69888 to fit

# %%
densenet121.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

history_densenet121 = densenet121.fit(x_train, y_train, epochs=100)
# Out:
# Epoch 1/100
# 1563/1563 [==============================] - 90s 49ms/step - loss: 6.0115 - accuracy: 0.0709
# Epoch 2/100
# 1563/1563 [==============================] - 75s 48ms/step - loss: 5.1430 - accuracy: 0.1252
# Epoch 3/100
# 1563/1563 [==============================] - 75s 48ms/step - loss: 4.4156 - accuracy: 0.1743
# Epoch 4/100
# 1563/1563 [==============================] - 74s 47ms/step - loss: 3.8586 - accuracy: 0.2172
# Epoch 5/100
# 1563/1563 [==============================] - 73s 47ms/step - loss: 3.4760 - accuracy: 0.2586
# Epoch 6/100
# 1563/1563 [==============================] - 72s 46ms/step - loss: 3.2281 - accuracy: 0.2899
# Epoch 7/100
# 1563/1563 [==============================] - 77s 50ms/step - loss: 3.0435 - accuracy: 0.3234
# Epoch 8/100
# 1563/1563 [==============================] - 74s 47ms/step - loss: 2.8927 - accuracy: 0.3514
# Epoch 9/100
# 1563/1563 [==============================] - 76s 48ms/step - loss: 2.7636 - accuracy: 0.3767
# Epoch 10/100
# 1563/1563 [==============================] - 76s 48ms/step - loss: 2.6593 - accuracy: 0.4008
# Epoch 11/100
# 1563/1563 [==============================] - 76s 48ms/step - loss: 2.5685 - accuracy: 0.4202
# Epoch 12/100
# 1563/1563 [==============================] - 78s 50ms/step - loss: 2.4864 - accuracy: 0.4445
# Epoch 13/100
# 1563/1563 [==============================] - 76s 49ms/step - loss: 2.4078 - accuracy: 0.4604
# Epoch 14/100
# 1563/1563 [==============================] - 77s 49ms/step - loss: 2.3345 - accuracy: 0.4815
# Epoch 15/100
# 1563/1563 [==============================] - 78s 50ms/step - loss: 2.2662 - accuracy: 0.4976
# Epoch 16/100
# 1563/1563 [==============================] - 75s 48ms/step - loss: 2.2229 - accuracy: 0.5136
# Epoch 17/100
# 1563/1563 [==============================] - 75s 48ms/step - loss: 2.1615 - accuracy: 0.5302
# Epoch 18/100
# 1563/1563 [==============================] - 75s 48ms/step - loss: 2.1181 - accuracy: 0.5445
# Epoch 19/100
# 1563/1563 [==============================] - 75s 48ms/step - loss: 2.0743 - accuracy: 0.5590
# Epoch 20/100
# 1563/1563 [==============================] - 74s 48ms/step - loss: 2.0395 - accuracy: 0.5687
# Epoch 21/100
# 1563/1563 [==============================] - 74s 48ms/step - loss: 2.0000 - accuracy: 0.5849
# Epoch 22/100
# 1563/1563 [==============================] - 77s 49ms/step - loss: 1.9607 - accuracy: 0.6012
# Epoch 23/100
# 1563/1563 [==============================] - 75s 48ms/step - loss: 1.9372 - accuracy: 0.6106
# Epoch 24/100
# 1563/1563 [==============================] - 75s 48ms/step - loss: 1.9175 - accuracy: 0.6172
# Epoch 25/100
# 1563/1563 [==============================] - 75s 48ms/step - loss: 1.8863 - accuracy: 0.6282
# Epoch 26/100
# 1563/1563 [==============================] - 75s 48ms/step - loss: 1.8730 - accuracy: 0.6373
# Epoch 27/100
# 1563/1563 [==============================] - 76s 49ms/step - loss: 1.8516 - accuracy: 0.6474
# Epoch 28/100
# 1563/1563 [==============================] - 77s 49ms/step - loss: 1.8211 - accuracy: 0.6587
# Epoch 29/100
# 1563/1563 [==============================] - 75s 48ms/step - loss: 1.8158 - accuracy: 0.6628
# Epoch 30/100
# 1563/1563 [==============================] - 75s 48ms/step - loss: 1.7936 - accuracy: 0.6732
# Epoch 31/100
# 1563/1563 [==============================] - 76s 49ms/step - loss: 1.7754 - accuracy: 0.6815
# Epoch 32/100
# 1563/1563 [==============================] - 77s 49ms/step - loss: 1.7620 - accuracy: 0.6881
# Epoch 33/100
# 1563/1563 [==============================] - 75s 48ms/step - loss: 1.7516 - accuracy: 0.6931
# Epoch 34/100
# 1563/1563 [==============================] - 75s 48ms/step - loss: 1.7397 - accuracy: 0.7005
# Epoch 35/100
# 1563/1563 [==============================] - 75s 48ms/step - loss: 1.7237 - accuracy: 0.7079
# Epoch 36/100
# 1563/1563 [==============================] - 75s 48ms/step - loss: 1.7255 - accuracy: 0.7103
# Epoch 37/100
# 1563/1563 [==============================] - 75s 48ms/step - loss: 1.7111 - accuracy: 0.7177
# Epoch 38/100
# 1563/1563 [==============================] - 76s 49ms/step - loss: 1.6978 - accuracy: 0.7223
# Epoch 39/100
# 1563/1563 [==============================] - 75s 48ms/step - loss: 1.7034 - accuracy: 0.7232
# Epoch 40/100
# 1563/1563 [==============================] - 75s 48ms/step - loss: 1.6902 - accuracy: 0.7302
# Epoch 41/100
# 1563/1563 [==============================] - 75s 48ms/step - loss: 1.6736 - accuracy: 0.7352
# Epoch 42/100
# 1563/1563 [==============================] - 77s 49ms/step - loss: 1.6749 - accuracy: 0.7390
# Epoch 43/100
# 1563/1563 [==============================] - 76s 49ms/step - loss: 1.6639 - accuracy: 0.7419
# Epoch 44/100
# 1563/1563 [==============================] - 80s 51ms/step - loss: 1.6575 - accuracy: 0.7448
# Epoch 45/100
# 1563/1563 [==============================] - 78s 50ms/step - loss: 1.6633 - accuracy: 0.7456
# Epoch 46/100
# 1563/1563 [==============================] - 78s 50ms/step - loss: 1.6373 - accuracy: 0.7551
# Epoch 47/100
# 1563/1563 [==============================] - 77s 49ms/step - loss: 1.6551 - accuracy: 0.7531
# Epoch 48/100
# 1563/1563 [==============================] - 74s 48ms/step - loss: 1.6397 - accuracy: 0.7602
# Epoch 49/100
# 1563/1563 [==============================] - 76s 48ms/step - loss: 1.6301 - accuracy: 0.7612
# Epoch 50/100
# 1563/1563 [==============================] - 74s 47ms/step - loss: 1.6259 - accuracy: 0.7639
# Epoch 51/100
# 1563/1563 [==============================] - 75s 48ms/step - loss: 1.6230 - accuracy: 0.7663
# Epoch 52/100
# 1563/1563 [==============================] - 75s 48ms/step - loss: 1.6168 - accuracy: 0.7697
# Epoch 53/100
# 1563/1563 [==============================] - 75s 48ms/step - loss: 1.6191 - accuracy: 0.7693
# Epoch 54/100
# 1563/1563 [==============================] - 75s 48ms/step - loss: 1.6149 - accuracy: 0.7718
# Epoch 55/100
# 1563/1563 [==============================] - 77s 49ms/step - loss: 1.6044 - accuracy: 0.7754
# Epoch 56/100
# 1563/1563 [==============================] - 74s 48ms/step - loss: 1.6033 - accuracy: 0.7763
# Epoch 57/100
# 1563/1563 [==============================] - 75s 48ms/step - loss: 1.6069 - accuracy: 0.7772
# Epoch 58/100
# 1563/1563 [==============================] - 75s 48ms/step - loss: 1.5895 - accuracy: 0.7827
# Epoch 59/100
# 1563/1563 [==============================] - 75s 48ms/step - loss: 1.5929 - accuracy: 0.7842
# Epoch 60/100
# 1563/1563 [==============================] - 74s 48ms/step - loss: 1.5813 - accuracy: 0.7872
# Epoch 61/100
# 1563/1563 [==============================] - 77s 49ms/step - loss: 1.5854 - accuracy: 0.7862
# Epoch 62/100
# 1563/1563 [==============================] - 74s 48ms/step - loss: 1.5910 - accuracy: 0.7869
# Epoch 63/100
# 1563/1563 [==============================] - 75s 48ms/step - loss: 1.5788 - accuracy: 0.7913
# Epoch 64/100
# 1563/1563 [==============================] - 74s 48ms/step - loss: 1.5747 - accuracy: 0.7908
# Epoch 65/100
# 1563/1563 [==============================] - 74s 48ms/step - loss: 1.5811 - accuracy: 0.7896
# Epoch 66/100
# 1563/1563 [==============================] - 76s 49ms/step - loss: 1.5591 - accuracy: 0.7962
# Epoch 67/100
# 1563/1563 [==============================] - 76s 49ms/step - loss: 1.5792 - accuracy: 0.7919
# Epoch 68/100
# 1563/1563 [==============================] - 75s 48ms/step - loss: 1.5441 - accuracy: 0.8022
# Epoch 69/100
# 1563/1563 [==============================] - 77s 49ms/step - loss: 1.5660 - accuracy: 0.7957
# Epoch 70/100
# 1563/1563 [==============================] - 74s 48ms/step - loss: 1.5635 - accuracy: 0.7975
# Epoch 71/100
# 1563/1563 [==============================] - 76s 49ms/step - loss: 1.5506 - accuracy: 0.8007
# Epoch 72/100
# 1563/1563 [==============================] - 75s 48ms/step - loss: 1.5456 - accuracy: 0.8036
# Epoch 73/100
# 1563/1563 [==============================] - 74s 47ms/step - loss: 1.5475 - accuracy: 0.8028
# Epoch 74/100
# 1563/1563 [==============================] - 75s 48ms/step - loss: 1.5513 - accuracy: 0.8016
# Epoch 75/100
# 1563/1563 [==============================] - 74s 47ms/step - loss: 1.5390 - accuracy: 0.8048
# Epoch 76/100
# 1563/1563 [==============================] - 77s 50ms/step - loss: 1.5475 - accuracy: 0.8015
# Epoch 77/100
# 1563/1563 [==============================] - 75s 48ms/step - loss: 1.5378 - accuracy: 0.8068
# Epoch 78/100
# 1563/1563 [==============================] - 76s 49ms/step - loss: 1.5433 - accuracy: 0.8045
# Epoch 79/100
# 1563/1563 [==============================] - 75s 48ms/step - loss: 1.5391 - accuracy: 0.8065
# Epoch 80/100
# 1563/1563 [==============================] - 74s 47ms/step - loss: 1.5328 - accuracy: 0.8072
# Epoch 81/100
# 1563/1563 [==============================] - 75s 48ms/step - loss: 1.5242 - accuracy: 0.8099
# Epoch 82/100
# 1563/1563 [==============================] - 78s 50ms/step - loss: 1.5248 - accuracy: 0.8119
# Epoch 83/100
# 1563/1563 [==============================] - 75s 48ms/step - loss: 1.5238 - accuracy: 0.8112
# Epoch 84/100
# 1563/1563 [==============================] - 75s 48ms/step - loss: 1.5127 - accuracy: 0.8139
# Epoch 85/100
# 1563/1563 [==============================] - 75s 48ms/step - loss: 1.5193 - accuracy: 0.8141
# Epoch 86/100
# 1563/1563 [==============================] - 75s 48ms/step - loss: 1.5235 - accuracy: 0.8102
# Epoch 87/100
# 1563/1563 [==============================] - 75s 48ms/step - loss: 1.5036 - accuracy: 0.8170
# Epoch 88/100
# 1563/1563 [==============================] - 76s 49ms/step - loss: 1.5221 - accuracy: 0.8109
# Epoch 89/100
# 1563/1563 [==============================] - 75s 48ms/step - loss: 1.5023 - accuracy: 0.8168
# Epoch 90/100
# 1563/1563 [==============================] - 75s 48ms/step - loss: 1.5041 - accuracy: 0.8157
# Epoch 91/100
# 1563/1563 [==============================] - 74s 47ms/step - loss: 1.5047 - accuracy: 0.8176
# Epoch 92/100
# 1563/1563 [==============================] - 75s 48ms/step - loss: 1.5002 - accuracy: 0.8179
# Epoch 93/100
# 1563/1563 [==============================] - 74s 48ms/step - loss: 1.5043 - accuracy: 0.8176
# Epoch 94/100
# 1563/1563 [==============================] - 75s 48ms/step - loss: 1.5005 - accuracy: 0.8179
# Epoch 95/100
# 1563/1563 [==============================] - 75s 48ms/step - loss: 1.4866 - accuracy: 0.8227
# Epoch 96/100
# 1563/1563 [==============================] - 75s 48ms/step - loss: 1.4913 - accuracy: 0.8188
# Epoch 97/100
# 1563/1563 [==============================] - 76s 49ms/step - loss: 1.4807 - accuracy: 0.8253
# Epoch 98/100
# 1563/1563 [==============================] - 74s 48ms/step - loss: 1.4962 - accuracy: 0.8178
# Epoch 99/100
# 1563/1563 [==============================] - 76s 48ms/step - loss: 1.4881 - accuracy: 0.8209
# Epoch 100/100
# 1563/1563 [==============================] - 76s 49ms/step - loss: 1.4821 - accuracy: 0.8239

# %%
import matplotlib.pyplot as plt

plt.plot(history_densenet121.history['loss'],'r')
plt.plot(history_resnet18.history['loss'],'b')
plt.title('Model training loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['DenseNet121','ResNet18'], loc='upper left')
plt.show()

# %%
plt.plot(history_densenet121.history['accuracy'], 'r')
plt.plot(history_resnet18.history['accuracy'], 'b')
plt.title('Model validation accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['DenseNet121', 'ResNet18'], loc='upper left')
plt.show()
