# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import backend, regularizers, initializers, models
from tensorflow.keras import layers
from tensorflow.keras.utils import plot_model

# %%
cifar100 = keras.datasets.cifar100

(x_train, y_train), (x_test, y_test) = cifar100.load_data()
x_train, x_test = x_train / 255.0, x_test / 255.0

print("x_train:", len(x_train), "x_test:", len(x_test))
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz
# 169009152/169001437 [==============================] - 3s 0us/step
# 169017344/169001437 [==============================] - 3s 0us/step
# x_train: 50000 x_test: 10000

# %%
def conv_block(input_tensor,
               filters,
               stage,
               block,
               strides=(2,2),
               bn_decay=0.9,
               bn_epsilon=1e-5):
  

  if backend.image_data_format() == 'channels_last':
    bn_axis=3
  else:
    bn_axis=1

  conv_name='conv'+str(stage)+block+'_branch'
  bn_name='bn'+str(stage)+block+'_branch'

  x = layers.Conv2D(filters,(3,3),strides=strides,padding='same',use_bias=False,kernel_initializer='he_normal',
                    kernel_regularizer=keras.regularizers.l2(1e-4),
                    name = conv_name+'2a')(input_tensor)

  x = layers.BatchNormalization(axis=bn_axis, momentum=bn_decay, epsilon=bn_epsilon,name=bn_name+'2a')(x)

  x = layers.Activation('relu')(x)
  
  x = layers.Conv2D(filters,(3,3),use_bias=False,padding='same',kernel_initializer='he_normal',
                    kernel_regularizer=keras.regularizers.l2(1e-4),
                    name = conv_name+'2b')(x)

  x = layers.BatchNormalization(axis=bn_axis, momentum=bn_decay, epsilon=bn_epsilon,name=bn_name+'2b')(x)


  shortcut = layers.Conv2D(filters,(3,3),strides=strides,padding='same',use_bias=False,kernel_initializer='he_normal',
                           kernel_regularizer=keras.regularizers.l2(1e-4),
                           name = conv_name+'1')(input_tensor)

  shortcut = layers.BatchNormalization(axis=bn_axis, momentum=bn_decay, epsilon=bn_epsilon,name=bn_name+'1')(shortcut)

  x = layers.add([x, shortcut])

  x = layers.Activation('relu')(x)

  return x

# %%
def identity_block(input_tensor,
                   filters,
                   stage,
                   block,
                   bn_decay=0.9,
                   bn_epsilon=1e-5):
  
  if backend.image_data_format() == 'channels_last':
    bn_axis=3
  else:
    bn_axis=1

  id_name='id'+str(stage)+block+'_branch'
  bn_name='bn'+str(stage)+block+'_branch'

  x = layers.Conv2D(filters,(3,3),padding='same',use_bias=False,kernel_initializer='he_normal',
                    kernel_regularizer=keras.regularizers.l2(1e-4),
                    name = id_name+'2a')(input_tensor)

  x = layers.BatchNormalization(axis=bn_axis,momentum=bn_decay, epsilon=bn_epsilon,name=bn_name+'2a')(x)

  x = layers.Activation('relu')(x)

  x = layers.Conv2D(filters,(3,3),padding='same',use_bias=False,kernel_initializer='he_normal',
                    kernel_regularizer=keras.regularizers.l2(1e-4),
                    name = id_name+'2b')(x)

  x = layers.BatchNormalization(axis=bn_axis,momentum=bn_decay, epsilon=bn_epsilon,name=bn_name+'2b')(x)

  x = layers.add([x,input_tensor])
  
  x = layers.Activation('relu')(x)

  return x

# %%
def resnet34(num_classes,
             batch_size=None,
             use_l2_regularizer=True,
             rescale_inputs=False,
             bn_decay=0.9,
             bn_epsilon=1e-5):

  input_shape = (32, 32, 3)
  img_input = layers.Input(shape=input_shape, batch_size=batch_size)
  if rescale_inputs:
    x = layers.Lambda(
        lambda x: x * 255.0 - backend.constant(
            imagenet_preprocessing.CHANNEL_MEANS,
            shape=[1, 1, 3],
            dtype=x.dtype),
        name='rescale')(
            img_input)
  else:
    x = img_input

  if backend.image_data_format() == 'channels_first':
    x = layers.Permute((3, 1, 2))(x)
    bn_axis = 1
  else:  
    bn_axis = 3

  block_config = dict(
      bn_decay=bn_decay,
      bn_epsilon=bn_epsilon)
  x = layers.ZeroPadding2D(padding=(3, 3), name='conv1_pad')(x)
  x = layers.Conv2D(
      64, (7, 7),
      strides=(2, 2),
      padding='valid',
      use_bias=False,
      kernel_initializer='he_normal',
      kernel_regularizer=keras.regularizers.l2(1e-4),
      name='conv1')(
          x)
  x = layers.BatchNormalization(
      axis=bn_axis,
      momentum=bn_decay,
      epsilon=bn_epsilon,
      name='bn_conv1')(
          x)
  x = layers.Activation('relu')(x)
  x = layers.MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)

  x = identity_block(x, 64, stage=2, block='a', **block_config)
  x = identity_block(x, 64, stage=2, block='b', **block_config)
  x = identity_block(x, 64, stage=2, block='c', **block_config)

  x = conv_block(x,128, stage=3, block='a', **block_config)
  x = identity_block(x, 128, stage=3, block='b', **block_config)
  x = identity_block(x, 128, stage=3, block='c', **block_config)
  x = identity_block(x, 128, stage=3, block='d', **block_config)

  x = conv_block(x,256, stage=4, block='a', **block_config)
  x = identity_block(x,256, stage=4, block='b', **block_config)
  x = identity_block(x, 256, stage=4, block='c', **block_config)
  x = identity_block(x, 256, stage=4, block='d', **block_config)
  x = identity_block(x, 256, stage=4, block='e', **block_config)
  x = identity_block(x, 256, stage=4, block='f', **block_config)

  x = conv_block(x,512, stage=5, block='a', **block_config)
  x = identity_block(x, 512, stage=5, block='b', **block_config)
  x = identity_block(x, 512, stage=5, block='c', **block_config)

  x = layers.GlobalAveragePooling2D()(x)
  x = layers.Dense(
      num_classes,
      kernel_initializer=initializers.RandomNormal(stddev=0.01),
      kernel_regularizer=keras.regularizers.l2(1e-4),
      bias_regularizer=keras.regularizers.l2(1e-4),
      name='fc1000')(
          x)

  x = layers.Activation('softmax', dtype='float32')(x)

  return models.Model(img_input, x, name='resnet34')

# %%
resnet34 = resnet34(num_classes=100)
resnet34.summary()
# Out:
# Model: "resnet34"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 32, 32, 3)]  0           []
#
#  conv1_pad (ZeroPadding2D)      (None, 38, 38, 3)    0           ['input_1[0][0]']
#
#  conv1 (Conv2D)                 (None, 16, 16, 64)   9408        ['conv1_pad[0][0]']
#
#  bn_conv1 (BatchNormalization)  (None, 16, 16, 64)   256         ['conv1[0][0]']
#
#  activation (Activation)        (None, 16, 16, 64)   0           ['bn_conv1[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, 8, 8, 64)     0           ['activation[0][0]']
#
#  id2a_branch2a (Conv2D)         (None, 8, 8, 64)     36864       ['max_pooling2d[0][0]']
#
#  bn2a_branch2a (BatchNormalizat  (None, 8, 8, 64)    256         ['id2a_branch2a[0][0]']
#  ion)
#
#  activation_1 (Activation)      (None, 8, 8, 64)     0           ['bn2a_branch2a[0][0]']
#
#  id2a_branch2b (Conv2D)         (None, 8, 8, 64)     36864       ['activation_1[0][0]']
#
#  bn2a_branch2b (BatchNormalizat  (None, 8, 8, 64)    256         ['id2a_branch2b[0][0]']
#  ion)
#
#  add (Add)                      (None, 8, 8, 64)     0           ['bn2a_branch2b[0][0]',
#                                                                   'max_pooling2d[0][0]']
#
#  activation_2 (Activation)      (None, 8, 8, 64)     0           ['add[0][0]']
#
#  id2b_branch2a (Conv2D)         (None, 8, 8, 64)     36864       ['activation_2[0][0]']
#
#  bn2b_branch2a (BatchNormalizat  (None, 8, 8, 64)    256         ['id2b_branch2a[0][0]']
#  ion)
#
#  activation_3 (Activation)      (None, 8, 8, 64)     0           ['bn2b_branch2a[0][0]']
#
#  id2b_branch2b (Conv2D)         (None, 8, 8, 64)     36864       ['activation_3[0][0]']
#
#  bn2b_branch2b (BatchNormalizat  (None, 8, 8, 64)    256         ['id2b_branch2b[0][0]']
#  ion)
#
#  add_1 (Add)                    (None, 8, 8, 64)     0           ['bn2b_branch2b[0][0]',
#                                                                   'activation_2[0][0]']
#
#  activation_4 (Activation)      (None, 8, 8, 64)     0           ['add_1[0][0]']
#
#  id2c_branch2a (Conv2D)         (None, 8, 8, 64)     36864       ['activation_4[0][0]']
#
#  bn2c_branch2a (BatchNormalizat  (None, 8, 8, 64)    256         ['id2c_branch2a[0][0]']
#  ion)
#
#  activation_5 (Activation)      (None, 8, 8, 64)     0           ['bn2c_branch2a[0][0]']
#
#  id2c_branch2b (Conv2D)         (None, 8, 8, 64)     36864       ['activation_5[0][0]']
#
#  bn2c_branch2b (BatchNormalizat  (None, 8, 8, 64)    256         ['id2c_branch2b[0][0]']
#  ion)
#
#  add_2 (Add)                    (None, 8, 8, 64)     0           ['bn2c_branch2b[0][0]',
#                                                                   'activation_4[0][0]']
#
#  activation_6 (Activation)      (None, 8, 8, 64)     0           ['add_2[0][0]']
#
#  conv3a_branch2a (Conv2D)       (None, 4, 4, 128)    73728       ['activation_6[0][0]']
#
#  bn3a_branch2a (BatchNormalizat  (None, 4, 4, 128)   512         ['conv3a_branch2a[0][0]']
#  ion)
#
#  activation_7 (Activation)      (None, 4, 4, 128)    0           ['bn3a_branch2a[0][0]']
#
#  conv3a_branch2b (Conv2D)       (None, 4, 4, 128)    147456      ['activation_7[0][0]']
#
#  conv3a_branch1 (Conv2D)        (None, 4, 4, 128)    73728       ['activation_6[0][0]']
#
#  bn3a_branch2b (BatchNormalizat  (None, 4, 4, 128)   512         ['conv3a_branch2b[0][0]']
#  ion)
#
#  bn3a_branch1 (BatchNormalizati  (None, 4, 4, 128)   512         ['conv3a_branch1[0][0]']
#  on)
#
#  add_3 (Add)                    (None, 4, 4, 128)    0           ['bn3a_branch2b[0][0]',
#                                                                   'bn3a_branch1[0][0]']
#
#  activation_8 (Activation)      (None, 4, 4, 128)    0           ['add_3[0][0]']
#
#  id3b_branch2a (Conv2D)         (None, 4, 4, 128)    147456      ['activation_8[0][0]']
#
#  bn3b_branch2a (BatchNormalizat  (None, 4, 4, 128)   512         ['id3b_branch2a[0][0]']
#  ion)
#
#  activation_9 (Activation)      (None, 4, 4, 128)    0           ['bn3b_branch2a[0][0]']
#
#  id3b_branch2b (Conv2D)         (None, 4, 4, 128)    147456      ['activation_9[0][0]']
#
#  bn3b_branch2b (BatchNormalizat  (None, 4, 4, 128)   512         ['id3b_branch2b[0][0]']
#  ion)
#
#  add_4 (Add)                    (None, 4, 4, 128)    0           ['bn3b_branch2b[0][0]',
#                                                                   'activation_8[0][0]']
#
#  activation_10 (Activation)     (None, 4, 4, 128)    0           ['add_4[0][0]']
#
#  id3c_branch2a (Conv2D)         (None, 4, 4, 128)    147456      ['activation_10[0][0]']
#
#  bn3c_branch2a (BatchNormalizat  (None, 4, 4, 128)   512         ['id3c_branch2a[0][0]']
#  ion)
#
#  activation_11 (Activation)     (None, 4, 4, 128)    0           ['bn3c_branch2a[0][0]']
#
#  id3c_branch2b (Conv2D)         (None, 4, 4, 128)    147456      ['activation_11[0][0]']
#
#  bn3c_branch2b (BatchNormalizat  (None, 4, 4, 128)   512         ['id3c_branch2b[0][0]']
#  ion)
#
#  add_5 (Add)                    (None, 4, 4, 128)    0           ['bn3c_branch2b[0][0]',
#                                                                   'activation_10[0][0]']
#
#  activation_12 (Activation)     (None, 4, 4, 128)    0           ['add_5[0][0]']
#
#  id3d_branch2a (Conv2D)         (None, 4, 4, 128)    147456      ['activation_12[0][0]']
#
#  bn3d_branch2a (BatchNormalizat  (None, 4, 4, 128)   512         ['id3d_branch2a[0][0]']
#  ion)
#
#  activation_13 (Activation)     (None, 4, 4, 128)    0           ['bn3d_branch2a[0][0]']
#
#  id3d_branch2b (Conv2D)         (None, 4, 4, 128)    147456      ['activation_13[0][0]']
#
#  bn3d_branch2b (BatchNormalizat  (None, 4, 4, 128)   512         ['id3d_branch2b[0][0]']
#  ion)
#
#  add_6 (Add)                    (None, 4, 4, 128)    0           ['bn3d_branch2b[0][0]',
#                                                                   'activation_12[0][0]']
#
#  activation_14 (Activation)     (None, 4, 4, 128)    0           ['add_6[0][0]']
#
#  conv4a_branch2a (Conv2D)       (None, 2, 2, 256)    294912      ['activation_14[0][0]']
#
#  bn4a_branch2a (BatchNormalizat  (None, 2, 2, 256)   1024        ['conv4a_branch2a[0][0]']
#  ion)
#
#  activation_15 (Activation)     (None, 2, 2, 256)    0           ['bn4a_branch2a[0][0]']
#
#  conv4a_branch2b (Conv2D)       (None, 2, 2, 256)    589824      ['activation_15[0][0]']
#
#  conv4a_branch1 (Conv2D)        (None, 2, 2, 256)    294912      ['activation_14[0][0]']
#
#  bn4a_branch2b (BatchNormalizat  (None, 2, 2, 256)   1024        ['conv4a_branch2b[0][0]']
#  ion)
#
#  bn4a_branch1 (BatchNormalizati  (None, 2, 2, 256)   1024        ['conv4a_branch1[0][0]']
#  on)
#
#  add_7 (Add)                    (None, 2, 2, 256)    0           ['bn4a_branch2b[0][0]',
#                                                                   'bn4a_branch1[0][0]']
#
#  activation_16 (Activation)     (None, 2, 2, 256)    0           ['add_7[0][0]']
#
#  id4b_branch2a (Conv2D)         (None, 2, 2, 256)    589824      ['activation_16[0][0]']
#
#  bn4b_branch2a (BatchNormalizat  (None, 2, 2, 256)   1024        ['id4b_branch2a[0][0]']
#  ion)
#
#  activation_17 (Activation)     (None, 2, 2, 256)    0           ['bn4b_branch2a[0][0]']
#
#  id4b_branch2b (Conv2D)         (None, 2, 2, 256)    589824      ['activation_17[0][0]']
#
#  bn4b_branch2b (BatchNormalizat  (None, 2, 2, 256)   1024        ['id4b_branch2b[0][0]']
#  ion)
#
#  add_8 (Add)                    (None, 2, 2, 256)    0           ['bn4b_branch2b[0][0]',
#                                                                   'activation_16[0][0]']
#
#  activation_18 (Activation)     (None, 2, 2, 256)    0           ['add_8[0][0]']
#
#  id4c_branch2a (Conv2D)         (None, 2, 2, 256)    589824      ['activation_18[0][0]']
#
#  bn4c_branch2a (BatchNormalizat  (None, 2, 2, 256)   1024        ['id4c_branch2a[0][0]']
#  ion)
#
#  activation_19 (Activation)     (None, 2, 2, 256)    0           ['bn4c_branch2a[0][0]']
#
#  id4c_branch2b (Conv2D)         (None, 2, 2, 256)    589824      ['activation_19[0][0]']
#
#  bn4c_branch2b (BatchNormalizat  (None, 2, 2, 256)   1024        ['id4c_branch2b[0][0]']
#  ion)
#
#  add_9 (Add)                    (None, 2, 2, 256)    0           ['bn4c_branch2b[0][0]',
#                                                                   'activation_18[0][0]']
#
#  activation_20 (Activation)     (None, 2, 2, 256)    0           ['add_9[0][0]']
#
#  id4d_branch2a (Conv2D)         (None, 2, 2, 256)    589824      ['activation_20[0][0]']
#
#  bn4d_branch2a (BatchNormalizat  (None, 2, 2, 256)   1024        ['id4d_branch2a[0][0]']
#  ion)
#
#  activation_21 (Activation)     (None, 2, 2, 256)    0           ['bn4d_branch2a[0][0]']
#
#  id4d_branch2b (Conv2D)         (None, 2, 2, 256)    589824      ['activation_21[0][0]']
#
#  bn4d_branch2b (BatchNormalizat  (None, 2, 2, 256)   1024        ['id4d_branch2b[0][0]']
#  ion)
#
#  add_10 (Add)                   (None, 2, 2, 256)    0           ['bn4d_branch2b[0][0]',
#                                                                   'activation_20[0][0]']
#
#  activation_22 (Activation)     (None, 2, 2, 256)    0           ['add_10[0][0]']
#
#  id4e_branch2a (Conv2D)         (None, 2, 2, 256)    589824      ['activation_22[0][0]']
#
#  bn4e_branch2a (BatchNormalizat  (None, 2, 2, 256)   1024        ['id4e_branch2a[0][0]']
#  ion)
#
#  activation_23 (Activation)     (None, 2, 2, 256)    0           ['bn4e_branch2a[0][0]']
#
#  id4e_branch2b (Conv2D)         (None, 2, 2, 256)    589824      ['activation_23[0][0]']
#
#  bn4e_branch2b (BatchNormalizat  (None, 2, 2, 256)   1024        ['id4e_branch2b[0][0]']
#  ion)
#
#  add_11 (Add)                   (None, 2, 2, 256)    0           ['bn4e_branch2b[0][0]',
#                                                                   'activation_22[0][0]']
#
#  activation_24 (Activation)     (None, 2, 2, 256)    0           ['add_11[0][0]']
#
#  id4f_branch2a (Conv2D)         (None, 2, 2, 256)    589824      ['activation_24[0][0]']
#
#  bn4f_branch2a (BatchNormalizat  (None, 2, 2, 256)   1024        ['id4f_branch2a[0][0]']
#  ion)
#
#  activation_25 (Activation)     (None, 2, 2, 256)    0           ['bn4f_branch2a[0][0]']
#
#  id4f_branch2b (Conv2D)         (None, 2, 2, 256)    589824      ['activation_25[0][0]']
#
#  bn4f_branch2b (BatchNormalizat  (None, 2, 2, 256)   1024        ['id4f_branch2b[0][0]']
#  ion)
#
#  add_12 (Add)                   (None, 2, 2, 256)    0           ['bn4f_branch2b[0][0]',
#                                                                   'activation_24[0][0]']
#
#  activation_26 (Activation)     (None, 2, 2, 256)    0           ['add_12[0][0]']
#
#  conv5a_branch2a (Conv2D)       (None, 1, 1, 512)    1179648     ['activation_26[0][0]']
#
#  bn5a_branch2a (BatchNormalizat  (None, 1, 1, 512)   2048        ['conv5a_branch2a[0][0]']
#  ion)
#
#  activation_27 (Activation)     (None, 1, 1, 512)    0           ['bn5a_branch2a[0][0]']
#
#  conv5a_branch2b (Conv2D)       (None, 1, 1, 512)    2359296     ['activation_27[0][0]']
#
#  conv5a_branch1 (Conv2D)        (None, 1, 1, 512)    1179648     ['activation_26[0][0]']
#
#  bn5a_branch2b (BatchNormalizat  (None, 1, 1, 512)   2048        ['conv5a_branch2b[0][0]']
#  ion)
#
#  bn5a_branch1 (BatchNormalizati  (None, 1, 1, 512)   2048        ['conv5a_branch1[0][0]']
#  on)
#
#  add_13 (Add)                   (None, 1, 1, 512)    0           ['bn5a_branch2b[0][0]',
#                                                                   'bn5a_branch1[0][0]']
#
#  activation_28 (Activation)     (None, 1, 1, 512)    0           ['add_13[0][0]']
#
#  id5b_branch2a (Conv2D)         (None, 1, 1, 512)    2359296     ['activation_28[0][0]']
#
#  bn5b_branch2a (BatchNormalizat  (None, 1, 1, 512)   2048        ['id5b_branch2a[0][0]']
#  ion)
#
#  activation_29 (Activation)     (None, 1, 1, 512)    0           ['bn5b_branch2a[0][0]']
#
#  id5b_branch2b (Conv2D)         (None, 1, 1, 512)    2359296     ['activation_29[0][0]']
#
#  bn5b_branch2b (BatchNormalizat  (None, 1, 1, 512)   2048        ['id5b_branch2b[0][0]']
#  ion)
#
#  add_14 (Add)                   (None, 1, 1, 512)    0           ['bn5b_branch2b[0][0]',
#                                                                   'activation_28[0][0]']
#
#  activation_30 (Activation)     (None, 1, 1, 512)    0           ['add_14[0][0]']
#
#  id5c_branch2a (Conv2D)         (None, 1, 1, 512)    2359296     ['activation_30[0][0]']
#
#  bn5c_branch2a (BatchNormalizat  (None, 1, 1, 512)   2048        ['id5c_branch2a[0][0]']
#  ion)
#
#  activation_31 (Activation)     (None, 1, 1, 512)    0           ['bn5c_branch2a[0][0]']
#
#  id5c_branch2b (Conv2D)         (None, 1, 1, 512)    2359296     ['activation_31[0][0]']
#
#  bn5c_branch2b (BatchNormalizat  (None, 1, 1, 512)   2048        ['id5c_branch2b[0][0]']
#  ion)
#
#  add_15 (Add)                   (None, 1, 1, 512)    0           ['bn5c_branch2b[0][0]',
#                                                                   'activation_30[0][0]']
#
#  activation_32 (Activation)     (None, 1, 1, 512)    0           ['add_15[0][0]']
#
#  global_average_pooling2d (Glob  (None, 512)         0           ['activation_32[0][0]']
#  alAveragePooling2D)
#
#  fc1000 (Dense)                 (None, 100)          51300       ['global_average_pooling2d[0][0]'
#                                                                  ]
#
#  activation_33 (Activation)     (None, 100)          0           ['fc1000[0][0]']
#
# ==================================================================================================
# Total params: 22,729,252
# Trainable params: 22,712,228
# Non-trainable params: 17,024
# __________________________________________________________________________________________________

# %%
plot_model(resnet34,show_shapes=True)

# %%
resnet34.compile(optimizer='SGD',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

history_resnet34 = resnet34.fit(x_train, y_train, epochs=100)
# Out:
# Epoch 1/100
# 1563/1563 [==============================] - 56s 27ms/step - loss: 5.4794 - accuracy: 0.1228
# Epoch 2/100
# 1563/1563 [==============================] - 43s 27ms/step - loss: 4.8691 - accuracy: 0.2196
# Epoch 3/100
# 1563/1563 [==============================] - 42s 27ms/step - loss: 4.5084 - accuracy: 0.2870
# Epoch 4/100
# 1563/1563 [==============================] - 42s 27ms/step - loss: 4.2343 - accuracy: 0.3384
# Epoch 5/100
# 1563/1563 [==============================] - 42s 27ms/step - loss: 4.0000 - accuracy: 0.3871
# Epoch 6/100
# 1563/1563 [==============================] - 42s 27ms/step - loss: 3.7999 - accuracy: 0.4278
# Epoch 7/100
# 1563/1563 [==============================] - 42s 27ms/step - loss: 3.6144 - accuracy: 0.4694
# Epoch 8/100
# 1563/1563 [==============================] - 42s 27ms/step - loss: 3.4335 - accuracy: 0.5097
# Epoch 9/100
# 1563/1563 [==============================] - 42s 27ms/step - loss: 3.2696 - accuracy: 0.5450
# Epoch 10/100
# 1563/1563 [==============================] - 42s 27ms/step - loss: 3.1119 - accuracy: 0.5843
# Epoch 11/100
# 1563/1563 [==============================] - 42s 27ms/step - loss: 2.9640 - accuracy: 0.6164
# Epoch 12/100
# 1563/1563 [==============================] - 42s 27ms/step - loss: 2.8182 - accuracy: 0.6531
# Epoch 13/100
# 1563/1563 [==============================] - 42s 27ms/step - loss: 2.6899 - accuracy: 0.6833
# Epoch 14/100
# 1563/1563 [==============================] - 42s 27ms/step - loss: 2.5578 - accuracy: 0.7215
# Epoch 15/100
# 1563/1563 [==============================] - 42s 27ms/step - loss: 2.4348 - accuracy: 0.7541
# Epoch 16/100
# 1563/1563 [==============================] - 42s 27ms/step - loss: 2.3399 - accuracy: 0.7796
# Epoch 17/100
# 1563/1563 [==============================] - 42s 27ms/step - loss: 2.2601 - accuracy: 0.8017
# Epoch 18/100
# 1563/1563 [==============================] - 42s 27ms/step - loss: 2.1693 - accuracy: 0.8249
# Epoch 19/100
# 1563/1563 [==============================] - 42s 27ms/step - loss: 2.0940 - accuracy: 0.8490
# Epoch 20/100
# 1563/1563 [==============================] - 42s 27ms/step - loss: 2.0417 - accuracy: 0.8642
# Epoch 21/100
# 1563/1563 [==============================] - 42s 27ms/step - loss: 1.9623 - accuracy: 0.8870
# Epoch 22/100
# 1563/1563 [==============================] - 42s 27ms/step - loss: 1.9373 - accuracy: 0.8933
# Epoch 23/100
# 1563/1563 [==============================] - 42s 27ms/step - loss: 1.8950 - accuracy: 0.9051
# Epoch 24/100
# 1563/1563 [==============================] - 42s 27ms/step - loss: 1.8651 - accuracy: 0.9105
# Epoch 25/100
# 1563/1563 [==============================] - 42s 27ms/step - loss: 1.8402 - accuracy: 0.9196
# Epoch 26/100
# 1563/1563 [==============================] - 42s 27ms/step - loss: 1.8020 - accuracy: 0.9290
# Epoch 27/100
# 1563/1563 [==============================] - 41s 27ms/step - loss: 1.7720 - accuracy: 0.9364
# Epoch 28/100
# 1563/1563 [==============================] - 42s 27ms/step - loss: 1.7467 - accuracy: 0.9446
# Epoch 29/100
# 1563/1563 [==============================] - 41s 27ms/step - loss: 1.7285 - accuracy: 0.9468
# Epoch 30/100
# 1563/1563 [==============================] - 41s 27ms/step - loss: 1.7154 - accuracy: 0.9486
# Epoch 31/100
# 1563/1563 [==============================] - 42s 27ms/step - loss: 1.6892 - accuracy: 0.9563
# Epoch 32/100
# 1563/1563 [==============================] - 42s 27ms/step - loss: 1.6745 - accuracy: 0.9581
# Epoch 33/100
# 1563/1563 [==============================] - 41s 27ms/step - loss: 1.6469 - accuracy: 0.9653
# Epoch 34/100
# 1563/1563 [==============================] - 42s 27ms/step - loss: 1.6409 - accuracy: 0.9650
# Epoch 35/100
# 1563/1563 [==============================] - 41s 27ms/step - loss: 1.6372 - accuracy: 0.9636
# Epoch 36/100
# 1563/1563 [==============================] - 41s 27ms/step - loss: 1.6151 - accuracy: 0.9687
# Epoch 37/100
# 1563/1563 [==============================] - 41s 27ms/step - loss: 1.6033 - accuracy: 0.9704
# Epoch 38/100
# 1563/1563 [==============================] - 41s 27ms/step - loss: 1.5887 - accuracy: 0.9726
# Epoch 39/100
# 1563/1563 [==============================] - 42s 27ms/step - loss: 1.5895 - accuracy: 0.9703
# Epoch 40/100
# 1563/1563 [==============================] - 41s 27ms/step - loss: 1.5789 - accuracy: 0.9708
# Epoch 41/100
# 1563/1563 [==============================] - 41s 27ms/step - loss: 1.5559 - accuracy: 0.9761
# Epoch 42/100
# 1563/1563 [==============================] - 41s 27ms/step - loss: 1.5491 - accuracy: 0.9756
# Epoch 43/100
# 1563/1563 [==============================] - 41s 27ms/step - loss: 1.5357 - accuracy: 0.9778
# Epoch 44/100
# 1563/1563 [==============================] - 41s 27ms/step - loss: 1.5277 - accuracy: 0.9783
# Epoch 45/100
# 1563/1563 [==============================] - 41s 27ms/step - loss: 1.5165 - accuracy: 0.9796
# Epoch 46/100
# 1563/1563 [==============================] - 41s 27ms/step - loss: 1.5126 - accuracy: 0.9792
# Epoch 47/100
# 1563/1563 [==============================] - 42s 27ms/step - loss: 1.5080 - accuracy: 0.9777
# Epoch 48/100
# 1563/1563 [==============================] - 41s 27ms/step - loss: 1.5002 - accuracy: 0.9774
# Epoch 49/100
# 1563/1563 [==============================] - 42s 27ms/step - loss: 1.4912 - accuracy: 0.9792
# Epoch 50/100
# 1563/1563 [==============================] - 42s 27ms/step - loss: 1.4808 - accuracy: 0.9792
# Epoch 51/100
# 1563/1563 [==============================] - 41s 27ms/step - loss: 1.4705 - accuracy: 0.9809
# Epoch 52/100
# 1563/1563 [==============================] - 41s 27ms/step - loss: 1.4555 - accuracy: 0.9835
# Epoch 53/100
# 1563/1563 [==============================] - 41s 27ms/step - loss: 1.4474 - accuracy: 0.9830
# Epoch 54/100
# 1563/1563 [==============================] - 42s 27ms/step - loss: 1.4437 - accuracy: 0.9825
# Epoch 55/100
# 1563/1563 [==============================] - 41s 27ms/step - loss: 1.4355 - accuracy: 0.9837
# Epoch 56/100
# 1563/1563 [==============================] - 41s 27ms/step - loss: 1.4362 - accuracy: 0.9802
# Epoch 57/100
# 1563/1563 [==============================] - 41s 27ms/step - loss: 1.4152 - accuracy: 0.9851
# Epoch 58/100
# 1563/1563 [==============================] - 41s 27ms/step - loss: 1.4118 - accuracy: 0.9841
# Epoch 59/100
# 1563/1563 [==============================] - 41s 27ms/step - loss: 1.4011 - accuracy: 0.9845
# Epoch 60/100
# 1563/1563 [==============================] - 41s 27ms/step - loss: 1.3993 - accuracy: 0.9832
# Epoch 61/100
# 1563/1563 [==============================] - 42s 27ms/step - loss: 1.3837 - accuracy: 0.9858
# Epoch 62/100
# 1563/1563 [==============================] - 41s 27ms/step - loss: 1.3701 - accuracy: 0.9882
# Epoch 63/100
# 1563/1563 [==============================] - 41s 27ms/step - loss: 1.3672 - accuracy: 0.9870
# Epoch 64/100
# 1563/1563 [==============================] - 41s 27ms/step - loss: 1.3562 - accuracy: 0.9883
# Epoch 65/100
# 1563/1563 [==============================] - 41s 27ms/step - loss: 1.3547 - accuracy: 0.9863
# Epoch 66/100
# 1563/1563 [==============================] - 41s 27ms/step - loss: 1.3482 - accuracy: 0.9858
# Epoch 67/100
# 1563/1563 [==============================] - 42s 27ms/step - loss: 1.3580 - accuracy: 0.9806
# Epoch 68/100
# 1563/1563 [==============================] - 41s 27ms/step - loss: 1.3532 - accuracy: 0.9804
# Epoch 69/100
# 1563/1563 [==============================] - 42s 27ms/step - loss: 1.3494 - accuracy: 0.9795
# Epoch 70/100
# 1563/1563 [==============================] - 41s 27ms/step - loss: 1.3353 - accuracy: 0.9822
# Epoch 71/100
# 1563/1563 [==============================] - 41s 27ms/step - loss: 1.3249 - accuracy: 0.9833
# Epoch 72/100
# 1563/1563 [==============================] - 41s 27ms/step - loss: 1.3186 - accuracy: 0.9832
# Epoch 73/100
# 1563/1563 [==============================] - 41s 27ms/step - loss: 1.3134 - accuracy: 0.9837
# Epoch 74/100
# 1563/1563 [==============================] - 41s 27ms/step - loss: 1.3145 - accuracy: 0.9804
# Epoch 75/100
# 1563/1563 [==============================] - 41s 27ms/step - loss: 1.3078 - accuracy: 0.9814
# Epoch 76/100
# 1563/1563 [==============================] - 41s 27ms/step - loss: 1.2928 - accuracy: 0.9842
# Epoch 77/100
# 1563/1563 [==============================] - 41s 27ms/step - loss: 1.2858 - accuracy: 0.9843
# Epoch 78/100
# 1563/1563 [==============================] - 41s 27ms/step - loss: 1.2744 - accuracy: 0.9863
# Epoch 79/100
# 1563/1563 [==============================] - 41s 27ms/step - loss: 1.2651 - accuracy: 0.9869
# Epoch 80/100
# 1563/1563 [==============================] - 41s 27ms/step - loss: 1.2651 - accuracy: 0.9848
# Epoch 81/100
# 1563/1563 [==============================] - 41s 27ms/step - loss: 1.2498 - accuracy: 0.9883
# Epoch 82/100
# 1563/1563 [==============================] - 41s 27ms/step - loss: 1.2347 - accuracy: 0.9910
# Epoch 83/100
# 1563/1563 [==============================] - 41s 27ms/step - loss: 1.2269 - accuracy: 0.9914
# Epoch 84/100
# 1563/1563 [==============================] - 42s 27ms/step - loss: 1.2158 - accuracy: 0.9928
# Epoch 85/100
# 1563/1563 [==============================] - 41s 27ms/step - loss: 1.2088 - accuracy: 0.9930
# Epoch 86/100
# 1563/1563 [==============================] - 41s 27ms/step - loss: 1.2024 - accuracy: 0.9927
# Epoch 87/100
# 1563/1563 [==============================] - 41s 27ms/step - loss: 1.1941 - accuracy: 0.9937
# Epoch 88/100
# 1563/1563 [==============================] - 41s 27ms/step - loss: 1.1865 - accuracy: 0.9937
# Epoch 89/100
# 1563/1563 [==============================] - 41s 27ms/step - loss: 1.1762 - accuracy: 0.9950
# Epoch 90/100
# 1563/1563 [==============================] - 42s 27ms/step - loss: 1.1683 - accuracy: 0.9955
# Epoch 91/100
# 1563/1563 [==============================] - 41s 27ms/step - loss: 1.1635 - accuracy: 0.9948
# Epoch 92/100
# 1563/1563 [==============================] - 42s 27ms/step - loss: 1.1538 - accuracy: 0.9959
# Epoch 93/100
# 1563/1563 [==============================] - 41s 27ms/step - loss: 1.1526 - accuracy: 0.9936
# Epoch 94/100
# 1563/1563 [==============================] - 41s 27ms/step - loss: 1.1442 - accuracy: 0.9948
# Epoch 95/100
# 1563/1563 [==============================] - 41s 27ms/step - loss: 1.1357 - accuracy: 0.9950
# Epoch 96/100
# 1563/1563 [==============================] - 42s 27ms/step - loss: 1.1294 - accuracy: 0.9952
# Epoch 97/100
# 1563/1563 [==============================] - 41s 27ms/step - loss: 1.1236 - accuracy: 0.9951
# Epoch 98/100
# 1563/1563 [==============================] - 41s 27ms/step - loss: 1.1135 - accuracy: 0.9964
# Epoch 99/100
# 1563/1563 [==============================] - 42s 27ms/step - loss: 1.1085 - accuracy: 0.9959
# Epoch 100/100
# 1563/1563 [==============================] - 41s 27ms/step - loss: 1.1020 - accuracy: 0.9958

# %%
#BN-ReLU-Conv(1×1)-BN-ReLU-Conv(3×3)
def dense_block(input_tensor,
                filters,
                stage,
                block,
                bn_decay=0.9,
                bn_epsilon=1e-5):
  filters1,filters2=filters

  if backend.image_data_format() == 'channels_last':
    bn_axis=3
  else:
    bn_axis=1

  dense_name='dense'+str(stage)+block+'_branch'
  bn_name='bn'+str(stage)+block+'_branch'

  x = layers.BatchNormalization(axis=bn_axis,
                                momentum=bn_decay,
                                epsilon=bn_epsilon,
                                name=bn_name+'2a')(input_tensor)

  x = layers.Activation('relu')(x)

  x = layers.Conv2D(filters1,(1,1),use_bias=False,
                    kernel_initializer='he_normal',
                    kernel_regularizer=keras.regularizers.l2(1e-4),
                    name=dense_name+'2a')(x)

  x = layers.BatchNormalization(axis=bn_axis,
                                momentum=bn_decay,
                                epsilon=bn_epsilon,
                                name=bn_name+'2b')(x)
  
  x = layers.Activation('relu')(x)

  x = layers.Conv2D(filters2,(3,3),padding='same',use_bias=False,
                    kernel_initializer='he_normal',
                    kernel_regularizer=keras.regularizers.l2(1e-4),
                    name=dense_name+'2b')(x)

  x = layers.concatenate([x,input_tensor])

  return x

# %%
#BN → 1×1 convolutional layer → 2×2 average pooling layer
def transition_block(input_tensor,
                     filters,
                     stage,
                     block,
                     bn_decay=0.9,
                     bn_epsilon=1e-5):
  if backend.image_data_format() == 'channels_last':
    bn_axis=3
  else:
    bn_axis=1

  transition_name = 'transition'+str(stage)+block+'_branch'
  bn_name='bn'+str(stage)+block+'_branch'

  x = layers.BatchNormalization(axis=bn_axis,
                                momentum=bn_decay,
                                epsilon=bn_epsilon,
                                name=bn_name+'2a')(input_tensor)

  x = layers.Conv2D(filters,(1,1),use_bias=False,
                    kernel_initializer='he_normal',
                    kernel_regularizer=keras.regularizers.l2(1e-4),
                    name=transition_name+'2a')(x)

  x = layers.AveragePooling2D(pool_size=(2,2),strides=(2,2),padding='same')(x)

  return x

# %%
def DenseNet121(num_classes,
                batch_size=None,
                bn_decay=0.9,
                bn_epsilon=1e-5):
  
  input_shape=(32,32,3)
  input = layers.Input(shape=input_shape,batch_size=batch_size)

  if backend.image_data_format() == 'channels_last':
    bn_axis=3
    x = input
  else:
    x = layers.permute((3,1,2))(input)
    bn_axis=1

  config_block=dict(bn_decay=bn_decay,
                    bn_epsilon=bn_epsilon)
  x = layers.Conv2D(64,(7,7),strides=(2,2),padding='same',
                    kernel_initializer='he_normal',
                    kernel_regularizer=keras.regularizers.l2(1e-4),
                    name='conv1')(x)

  x = layers.MaxPooling2D(pool_size=(3,3),strides=(2,2),padding='same')(x)

  x = dense_block(x,[128,32],stage=2,block='a',**config_block)
  x = dense_block(x,[128,32],stage=2,block='b',**config_block)
  x = dense_block(x,[128,32],stage=2,block='c',**config_block)
  x = dense_block(x,[128,32],stage=2,block='d',**config_block)
  x = dense_block(x,[128,32],stage=2,block='e',**config_block)
  x = dense_block(x,[128,32],stage=2,block='f',**config_block)
  x = transition_block(x,32,stage=2,block='g',**config_block)

  x = dense_block(x,[128,32],stage=3,block='a',**config_block)
  x = dense_block(x,[128,32],stage=3,block='b',**config_block)
  x = dense_block(x,[128,32],stage=3,block='c',**config_block)
  x = dense_block(x,[128,32],stage=3,block='d',**config_block)
  x = dense_block(x,[128,32],stage=3,block='e',**config_block)
  x = dense_block(x,[128,32],stage=3,block='f',**config_block)
  x = dense_block(x,[128,32],stage=3,block='g',**config_block)
  x = dense_block(x,[128,32],stage=3,block='h',**config_block)
  x = dense_block(x,[128,32],stage=3,block='i',**config_block)
  x = dense_block(x,[128,32],stage=3,block='j',**config_block)
  x = dense_block(x,[128,32],stage=3,block='k',**config_block)
  x = dense_block(x,[128,32],stage=3,block='l',**config_block)
  x = transition_block(x,32,stage=3,block='m',**config_block)

  x = dense_block(x,[128,32],stage=4,block='a',**config_block)
  x = dense_block(x,[128,32],stage=4,block='b',**config_block)
  x = dense_block(x,[128,32],stage=4,block='c',**config_block)
  x = dense_block(x,[128,32],stage=4,block='d',**config_block)
  x = dense_block(x,[128,32],stage=4,block='e',**config_block)
  x = dense_block(x,[128,32],stage=4,block='f',**config_block)
  x = dense_block(x,[128,32],stage=4,block='g',**config_block)
  x = dense_block(x,[128,32],stage=4,block='h',**config_block)
  x = dense_block(x,[128,32],stage=4,block='i',**config_block)
  x = dense_block(x,[128,32],stage=4,block='j',**config_block)
  x = dense_block(x,[128,32],stage=4,block='k',**config_block)
  x = dense_block(x,[128,32],stage=4,block='l',**config_block)
  x = dense_block(x,[128,32],stage=4,block='m',**config_block)
  x = dense_block(x,[128,32],stage=4,block='n',**config_block)
  x = dense_block(x,[128,32],stage=4,block='o',**config_block)
  x = dense_block(x,[128,32],stage=4,block='p',**config_block)
  x = dense_block(x,[128,32],stage=4,block='q',**config_block)
  x = dense_block(x,[128,32],stage=4,block='r',**config_block)
  x = dense_block(x,[128,32],stage=4,block='s',**config_block)
  x = dense_block(x,[128,32],stage=4,block='t',**config_block)
  x = dense_block(x,[128,32],stage=4,block='u',**config_block)
  x = dense_block(x,[128,32],stage=4,block='v',**config_block)
  x = dense_block(x,[128,32],stage=4,block='w',**config_block)
  x = dense_block(x,[128,32],stage=4,block='x',**config_block)
  x = transition_block(x,32,stage=4,block='y',**config_block)

  x = dense_block(x,[128,32],stage=5,block='a',**config_block)
  x = dense_block(x,[128,32],stage=5,block='b',**config_block)
  x = dense_block(x,[128,32],stage=5,block='c',**config_block)
  x = dense_block(x,[128,32],stage=5,block='d',**config_block)
  x = dense_block(x,[128,32],stage=5,block='e',**config_block)
  x = dense_block(x,[128,32],stage=5,block='f',**config_block)
  x = dense_block(x,[128,32],stage=5,block='g',**config_block)
  x = dense_block(x,[128,32],stage=5,block='h',**config_block)
  x = dense_block(x,[128,32],stage=5,block='i',**config_block)
  x = dense_block(x,[128,32],stage=5,block='j',**config_block)
  x = dense_block(x,[128,32],stage=5,block='k',**config_block)
  x = dense_block(x,[128,32],stage=5,block='l',**config_block)
  x = dense_block(x,[128,32],stage=5,block='m',**config_block)
  x = dense_block(x,[128,32],stage=5,block='n',**config_block)
  x = dense_block(x,[128,32],stage=5,block='o',**config_block)
  x = dense_block(x,[128,32],stage=5,block='p',**config_block)
  x = transition_block(x,32,stage=5,block='q',**config_block)
  
  x = layers.GlobalAveragePooling2D()(x)
  x = layers.Dense(
      num_classes,
      kernel_initializer='he_normal',
      kernel_regularizer=keras.regularizers.l2(1e-4),
      bias_regularizer=keras.regularizers.l2(1e-4),
      name='1000D_full')(x)
  x = layers.Activation('softmax',dtype='float32')(x)

  return models.Model(input,x,name='DenseNet121')

# %%
densenet121=DenseNet121(num_classes=100)
densenet121.summary()
# Out:
# Model: "DenseNet121"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 32, 32, 3)]  0           []
#
#  conv1 (Conv2D)                 (None, 16, 16, 64)   9472        ['input_2[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 8, 8, 64)    0           ['conv1[0][0]']
#
#  bn2a_branch2a (BatchNormalizat  (None, 8, 8, 64)    256         ['max_pooling2d_1[0][0]']
#  ion)
#
#  activation_34 (Activation)     (None, 8, 8, 64)     0           ['bn2a_branch2a[0][0]']
#
#  dense2a_branch2a (Conv2D)      (None, 8, 8, 128)    8192        ['activation_34[0][0]']
#
#  bn2a_branch2b (BatchNormalizat  (None, 8, 8, 128)   512         ['dense2a_branch2a[0][0]']
#  ion)
#
#  activation_35 (Activation)     (None, 8, 8, 128)    0           ['bn2a_branch2b[0][0]']
#
#  dense2a_branch2b (Conv2D)      (None, 8, 8, 32)     36864       ['activation_35[0][0]']
#
#  concatenate (Concatenate)      (None, 8, 8, 96)     0           ['dense2a_branch2b[0][0]',
#                                                                   'max_pooling2d_1[0][0]']
#
#  bn2b_branch2a (BatchNormalizat  (None, 8, 8, 96)    384         ['concatenate[0][0]']
#  ion)
#
#  activation_36 (Activation)     (None, 8, 8, 96)     0           ['bn2b_branch2a[0][0]']
#
#  dense2b_branch2a (Conv2D)      (None, 8, 8, 128)    12288       ['activation_36[0][0]']
#
#  bn2b_branch2b (BatchNormalizat  (None, 8, 8, 128)   512         ['dense2b_branch2a[0][0]']
#  ion)
#
#  activation_37 (Activation)     (None, 8, 8, 128)    0           ['bn2b_branch2b[0][0]']
#
#  dense2b_branch2b (Conv2D)      (None, 8, 8, 32)     36864       ['activation_37[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 8, 8, 128)    0           ['dense2b_branch2b[0][0]',
#                                                                   'concatenate[0][0]']
#
#  bn2c_branch2a (BatchNormalizat  (None, 8, 8, 128)   512         ['concatenate_1[0][0]']
#  ion)
#
#  activation_38 (Activation)     (None, 8, 8, 128)    0           ['bn2c_branch2a[0][0]']
#
#  dense2c_branch2a (Conv2D)      (None, 8, 8, 128)    16384       ['activation_38[0][0]']
#
#  bn2c_branch2b (BatchNormalizat  (None, 8, 8, 128)   512         ['dense2c_branch2a[0][0]']
#  ion)
#
#  activation_39 (Activation)     (None, 8, 8, 128)    0           ['bn2c_branch2b[0][0]']
#
#  dense2c_branch2b (Conv2D)      (None, 8, 8, 32)     36864       ['activation_39[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 8, 8, 160)    0           ['dense2c_branch2b[0][0]',
#                                                                   'concatenate_1[0][0]']
#
#  bn2d_branch2a (BatchNormalizat  (None, 8, 8, 160)   640         ['concatenate_2[0][0]']
#  ion)
#
#  activation_40 (Activation)     (None, 8, 8, 160)    0           ['bn2d_branch2a[0][0]']
#
#  dense2d_branch2a (Conv2D)      (None, 8, 8, 128)    20480       ['activation_40[0][0]']
#
#  bn2d_branch2b (BatchNormalizat  (None, 8, 8, 128)   512         ['dense2d_branch2a[0][0]']
#  ion)
#
#  activation_41 (Activation)     (None, 8, 8, 128)    0           ['bn2d_branch2b[0][0]']
#
#  dense2d_branch2b (Conv2D)      (None, 8, 8, 32)     36864       ['activation_41[0][0]']
#
#  concatenate_3 (Concatenate)    (None, 8, 8, 192)    0           ['dense2d_branch2b[0][0]',
#                                                                   'concatenate_2[0][0]']
#
#  bn2e_branch2a (BatchNormalizat  (None, 8, 8, 192)   768         ['concatenate_3[0][0]']
#  ion)
#
#  activation_42 (Activation)     (None, 8, 8, 192)    0           ['bn2e_branch2a[0][0]']
#
#  dense2e_branch2a (Conv2D)      (None, 8, 8, 128)    24576       ['activation_42[0][0]']
#
#  bn2e_branch2b (BatchNormalizat  (None, 8, 8, 128)   512         ['dense2e_branch2a[0][0]']
#  ion)
#
#  activation_43 (Activation)     (None, 8, 8, 128)    0           ['bn2e_branch2b[0][0]']
#
#  dense2e_branch2b (Conv2D)      (None, 8, 8, 32)     36864       ['activation_43[0][0]']
#
#  concatenate_4 (Concatenate)    (None, 8, 8, 224)    0           ['dense2e_branch2b[0][0]',
#                                                                   'concatenate_3[0][0]']
#
#  bn2f_branch2a (BatchNormalizat  (None, 8, 8, 224)   896         ['concatenate_4[0][0]']
#  ion)
#
#  activation_44 (Activation)     (None, 8, 8, 224)    0           ['bn2f_branch2a[0][0]']
#
#  dense2f_branch2a (Conv2D)      (None, 8, 8, 128)    28672       ['activation_44[0][0]']
#
#  bn2f_branch2b (BatchNormalizat  (None, 8, 8, 128)   512         ['dense2f_branch2a[0][0]']
#  ion)
#
#  activation_45 (Activation)     (None, 8, 8, 128)    0           ['bn2f_branch2b[0][0]']
#
#  dense2f_branch2b (Conv2D)      (None, 8, 8, 32)     36864       ['activation_45[0][0]']
#
#  concatenate_5 (Concatenate)    (None, 8, 8, 256)    0           ['dense2f_branch2b[0][0]',
#                                                                   'concatenate_4[0][0]']
#
#  bn2g_branch2a (BatchNormalizat  (None, 8, 8, 256)   1024        ['concatenate_5[0][0]']
#  ion)
#
#  transition2g_branch2a (Conv2D)  (None, 8, 8, 32)    8192        ['bn2g_branch2a[0][0]']
#
#  average_pooling2d (AveragePool  (None, 4, 4, 32)    0           ['transition2g_branch2a[0][0]']
#  ing2D)
#
#  bn3a_branch2a (BatchNormalizat  (None, 4, 4, 32)    128         ['average_pooling2d[0][0]']
#  ion)
#
#  activation_46 (Activation)     (None, 4, 4, 32)     0           ['bn3a_branch2a[0][0]']
#
#  dense3a_branch2a (Conv2D)      (None, 4, 4, 128)    4096        ['activation_46[0][0]']
#
#  bn3a_branch2b (BatchNormalizat  (None, 4, 4, 128)   512         ['dense3a_branch2a[0][0]']
#  ion)
#
#  activation_47 (Activation)     (None, 4, 4, 128)    0           ['bn3a_branch2b[0][0]']
#
#  dense3a_branch2b (Conv2D)      (None, 4, 4, 32)     36864       ['activation_47[0][0]']
#
#  concatenate_6 (Concatenate)    (None, 4, 4, 64)     0           ['dense3a_branch2b[0][0]',
#                                                                   'average_pooling2d[0][0]']
#
#  bn3b_branch2a (BatchNormalizat  (None, 4, 4, 64)    256         ['concatenate_6[0][0]']
#  ion)
#
#  activation_48 (Activation)     (None, 4, 4, 64)     0           ['bn3b_branch2a[0][0]']
#
#  dense3b_branch2a (Conv2D)      (None, 4, 4, 128)    8192        ['activation_48[0][0]']
#
#  bn3b_branch2b (BatchNormalizat  (None, 4, 4, 128)   512         ['dense3b_branch2a[0][0]']
#  ion)
#
#  activation_49 (Activation)     (None, 4, 4, 128)    0           ['bn3b_branch2b[0][0]']
#
#  dense3b_branch2b (Conv2D)      (None, 4, 4, 32)     36864       ['activation_49[0][0]']
#
#  concatenate_7 (Concatenate)    (None, 4, 4, 96)     0           ['dense3b_branch2b[0][0]',
#                                                                   'concatenate_6[0][0]']
#
#  bn3c_branch2a (BatchNormalizat  (None, 4, 4, 96)    384         ['concatenate_7[0][0]']
#  ion)
#
#  activation_50 (Activation)     (None, 4, 4, 96)     0           ['bn3c_branch2a[0][0]']
#
#  dense3c_branch2a (Conv2D)      (None, 4, 4, 128)    12288       ['activation_50[0][0]']
#
#  bn3c_branch2b (BatchNormalizat  (None, 4, 4, 128)   512         ['dense3c_branch2a[0][0]']
#  ion)
#
#  activation_51 (Activation)     (None, 4, 4, 128)    0           ['bn3c_branch2b[0][0]']
#
#  dense3c_branch2b (Conv2D)      (None, 4, 4, 32)     36864       ['activation_51[0][0]']
#
#  concatenate_8 (Concatenate)    (None, 4, 4, 128)    0           ['dense3c_branch2b[0][0]',
#                                                                   'concatenate_7[0][0]']
#
#  bn3d_branch2a (BatchNormalizat  (None, 4, 4, 128)   512         ['concatenate_8[0][0]']
#  ion)
#
#  activation_52 (Activation)     (None, 4, 4, 128)    0           ['bn3d_branch2a[0][0]']
#
#  dense3d_branch2a (Conv2D)      (None, 4, 4, 128)    16384       ['activation_52[0][0]']
#
#  bn3d_branch2b (BatchNormalizat  (None, 4, 4, 128)   512         ['dense3d_branch2a[0][0]']
#  ion)
#
#  activation_53 (Activation)     (None, 4, 4, 128)    0           ['bn3d_branch2b[0][0]']
#
#  dense3d_branch2b (Conv2D)      (None, 4, 4, 32)     36864       ['activation_53[0][0]']
#
#  concatenate_9 (Concatenate)    (None, 4, 4, 160)    0           ['dense3d_branch2b[0][0]',
#                                                                   'concatenate_8[0][0]']
#
#  bn3e_branch2a (BatchNormalizat  (None, 4, 4, 160)   640         ['concatenate_9[0][0]']
#  ion)
#
#  activation_54 (Activation)     (None, 4, 4, 160)    0           ['bn3e_branch2a[0][0]']
#
#  dense3e_branch2a (Conv2D)      (None, 4, 4, 128)    20480       ['activation_54[0][0]']
#
#  bn3e_branch2b (BatchNormalizat  (None, 4, 4, 128)   512         ['dense3e_branch2a[0][0]']
#  ion)
#
#  activation_55 (Activation)     (None, 4, 4, 128)    0           ['bn3e_branch2b[0][0]']
#
#  dense3e_branch2b (Conv2D)      (None, 4, 4, 32)     36864       ['activation_55[0][0]']
#
#  concatenate_10 (Concatenate)   (None, 4, 4, 192)    0           ['dense3e_branch2b[0][0]',
#                                                                   'concatenate_9[0][0]']
#
#  bn3f_branch2a (BatchNormalizat  (None, 4, 4, 192)   768         ['concatenate_10[0][0]']
#  ion)
#
#  activation_56 (Activation)     (None, 4, 4, 192)    0           ['bn3f_branch2a[0][0]']
#
#  dense3f_branch2a (Conv2D)      (None, 4, 4, 128)    24576       ['activation_56[0][0]']
#
#  bn3f_branch2b (BatchNormalizat  (None, 4, 4, 128)   512         ['dense3f_branch2a[0][0]']
#  ion)
#
#  activation_57 (Activation)     (None, 4, 4, 128)    0           ['bn3f_branch2b[0][0]']
#
#  dense3f_branch2b (Conv2D)      (None, 4, 4, 32)     36864       ['activation_57[0][0]']
#
#  concatenate_11 (Concatenate)   (None, 4, 4, 224)    0           ['dense3f_branch2b[0][0]',
#                                                                   'concatenate_10[0][0]']
#
#  bn3g_branch2a (BatchNormalizat  (None, 4, 4, 224)   896         ['concatenate_11[0][0]']
#  ion)
#
#  activation_58 (Activation)     (None, 4, 4, 224)    0           ['bn3g_branch2a[0][0]']
#
#  dense3g_branch2a (Conv2D)      (None, 4, 4, 128)    28672       ['activation_58[0][0]']
#
#  bn3g_branch2b (BatchNormalizat  (None, 4, 4, 128)   512         ['dense3g_branch2a[0][0]']
#  ion)
#
#  activation_59 (Activation)     (None, 4, 4, 128)    0           ['bn3g_branch2b[0][0]']
#
#  dense3g_branch2b (Conv2D)      (None, 4, 4, 32)     36864       ['activation_59[0][0]']
#
#  concatenate_12 (Concatenate)   (None, 4, 4, 256)    0           ['dense3g_branch2b[0][0]',
#                                                                   'concatenate_11[0][0]']
#
#  bn3h_branch2a (BatchNormalizat  (None, 4, 4, 256)   1024        ['concatenate_12[0][0]']
#  ion)
#
#  activation_60 (Activation)     (None, 4, 4, 256)    0           ['bn3h_branch2a[0][0]']
#
#  dense3h_branch2a (Conv2D)      (None, 4, 4, 128)    32768       ['activation_60[0][0]']
#
#  bn3h_branch2b (BatchNormalizat  (None, 4, 4, 128)   512         ['dense3h_branch2a[0][0]']
#  ion)
#
#  activation_61 (Activation)     (None, 4, 4, 128)    0           ['bn3h_branch2b[0][0]']
#
#  dense3h_branch2b (Conv2D)      (None, 4, 4, 32)     36864       ['activation_61[0][0]']
#
#  concatenate_13 (Concatenate)   (None, 4, 4, 288)    0           ['dense3h_branch2b[0][0]',
#                                                                   'concatenate_12[0][0]']
#
#  bn3i_branch2a (BatchNormalizat  (None, 4, 4, 288)   1152        ['concatenate_13[0][0]']
#  ion)
#
#  activation_62 (Activation)     (None, 4, 4, 288)    0           ['bn3i_branch2a[0][0]']
#
#  dense3i_branch2a (Conv2D)      (None, 4, 4, 128)    36864       ['activation_62[0][0]']
#
#  bn3i_branch2b (BatchNormalizat  (None, 4, 4, 128)   512         ['dense3i_branch2a[0][0]']
#  ion)
#
#  activation_63 (Activation)     (None, 4, 4, 128)    0           ['bn3i_branch2b[0][0]']
#
#  dense3i_branch2b (Conv2D)      (None, 4, 4, 32)     36864       ['activation_63[0][0]']
#
#  concatenate_14 (Concatenate)   (None, 4, 4, 320)    0           ['dense3i_branch2b[0][0]',
#                                                                   'concatenate_13[0][0]']
#
#  bn3j_branch2a (BatchNormalizat  (None, 4, 4, 320)   1280        ['concatenate_14[0][0]']
#  ion)
#
#  activation_64 (Activation)     (None, 4, 4, 320)    0           ['bn3j_branch2a[0][0]']
#
#  dense3j_branch2a (Conv2D)      (None, 4, 4, 128)    40960       ['activation_64[0][0]']
#
#  bn3j_branch2b (BatchNormalizat  (None, 4, 4, 128)   512         ['dense3j_branch2a[0][0]']
#  ion)
#
#  activation_65 (Activation)     (None, 4, 4, 128)    0           ['bn3j_branch2b[0][0]']
#
#  dense3j_branch2b (Conv2D)      (None, 4, 4, 32)     36864       ['activation_65[0][0]']
#
#  concatenate_15 (Concatenate)   (None, 4, 4, 352)    0           ['dense3j_branch2b[0][0]',
#                                                                   'concatenate_14[0][0]']
#
#  bn3k_branch2a (BatchNormalizat  (None, 4, 4, 352)   1408        ['concatenate_15[0][0]']
#  ion)
#
#  activation_66 (Activation)     (None, 4, 4, 352)    0           ['bn3k_branch2a[0][0]']
#
#  dense3k_branch2a (Conv2D)      (None, 4, 4, 128)    45056       ['activation_66[0][0]']
#
#  bn3k_branch2b (BatchNormalizat  (None, 4, 4, 128)   512         ['dense3k_branch2a[0][0]']
#  ion)
#
#  activation_67 (Activation)     (None, 4, 4, 128)    0           ['bn3k_branch2b[0][0]']
#
#  dense3k_branch2b (Conv2D)      (None, 4, 4, 32)     36864       ['activation_67[0][0]']
#
#  concatenate_16 (Concatenate)   (None, 4, 4, 384)    0           ['dense3k_branch2b[0][0]',
#                                                                   'concatenate_15[0][0]']
#
#  bn3l_branch2a (BatchNormalizat  (None, 4, 4, 384)   1536        ['concatenate_16[0][0]']
#  ion)
#
#  activation_68 (Activation)     (None, 4, 4, 384)    0           ['bn3l_branch2a[0][0]']
#
#  dense3l_branch2a (Conv2D)      (None, 4, 4, 128)    49152       ['activation_68[0][0]']
#
#  bn3l_branch2b (BatchNormalizat  (None, 4, 4, 128)   512         ['dense3l_branch2a[0][0]']
#  ion)
#
#  activation_69 (Activation)     (None, 4, 4, 128)    0           ['bn3l_branch2b[0][0]']
#
#  dense3l_branch2b (Conv2D)      (None, 4, 4, 32)     36864       ['activation_69[0][0]']
#
#  concatenate_17 (Concatenate)   (None, 4, 4, 416)    0           ['dense3l_branch2b[0][0]',
#                                                                   'concatenate_16[0][0]']
#
#  bn3m_branch2a (BatchNormalizat  (None, 4, 4, 416)   1664        ['concatenate_17[0][0]']
#  ion)
#
#  transition3m_branch2a (Conv2D)  (None, 4, 4, 32)    13312       ['bn3m_branch2a[0][0]']
#
#  average_pooling2d_1 (AveragePo  (None, 2, 2, 32)    0           ['transition3m_branch2a[0][0]']
#  oling2D)
#
#  bn4a_branch2a (BatchNormalizat  (None, 2, 2, 32)    128         ['average_pooling2d_1[0][0]']
#  ion)
#
#  activation_70 (Activation)     (None, 2, 2, 32)     0           ['bn4a_branch2a[0][0]']
#
#  dense4a_branch2a (Conv2D)      (None, 2, 2, 128)    4096        ['activation_70[0][0]']
#
#  bn4a_branch2b (BatchNormalizat  (None, 2, 2, 128)   512         ['dense4a_branch2a[0][0]']
#  ion)
#
#  activation_71 (Activation)     (None, 2, 2, 128)    0           ['bn4a_branch2b[0][0]']
#
#  dense4a_branch2b (Conv2D)      (None, 2, 2, 32)     36864       ['activation_71[0][0]']
#
#  concatenate_18 (Concatenate)   (None, 2, 2, 64)     0           ['dense4a_branch2b[0][0]',
#                                                                   'average_pooling2d_1[0][0]']
#
#  bn4b_branch2a (BatchNormalizat  (None, 2, 2, 64)    256         ['concatenate_18[0][0]']
#  ion)
#
#  activation_72 (Activation)     (None, 2, 2, 64)     0           ['bn4b_branch2a[0][0]']
#
#  dense4b_branch2a (Conv2D)      (None, 2, 2, 128)    8192        ['activation_72[0][0]']
#
#  bn4b_branch2b (BatchNormalizat  (None, 2, 2, 128)   512         ['dense4b_branch2a[0][0]']
#  ion)
#
#  activation_73 (Activation)     (None, 2, 2, 128)    0           ['bn4b_branch2b[0][0]']
#
#  dense4b_branch2b (Conv2D)      (None, 2, 2, 32)     36864       ['activation_73[0][0]']
#
#  concatenate_19 (Concatenate)   (None, 2, 2, 96)     0           ['dense4b_branch2b[0][0]',
#                                                                   'concatenate_18[0][0]']
#
#  bn4c_branch2a (BatchNormalizat  (None, 2, 2, 96)    384         ['concatenate_19[0][0]']
#  ion)
#
#  activation_74 (Activation)     (None, 2, 2, 96)     0           ['bn4c_branch2a[0][0]']
#
#  dense4c_branch2a (Conv2D)      (None, 2, 2, 128)    12288       ['activation_74[0][0]']
#
#  bn4c_branch2b (BatchNormalizat  (None, 2, 2, 128)   512         ['dense4c_branch2a[0][0]']
#  ion)
#
#  activation_75 (Activation)     (None, 2, 2, 128)    0           ['bn4c_branch2b[0][0]']
#
#  dense4c_branch2b (Conv2D)      (None, 2, 2, 32)     36864       ['activation_75[0][0]']
#
#  concatenate_20 (Concatenate)   (None, 2, 2, 128)    0           ['dense4c_branch2b[0][0]',
#                                                                   'concatenate_19[0][0]']
#
#  bn4d_branch2a (BatchNormalizat  (None, 2, 2, 128)   512         ['concatenate_20[0][0]']
#  ion)
#
#  activation_76 (Activation)     (None, 2, 2, 128)    0           ['bn4d_branch2a[0][0]']
#
#  dense4d_branch2a (Conv2D)      (None, 2, 2, 128)    16384       ['activation_76[0][0]']
#
#  bn4d_branch2b (BatchNormalizat  (None, 2, 2, 128)   512         ['dense4d_branch2a[0][0]']
#  ion)
#
#  activation_77 (Activation)     (None, 2, 2, 128)    0           ['bn4d_branch2b[0][0]']
#
#  dense4d_branch2b (Conv2D)      (None, 2, 2, 32)     36864       ['activation_77[0][0]']
#
#  concatenate_21 (Concatenate)   (None, 2, 2, 160)    0           ['dense4d_branch2b[0][0]',
#                                                                   'concatenate_20[0][0]']
#
#  bn4e_branch2a (BatchNormalizat  (None, 2, 2, 160)   640         ['concatenate_21[0][0]']
#  ion)
#
#  activation_78 (Activation)     (None, 2, 2, 160)    0           ['bn4e_branch2a[0][0]']
#
#  dense4e_branch2a (Conv2D)      (None, 2, 2, 128)    20480       ['activation_78[0][0]']
#
#  bn4e_branch2b (BatchNormalizat  (None, 2, 2, 128)   512         ['dense4e_branch2a[0][0]']
#  ion)
#
#  activation_79 (Activation)     (None, 2, 2, 128)    0           ['bn4e_branch2b[0][0]']
#
#  dense4e_branch2b (Conv2D)      (None, 2, 2, 32)     36864       ['activation_79[0][0]']
#
#  concatenate_22 (Concatenate)   (None, 2, 2, 192)    0           ['dense4e_branch2b[0][0]',
#                                                                   'concatenate_21[0][0]']
#
#  bn4f_branch2a (BatchNormalizat  (None, 2, 2, 192)   768         ['concatenate_22[0][0]']
#  ion)
#
#  activation_80 (Activation)     (None, 2, 2, 192)    0           ['bn4f_branch2a[0][0]']
#
#  dense4f_branch2a (Conv2D)      (None, 2, 2, 128)    24576       ['activation_80[0][0]']
#
#  bn4f_branch2b (BatchNormalizat  (None, 2, 2, 128)   512         ['dense4f_branch2a[0][0]']
#  ion)
#
#  activation_81 (Activation)     (None, 2, 2, 128)    0           ['bn4f_branch2b[0][0]']
#
#  dense4f_branch2b (Conv2D)      (None, 2, 2, 32)     36864       ['activation_81[0][0]']
#
#  concatenate_23 (Concatenate)   (None, 2, 2, 224)    0           ['dense4f_branch2b[0][0]',
#                                                                   'concatenate_22[0][0]']
#
#  bn4g_branch2a (BatchNormalizat  (None, 2, 2, 224)   896         ['concatenate_23[0][0]']
#  ion)
#
#  activation_82 (Activation)     (None, 2, 2, 224)    0           ['bn4g_branch2a[0][0]']
#
#  dense4g_branch2a (Conv2D)      (None, 2, 2, 128)    28672       ['activation_82[0][0]']
#
#  bn4g_branch2b (BatchNormalizat  (None, 2, 2, 128)   512         ['dense4g_branch2a[0][0]']
#  ion)
#
#  activation_83 (Activation)     (None, 2, 2, 128)    0           ['bn4g_branch2b[0][0]']
#
#  dense4g_branch2b (Conv2D)      (None, 2, 2, 32)     36864       ['activation_83[0][0]']
#
#  concatenate_24 (Concatenate)   (None, 2, 2, 256)    0           ['dense4g_branch2b[0][0]',
#                                                                   'concatenate_23[0][0]']
#
#  bn4h_branch2a (BatchNormalizat  (None, 2, 2, 256)   1024        ['concatenate_24[0][0]']
#  ion)
#
#  activation_84 (Activation)     (None, 2, 2, 256)    0           ['bn4h_branch2a[0][0]']
#
#  dense4h_branch2a (Conv2D)      (None, 2, 2, 128)    32768       ['activation_84[0][0]']
#
#  bn4h_branch2b (BatchNormalizat  (None, 2, 2, 128)   512         ['dense4h_branch2a[0][0]']
#  ion)
#
#  activation_85 (Activation)     (None, 2, 2, 128)    0           ['bn4h_branch2b[0][0]']
#
#  dense4h_branch2b (Conv2D)      (None, 2, 2, 32)     36864       ['activation_85[0][0]']
#
#  concatenate_25 (Concatenate)   (None, 2, 2, 288)    0           ['dense4h_branch2b[0][0]',
#                                                                   'concatenate_24[0][0]']
#
#  bn4i_branch2a (BatchNormalizat  (None, 2, 2, 288)   1152        ['concatenate_25[0][0]']
#  ion)
#
#  activation_86 (Activation)     (None, 2, 2, 288)    0           ['bn4i_branch2a[0][0]']
#
#  dense4i_branch2a (Conv2D)      (None, 2, 2, 128)    36864       ['activation_86[0][0]']
#
#  bn4i_branch2b (BatchNormalizat  (None, 2, 2, 128)   512         ['dense4i_branch2a[0][0]']
#  ion)
#
#  activation_87 (Activation)     (None, 2, 2, 128)    0           ['bn4i_branch2b[0][0]']
#
#  dense4i_branch2b (Conv2D)      (None, 2, 2, 32)     36864       ['activation_87[0][0]']
#
#  concatenate_26 (Concatenate)   (None, 2, 2, 320)    0           ['dense4i_branch2b[0][0]',
#                                                                   'concatenate_25[0][0]']
#
# ...
#
#  dense5h_branch2b (Conv2D)      (None, 1, 1, 32)     36864       ['activation_133[0][0]']
#
#  concatenate_49 (Concatenate)   (None, 1, 1, 288)    0           ['dense5h_branch2b[0][0]',
#                                                                   'concatenate_48[0][0]']
#
#  bn5i_branch2a (BatchNormalizat  (None, 1, 1, 288)   1152        ['concatenate_49[0][0]']
#  ion)
#
#  activation_134 (Activation)    (None, 1, 1, 288)    0           ['bn5i_branch2a[0][0]']
#
#  dense5i_branch2a (Conv2D)      (None, 1, 1, 128)    36864       ['activation_134[0][0]']
#
#  bn5i_branch2b (BatchNormalizat  (None, 1, 1, 128)   512         ['dense5i_branch2a[0][0]']
#  ion)
#
#  activation_135 (Activation)    (None, 1, 1, 128)    0           ['bn5i_branch2b[0][0]']
#
#  dense5i_branch2b (Conv2D)      (None, 1, 1, 32)     36864       ['activation_135[0][0]']
#
#  concatenate_50 (Concatenate)   (None, 1, 1, 320)    0           ['dense5i_branch2b[0][0]',
#                                                                   'concatenate_49[0][0]']
#
#  bn5j_branch2a (BatchNormalizat  (None, 1, 1, 320)   1280        ['concatenate_50[0][0]']
#  ion)
#
#  activation_136 (Activation)    (None, 1, 1, 320)    0           ['bn5j_branch2a[0][0]']
#
#  dense5j_branch2a (Conv2D)      (None, 1, 1, 128)    40960       ['activation_136[0][0]']
#
#  bn5j_branch2b (BatchNormalizat  (None, 1, 1, 128)   512         ['dense5j_branch2a[0][0]']
#  ion)
#
#  activation_137 (Activation)    (None, 1, 1, 128)    0           ['bn5j_branch2b[0][0]']
#
#  dense5j_branch2b (Conv2D)      (None, 1, 1, 32)     36864       ['activation_137[0][0]']
#
#  concatenate_51 (Concatenate)   (None, 1, 1, 352)    0           ['dense5j_branch2b[0][0]',
#                                                                   'concatenate_50[0][0]']
#
#  bn5k_branch2a (BatchNormalizat  (None, 1, 1, 352)   1408        ['concatenate_51[0][0]']
#  ion)
#
#  activation_138 (Activation)    (None, 1, 1, 352)    0           ['bn5k_branch2a[0][0]']
#
#  dense5k_branch2a (Conv2D)      (None, 1, 1, 128)    45056       ['activation_138[0][0]']
#
#  bn5k_branch2b (BatchNormalizat  (None, 1, 1, 128)   512         ['dense5k_branch2a[0][0]']
#  ion)
#
#  activation_139 (Activation)    (None, 1, 1, 128)    0           ['bn5k_branch2b[0][0]']
#
#  dense5k_branch2b (Conv2D)      (None, 1, 1, 32)     36864       ['activation_139[0][0]']
#
#  concatenate_52 (Concatenate)   (None, 1, 1, 384)    0           ['dense5k_branch2b[0][0]',
#                                                                   'concatenate_51[0][0]']
#
#  bn5l_branch2a (BatchNormalizat  (None, 1, 1, 384)   1536        ['concatenate_52[0][0]']
#  ion)
#
#  activation_140 (Activation)    (None, 1, 1, 384)    0           ['bn5l_branch2a[0][0]']
#
#  dense5l_branch2a (Conv2D)      (None, 1, 1, 128)    49152       ['activation_140[0][0]']
#
#  bn5l_branch2b (BatchNormalizat  (None, 1, 1, 128)   512         ['dense5l_branch2a[0][0]']
#  ion)
#
#  activation_141 (Activation)    (None, 1, 1, 128)    0           ['bn5l_branch2b[0][0]']
#
#  dense5l_branch2b (Conv2D)      (None, 1, 1, 32)     36864       ['activation_141[0][0]']
#
#  concatenate_53 (Concatenate)   (None, 1, 1, 416)    0           ['dense5l_branch2b[0][0]',
#                                                                   'concatenate_52[0][0]']
#
#  bn5m_branch2a (BatchNormalizat  (None, 1, 1, 416)   1664        ['concatenate_53[0][0]']
#  ion)
#
#  activation_142 (Activation)    (None, 1, 1, 416)    0           ['bn5m_branch2a[0][0]']
#
#  dense5m_branch2a (Conv2D)      (None, 1, 1, 128)    53248       ['activation_142[0][0]']
#
#  bn5m_branch2b (BatchNormalizat  (None, 1, 1, 128)   512         ['dense5m_branch2a[0][0]']
#  ion)
#
#  activation_143 (Activation)    (None, 1, 1, 128)    0           ['bn5m_branch2b[0][0]']
#
#  dense5m_branch2b (Conv2D)      (None, 1, 1, 32)     36864       ['activation_143[0][0]']
#
#  concatenate_54 (Concatenate)   (None, 1, 1, 448)    0           ['dense5m_branch2b[0][0]',
#                                                                   'concatenate_53[0][0]']
#
#  bn5n_branch2a (BatchNormalizat  (None, 1, 1, 448)   1792        ['concatenate_54[0][0]']
#  ion)
#
#  activation_144 (Activation)    (None, 1, 1, 448)    0           ['bn5n_branch2a[0][0]']
#
#  dense5n_branch2a (Conv2D)      (None, 1, 1, 128)    57344       ['activation_144[0][0]']
#
#  bn5n_branch2b (BatchNormalizat  (None, 1, 1, 128)   512         ['dense5n_branch2a[0][0]']
#  ion)
#
#  activation_145 (Activation)    (None, 1, 1, 128)    0           ['bn5n_branch2b[0][0]']
#
#  dense5n_branch2b (Conv2D)      (None, 1, 1, 32)     36864       ['activation_145[0][0]']
#
#  concatenate_55 (Concatenate)   (None, 1, 1, 480)    0           ['dense5n_branch2b[0][0]',
#                                                                   'concatenate_54[0][0]']
#
#  bn5o_branch2a (BatchNormalizat  (None, 1, 1, 480)   1920        ['concatenate_55[0][0]']
#  ion)
#
#  activation_146 (Activation)    (None, 1, 1, 480)    0           ['bn5o_branch2a[0][0]']
#
#  dense5o_branch2a (Conv2D)      (None, 1, 1, 128)    61440       ['activation_146[0][0]']
#
#  bn5o_branch2b (BatchNormalizat  (None, 1, 1, 128)   512         ['dense5o_branch2a[0][0]']
#  ion)
#
#  activation_147 (Activation)    (None, 1, 1, 128)    0           ['bn5o_branch2b[0][0]']
#
#  dense5o_branch2b (Conv2D)      (None, 1, 1, 32)     36864       ['activation_147[0][0]']
#
#  concatenate_56 (Concatenate)   (None, 1, 1, 512)    0           ['dense5o_branch2b[0][0]',
#                                                                   'concatenate_55[0][0]']
#
#  bn5p_branch2a (BatchNormalizat  (None, 1, 1, 512)   2048        ['concatenate_56[0][0]']
#  ion)
#
#  activation_148 (Activation)    (None, 1, 1, 512)    0           ['bn5p_branch2a[0][0]']
#
#  dense5p_branch2a (Conv2D)      (None, 1, 1, 128)    65536       ['activation_148[0][0]']
#
#  bn5p_branch2b (BatchNormalizat  (None, 1, 1, 128)   512         ['dense5p_branch2a[0][0]']
#  ion)
#
#  activation_149 (Activation)    (None, 1, 1, 128)    0           ['bn5p_branch2b[0][0]']
#
#  dense5p_branch2b (Conv2D)      (None, 1, 1, 32)     36864       ['activation_149[0][0]']
#
#  concatenate_57 (Concatenate)   (None, 1, 1, 544)    0           ['dense5p_branch2b[0][0]',
#                                                                   'concatenate_56[0][0]']
#
#  bn5q_branch2a (BatchNormalizat  (None, 1, 1, 544)   2176        ['concatenate_57[0][0]']
#  ion)
#
#  transition5q_branch2a (Conv2D)  (None, 1, 1, 32)    17408       ['bn5q_branch2a[0][0]']
#
#  average_pooling2d_3 (AveragePo  (None, 1, 1, 32)    0           ['transition5q_branch2a[0][0]']
#  oling2D)
#
#  global_average_pooling2d_1 (Gl  (None, 32)          0           ['average_pooling2d_3[0][0]']
#  obalAveragePooling2D)
#
#  1000D_full (Dense)             (None, 100)          3300        ['global_average_pooling2d_1[0][0
#                                                                  ]']
#
#  activation_150 (Activation)    (None, 100)          0           ['1000D_full[0][0]']
#
# ==================================================================================================
# Total params: 4,538,340
# Trainable params: 4,484,836
# Non-trainable params: 53,504
# __________________________________________________________________________________________________

# %%
plot_model(densenet121,show_shapes=True)

# %%
densenet121.compile(optimizer='SGD',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

history_densenet121 = densenet121.fit(x_train, y_train, epochs=100)
# Out:
# Epoch 1/100
# 1563/1563 [==============================] - 79s 43ms/step - loss: 6.4145 - accuracy: 0.0507
# Epoch 2/100
# 1563/1563 [==============================] - 67s 43ms/step - loss: 5.9484 - accuracy: 0.0952
# Epoch 3/100
# 1563/1563 [==============================] - 67s 43ms/step - loss: 5.6666 - accuracy: 0.1342
# Epoch 4/100
# 1563/1563 [==============================] - 68s 43ms/step - loss: 5.4360 - accuracy: 0.1644
# Epoch 5/100
# 1563/1563 [==============================] - 68s 43ms/step - loss: 5.2469 - accuracy: 0.1940
# Epoch 6/100
# 1563/1563 [==============================] - 68s 43ms/step - loss: 5.0570 - accuracy: 0.2228
# Epoch 7/100
# 1563/1563 [==============================] - 68s 43ms/step - loss: 4.9032 - accuracy: 0.2488
# Epoch 8/100
# 1563/1563 [==============================] - 68s 43ms/step - loss: 4.7569 - accuracy: 0.2733
# Epoch 9/100
# 1563/1563 [==============================] - 67s 43ms/step - loss: 4.6191 - accuracy: 0.2984
# Epoch 10/100
# 1563/1563 [==============================] - 68s 44ms/step - loss: 4.4983 - accuracy: 0.3195
# Epoch 11/100
# 1563/1563 [==============================] - 70s 45ms/step - loss: 4.3802 - accuracy: 0.3399
# Epoch 12/100
# 1563/1563 [==============================] - 68s 44ms/step - loss: 4.2682 - accuracy: 0.3600
# Epoch 13/100
# 1563/1563 [==============================] - 69s 44ms/step - loss: 4.1628 - accuracy: 0.3811
# Epoch 14/100
# 1563/1563 [==============================] - 70s 45ms/step - loss: 4.0695 - accuracy: 0.3979
# Epoch 15/100
# 1563/1563 [==============================] - 69s 44ms/step - loss: 3.9770 - accuracy: 0.4170
# Epoch 16/100
# 1563/1563 [==============================] - 69s 44ms/step - loss: 3.8874 - accuracy: 0.4353
# Epoch 17/100
# 1563/1563 [==============================] - 71s 45ms/step - loss: 3.8046 - accuracy: 0.4505
# Epoch 18/100
# 1563/1563 [==============================] - 69s 44ms/step - loss: 3.7208 - accuracy: 0.4681
# Epoch 19/100
# 1563/1563 [==============================] - 69s 44ms/step - loss: 3.6439 - accuracy: 0.4826
# Epoch 20/100
# 1563/1563 [==============================] - 69s 44ms/step - loss: 3.5503 - accuracy: 0.5030
# Epoch 21/100
# 1563/1563 [==============================] - 69s 44ms/step - loss: 3.4716 - accuracy: 0.5168
# Epoch 22/100
# 1563/1563 [==============================] - 70s 45ms/step - loss: 3.3935 - accuracy: 0.5342
# Epoch 23/100
# 1563/1563 [==============================] - 69s 44ms/step - loss: 3.3274 - accuracy: 0.5469
# Epoch 24/100
# 1563/1563 [==============================] - 69s 44ms/step - loss: 3.2488 - accuracy: 0.5653
# Epoch 25/100
# 1563/1563 [==============================] - 69s 44ms/step - loss: 3.1717 - accuracy: 0.5814
# Epoch 26/100
# 1563/1563 [==============================] - 69s 44ms/step - loss: 3.1051 - accuracy: 0.5965
# Epoch 27/100
# 1563/1563 [==============================] - 69s 44ms/step - loss: 3.0413 - accuracy: 0.6089
# Epoch 28/100
# 1563/1563 [==============================] - 69s 44ms/step - loss: 2.9771 - accuracy: 0.6248
# Epoch 29/100
# 1563/1563 [==============================] - 69s 44ms/step - loss: 2.9151 - accuracy: 0.6383
# Epoch 30/100
# 1563/1563 [==============================] - 69s 44ms/step - loss: 2.8474 - accuracy: 0.6546
# Epoch 31/100
# 1563/1563 [==============================] - 69s 44ms/step - loss: 2.7990 - accuracy: 0.6677
# Epoch 32/100
# 1563/1563 [==============================] - 69s 44ms/step - loss: 2.7457 - accuracy: 0.6791
# Epoch 33/100
# 1563/1563 [==============================] - 69s 44ms/step - loss: 2.6824 - accuracy: 0.6927
# Epoch 34/100
# 1563/1563 [==============================] - 68s 44ms/step - loss: 2.6276 - accuracy: 0.7082
# Epoch 35/100
# 1563/1563 [==============================] - 69s 44ms/step - loss: 2.5854 - accuracy: 0.7183
# Epoch 36/100
# 1563/1563 [==============================] - 68s 44ms/step - loss: 2.5381 - accuracy: 0.7286
# Epoch 37/100
# 1563/1563 [==============================] - 68s 44ms/step - loss: 2.4813 - accuracy: 0.7456
# Epoch 38/100
# 1563/1563 [==============================] - 69s 44ms/step - loss: 2.4489 - accuracy: 0.7532
# Epoch 39/100
# 1563/1563 [==============================] - 69s 44ms/step - loss: 2.4010 - accuracy: 0.7638
# Epoch 40/100
# 1563/1563 [==============================] - 69s 44ms/step - loss: 2.3611 - accuracy: 0.7751
# Epoch 41/100
# 1563/1563 [==============================] - 69s 44ms/step - loss: 2.3260 - accuracy: 0.7824
# Epoch 42/100
# 1563/1563 [==============================] - 69s 44ms/step - loss: 2.2950 - accuracy: 0.7913
# Epoch 43/100
# 1563/1563 [==============================] - 69s 44ms/step - loss: 2.2464 - accuracy: 0.8068
# Epoch 44/100
# 1563/1563 [==============================] - 70s 45ms/step - loss: 2.2118 - accuracy: 0.8131
# Epoch 45/100
# 1563/1563 [==============================] - 69s 44ms/step - loss: 2.1811 - accuracy: 0.8215
# Epoch 46/100
# 1563/1563 [==============================] - 69s 44ms/step - loss: 2.1458 - accuracy: 0.8302
# Epoch 47/100
# 1563/1563 [==============================] - 69s 44ms/step - loss: 2.1141 - accuracy: 0.8383
# Epoch 48/100
# 1563/1563 [==============================] - 68s 44ms/step - loss: 2.0925 - accuracy: 0.8422
# Epoch 49/100
# 1563/1563 [==============================] - 69s 44ms/step - loss: 2.0879 - accuracy: 0.8443
# Epoch 50/100
# 1563/1563 [==============================] - 68s 44ms/step - loss: 2.0442 - accuracy: 0.8570
# Epoch 51/100
# 1563/1563 [==============================] - 68s 44ms/step - loss: 2.0039 - accuracy: 0.8676
# Epoch 52/100
# 1563/1563 [==============================] - 68s 44ms/step - loss: 2.0074 - accuracy: 0.8666
# Epoch 53/100
# 1563/1563 [==============================] - 69s 44ms/step - loss: 1.9804 - accuracy: 0.8712
# Epoch 54/100
# 1563/1563 [==============================] - 68s 44ms/step - loss: 1.9318 - accuracy: 0.8868
# Epoch 55/100
# 1563/1563 [==============================] - 69s 44ms/step - loss: 1.9202 - accuracy: 0.8876
# Epoch 56/100
# 1563/1563 [==============================] - 68s 44ms/step - loss: 1.9212 - accuracy: 0.8849
# Epoch 57/100
# 1563/1563 [==============================] - 68s 44ms/step - loss: 1.9011 - accuracy: 0.8894
# Epoch 58/100
# 1563/1563 [==============================] - 69s 44ms/step - loss: 1.8751 - accuracy: 0.8972
# Epoch 59/100
# 1563/1563 [==============================] - 68s 44ms/step - loss: 1.8547 - accuracy: 0.9018
# Epoch 60/100
# 1563/1563 [==============================] - 69s 44ms/step - loss: 1.8543 - accuracy: 0.8987
# Epoch 61/100
# 1563/1563 [==============================] - 68s 44ms/step - loss: 1.8244 - accuracy: 0.9076
# Epoch 62/100
# 1563/1563 [==============================] - 68s 44ms/step - loss: 1.8086 - accuracy: 0.9115
# Epoch 63/100
# 1563/1563 [==============================] - 68s 44ms/step - loss: 1.7934 - accuracy: 0.9155
# Epoch 64/100
# 1563/1563 [==============================] - 68s 44ms/step - loss: 1.7805 - accuracy: 0.9179
# Epoch 65/100
# 1563/1563 [==============================] - 68s 44ms/step - loss: 1.7693 - accuracy: 0.9187
# Epoch 66/100
# 1563/1563 [==============================] - 69s 44ms/step - loss: 1.7643 - accuracy: 0.9192
# Epoch 67/100
# 1563/1563 [==============================] - 71s 46ms/step - loss: 1.7589 - accuracy: 0.9189
# Epoch 68/100
# 1563/1563 [==============================] - 71s 45ms/step - loss: 1.7199 - accuracy: 0.9290
# Epoch 69/100
# 1563/1563 [==============================] - 69s 44ms/step - loss: 1.7202 - accuracy: 0.9285
# Epoch 70/100
# 1563/1563 [==============================] - 69s 44ms/step - loss: 1.7010 - accuracy: 0.9323
# Epoch 71/100
# 1563/1563 [==============================] - 69s 44ms/step - loss: 1.6968 - accuracy: 0.9332
# Epoch 72/100
# 1563/1563 [==============================] - 69s 44ms/step - loss: 1.6953 - accuracy: 0.9310
# Epoch 73/100
# 1563/1563 [==============================] - 69s 44ms/step - loss: 1.6807 - accuracy: 0.9328
# Epoch 74/100
# 1563/1563 [==============================] - 69s 44ms/step - loss: 1.6658 - accuracy: 0.9371
# Epoch 75/100
# 1563/1563 [==============================] - 69s 44ms/step - loss: 1.6474 - accuracy: 0.9411
# Epoch 76/100
# 1563/1563 [==============================] - 69s 44ms/step - loss: 1.6261 - accuracy: 0.9462
# Epoch 77/100
# 1563/1563 [==============================] - 68s 44ms/step - loss: 1.6248 - accuracy: 0.9458
# Epoch 78/100
# 1563/1563 [==============================] - 68s 44ms/step - loss: 1.6323 - accuracy: 0.9399
# Epoch 79/100
# 1563/1563 [==============================] - 69s 44ms/step - loss: 1.6225 - accuracy: 0.9419
# Epoch 80/100
# 1563/1563 [==============================] - 69s 44ms/step - loss: 1.5925 - accuracy: 0.9495
# Epoch 81/100
# 1563/1563 [==============================] - 69s 44ms/step - loss: 1.5881 - accuracy: 0.9476
# Epoch 82/100
# 1563/1563 [==============================] - 70s 45ms/step - loss: 1.5779 - accuracy: 0.9487
# Epoch 83/100
# 1563/1563 [==============================] - 70s 44ms/step - loss: 1.5773 - accuracy: 0.9487
# Epoch 84/100
# 1563/1563 [==============================] - 69s 44ms/step - loss: 1.5688 - accuracy: 0.9485
# Epoch 85/100
# 1563/1563 [==============================] - 71s 45ms/step - loss: 1.5758 - accuracy: 0.9450
# Epoch 86/100
# 1563/1563 [==============================] - 72s 46ms/step - loss: 1.5574 - accuracy: 0.9492
# Epoch 87/100
# 1563/1563 [==============================] - 73s 47ms/step - loss: 1.5577 - accuracy: 0.9475
# Epoch 88/100
# 1563/1563 [==============================] - 73s 47ms/step - loss: 1.5454 - accuracy: 0.9504
# Epoch 89/100
# 1563/1563 [==============================] - 73s 46ms/step - loss: 1.5211 - accuracy: 0.9551
# Epoch 90/100
# 1563/1563 [==============================] - 71s 45ms/step - loss: 1.5060 - accuracy: 0.9591
# Epoch 91/100
# 1563/1563 [==============================] - 70s 45ms/step - loss: 1.5073 - accuracy: 0.9570
# Epoch 92/100
# 1563/1563 [==============================] - 70s 45ms/step - loss: 1.4942 - accuracy: 0.9593
# Epoch 93/100
# 1563/1563 [==============================] - 71s 45ms/step - loss: 1.4860 - accuracy: 0.9603
# Epoch 94/100
# 1563/1563 [==============================] - 70s 45ms/step - loss: 1.4836 - accuracy: 0.9585
# Epoch 95/100
# 1563/1563 [==============================] - 71s 45ms/step - loss: 1.4820 - accuracy: 0.9570
# Epoch 96/100
# 1563/1563 [==============================] - 70s 45ms/step - loss: 1.4813 - accuracy: 0.9560
# Epoch 97/100
# 1563/1563 [==============================] - 69s 44ms/step - loss: 1.4661 - accuracy: 0.9586
# Epoch 98/100
# 1563/1563 [==============================] - 70s 44ms/step - loss: 1.4593 - accuracy: 0.9588
# Epoch 99/100
# 1563/1563 [==============================] - 71s 45ms/step - loss: 1.4449 - accuracy: 0.9625
# Epoch 100/100
# 1563/1563 [==============================] - 70s 45ms/step - loss: 1.4423 - accuracy: 0.9606

# %%
import matplotlib.pyplot as plt

plt.plot(history_densenet121.history['loss'],'r')
plt.plot(history_resnet34.history['loss'],'b')
plt.title('Model training loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['DenseNet121','ResNet34'], loc='upper left')
plt.show()

# %%
plt.plot(history_densenet121.history['accuracy'], 'r')
plt.plot(history_resnet34.history['accuracy'], 'b')
plt.title('Model validation accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['DenseNet121', 'ResNet34'], loc='upper left')
plt.show()
